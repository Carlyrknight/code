# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
#import 
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Open Model

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic60.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 70

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/corpus.pkl', 'rb') )

# %% [markdown]
# # IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %% [markdown]
# ### Descriptions: Based on year 2005

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['divis', 'engin', 'tool', 'machin', 'truck', 'air', 'power', 'water']
# FREX WORDS: ['truck', 'pump', 'engin', 'valv', 'machin', 'tool', 'hydraul', 'compressor']
#
# TOPIC  1
# PROB WORDS: ['milk', 'beverag', 'food', 'tho', 'bottl', 'can', 'dairi', 'alden']
# FREX WORDS: ['milk', 'beverag', 'bottl', 'can', 'alden', 'tho', 'dairi', 'glen']
#
# TOPIC  2
# PROB WORDS: ['loan', 'bank', 'borrow', 'matur', 'save', 'portfolio', 'liabil', 'debt']
# FREX WORDS: ['loan', 'bank', 'portfolio', 'well', 'fargo', 'chargeoff', 'lend', 'nonaccru']
#
# TOPIC  3
# PROB WORDS: ['coal', 'mine', 'caterpillar', 'ton', 'kopper', 'ship', 'energi', 'vessel']
# FREX WORDS: ['coal', 'caterpillar', 'mine', 'ogden', 'kopper', 'ton', 'vessel', 'coke']
#
# TOPIC  4
# PROB WORDS: ['insur', 'claim', 'risk', 'reinsur', 'underwrit', 'liabil', 'premium', 'properti']
# FREX WORDS: ['reinsur', 'underwrit', 'casualti', 'cna', 'catastroph', 'allstat', 'policyhold', 'insur']
#
# TOPIC  5
# PROB WORDS: ['store', 'retail', 'merchandis', 'open', 'center', 'depart', 'leas', 'shop']
# FREX WORDS: ['store', 'merchandis', 'shop', 'retail', 'supermarket', 'maci', 'catalog', 'remodel']
#
# TOPIC  6
# PROB WORDS: ['insur', 'life', 'claim', 'risk', 'reinsur', 'annuiti', 'liabil', 'safeco']
# FREX WORDS: ['safeco', 'reinsur', 'annuiti', 'policyhold', 'metlif', 'hedg', 'mortal', 'cigna']
#
# TOPIC  7
# PROB WORDS: ['revenu', 'softwar', 'technolog', 'ncr', 'sun', 'solut', 'system', 'affect']
# FREX WORDS: ['softwar', 'ncr', 'sun', 'ed', 'microsoft', 'outsourc', 'server', 'solut']
#
# TOPIC  8
# PROB WORDS: ['transport', 'leas', 'truck', 'carrier', 'emerson', 'freight', 'revenu', 'fleet']
# FREX WORDS: ['truck', 'emerson', 'transport', 'carrier', 'trailer', 'freight', 'fedex', 'fleet']
#
# TOPIC  9
# PROB WORDS: ['environment', 'site', 'remedi', 'liabil', 'regul', 'matter', 'respons', 'parti']
# FREX WORDS: ['environment', 'remedi', 'site', 'cleanup', 'prp', 'epa', 'dow', 'contamin']
#
# TOPIC  10
# PROB WORDS: ['care', 'health', 'medic', 'hospit', 'medicar', 'patient', 'regul', 'pharmaci']
# FREX WORDS: ['pharmaci', 'medicar', 'patient', 'caremark', 'drug', 'physician', 'medic', 'medicaid']
#
# TOPIC  11
# PROB WORDS: ['claim', 'insur', 'asbesto', 'liabil', 'advers', 'settlement', 'matter', 'file']
# FREX WORDS: ['asbesto', 'claim', 'honeywel', 'claimant', 'injuri', 'asbestosrel', 'insur', 'defens']
#
# TOPIC  12
# PROB WORDS: ['aluminum', 'metal', 'nucor', 'alcoa', 'ton', 'sheet', 'reynold', 'alloi']
# FREX WORDS: ['aluminum', 'metal', 'nucor', 'alcoa', 'reynold', 'titanium', 'alloi', 'alumina']
#
# TOPIC  13
# PROB WORDS: ['oil', 'ga', 'drill', 'field', 'barrel', 'crude', 'well', 'dai']
# FREX WORDS: ['oil', 'drill', 'barrel', 'crude', 'ga', 'refineri', 'well', 'petroleum']
#
# TOPIC  14
# PROB WORDS: ['merck', 'patient', 'research', 'diseas', 'treatment', 'health', 'medic', 'drug']
# FREX WORDS: ['patient', 'merck', 'diseas', 'pfizer', 'medicin', 'cancer', 'clinic', 'drug']
#
# TOPIC  15
# PROB WORDS: ['steel', 'furnac', 'ton', 'iron', 'or', 'ltv', 'roll', 'sharon']
# FREX WORDS: ['steel', 'furnac', 'ltv', 'armco', 'iron', 'sharon', 'or', 'ton']
#
# TOPIC  16
# PROB WORDS: ['power', 'electr', 'ga', 'mohawk', 'niagara', 'nuclear', 'commiss', 'util']
# FREX WORDS: ['niagara', 'mohawk', 'ga', 'electr', 'nuclear', 'kilowatt', 'power', 'atom']
#
# TOPIC  17
# PROB WORDS: ['lyondel', 'equistar', 'landfil', 'ventur', 'joint', 'wast', 'alli', 'lcr']
# FREX WORDS: ['lyondel', 'equistar', 'landfil', 'lcr', 'cement', 'alli', 'crude', 'lone']
#
# TOPIC  18
# PROB WORDS: ['shall', 'borrow', 'lender', 'loan', 'section', 'agent', 'administr', 'parti']
# FREX WORDS: ['shall', 'lender', 'corco', 'hereund', 'loan', 'tranch', 'section', 'hereof']
#
# TOPIC  19
# PROB WORDS: ['chemic', 'plastic', 'research', 'resin', 'divis', 'fiber', 'polym', 'raw']
# FREX WORDS: ['chemic', 'resin', 'plastic', 'polym', 'dow', 'polyest', 'fiber', 'polyethylen']
#
# TOPIC  20
# PROB WORDS: ['tire', 'car', 'vehicl', 'automot', 'goodyear', 'rubber', 'motor', 'delphi']
# FREX WORDS: ['delphi', 'tire', 'goodyear', 'automot', 'car', 'rubber', 'vehicl', 'motor']
#
# TOPIC  21
# PROB WORDS: ['insur', 'life', 'premium', 'american', 'group', 'policyhold', 'individu', 'annuiti']
# FREX WORDS: ['insur', 'policyhold', 'life', 'annuiti', 'policyown', 'mcgrawhil', 'colleg', 'transamerica']
#
# TOPIC  22
# PROB WORDS: ['divis', 'research', 'field', 'electron', 'laboratori', 'engin', 'instal', 'introduc']
# FREX WORDS: ['rca', 'laboratori', 'research', 'divis', 'tube', 'electron', 'machin', 'field']
#
# TOPIC  23
# PROB WORDS: ['home', 'hous', 'land', 'disnei', 'park', 'california', 'famili', 'residenti']
# FREX WORDS: ['home', 'disnei', 'hous', 'land', 'homebuild', 'park', 'walt', 'recreat']
#
# TOPIC  24
# PROB WORDS: ['eastman', 'gatx', 'kodak', 'film', 'camera', 'photograph', 'imag', 'color']
# FREX WORDS: ['eastman', 'gatx', 'kodak', 'film', 'camera', 'photograph', 'cocacola', 'photographi']
#
# TOPIC  25
# PROB WORDS: ['research', 'drug', 'abbott', 'pharmaceut', 'laboratori', 'care', 'introduc', 'len']
# FREX WORDS: ['abbott', 'drug', 'pharmaceut', 'len', 'bausch', 'lomb', 'laboratori', 'upjohn']
#
# TOPIC  26
# PROB WORDS: ['fuel', 'power', 'energi', 'util', 'electr', 'nuclear', 'carolina', 'pec']
# FREX WORDS: ['pec', 'fuel', 'nuclear', 'aep', 'decommiss', 'energi', 'ferc', 'synthet']
#
# TOPIC  27
# PROB WORDS: ['network', 'technolog', 'commun', 'gatewai', 'internet', 'telecommun', 'cabl', 'access']
# FREX WORDS: ['gatewai', 'network', 'internet', 'telecommun', 'wireless', 'cabl', 'broadband', 'qwest']
#
# TOPIC  28
# PROB WORDS: ['patent', 'file', 'inventori', 'law', 'item', 'revenu', 'advers', 'investig']
# FREX WORDS: ['patent', 'complaint', 'infring', 'alleg', 'intellectu', 'plaintiff', 'xerox', 'injunct']
#
# TOPIC  29
# PROB WORDS: ['risk', 'trade', 'instrument', 'transact', 'merril', 'lynch', 'deriv', 'commod']
# FREX WORDS: ['risk', 'merril', 'lynch', 'counterparti', 'swap', 'instrument', 'hedg', 'commod']
#
# TOPIC  30
# PROB WORDS: ['txu', 'energi', 'corp', 'electr', 'gpu', 'nuclear', 'util', 'regulatori']
# FREX WORDS: ['txu', 'gpu', 'nsp', 'nuclear', 'decommiss', 'jcpl', 'electr', 'energi']
#
# TOPIC  31
# PROB WORDS: ['currenc', 'foreign', 'hedg', 'exchang', 'risk', 'instrument', 'deriv', 'exposur']
# FREX WORDS: ['currenc', 'hedg', 'foreign', 'swap', 'instrument', 'euro', 'risk', 'exposur']
#
# TOPIC  32
# PROB WORDS: ['divis', 'glass', 'fabric', 'textil', 'plastic', 'instal', 'packag', 'fiber']
# FREX WORDS: ['glass', 'textil', 'fabric', 'carpet', 'yarn', 'plastic', 'furnitur', 'vinyl']
#
# TOPIC  33
# PROB WORDS: ['bank', 'york', 'trust', 'branch', 'street', 'loan', 'depart', 'citi']
# FREX WORDS: ['bank', 'branch', 'manhattan', 'trust', 'boston', 'street', 'irv', 'york']
#
# TOPIC  34
# PROB WORDS: ['loan', 'mortgag', 'risk', 'fair', 'hedg', 'deriv', 'instrument', 'portfolio']
# FREX WORDS: ['mortgag', 'loan', 'hedg', 'msr', 'risk', 'portfolio', 'securit', 'deriv']
#
# TOPIC  35
# PROB WORDS: ['presid', 'vice', 'chairman', 'execut', 'chief', 'york', 'divis', 'john']
# FREX WORDS: ['vice', 'presid', 'chairman', 'robert', 'treasur', 'william', 'jame', 'chief']
#
# TOPIC  36
# PROB WORDS: ['aircraft', 'airlin', 'air', 'rout', 'passeng', 'american', 'jet', 'boe']
# FREX WORDS: ['aircraft', 'airlin', 'boe', 'passeng', 'fare', 'jet', 'flight', 'rout']
#
# TOPIC  37
# PROB WORDS: ['railroad', 'car', 'freight', 'transport', 'traffic', 'pacif', 'commiss', 'revenu']
# FREX WORDS: ['railroad', 'car', 'freight', 'traffic', 'railwai', 'interst', 'rail', 'yard']
#
# TOPIC  38
# PROB WORDS: ['acquisit', 'debt', 'sfa', 'borrow', 'revolv', 'liabil', 'grant', 'amort']
# FREX WORDS: ['sfa', 'acquisit', 'forma', 'revolv', 'ebitda', 'vendor', 'subordin', 'swap']
#
# TOPIC  39
# PROB WORDS: ['grace', 'monsanto', 'ppg', 'dec', 'bangor', 'punta', 'piper', 'dean']
# FREX WORDS: ['monsanto', 'grace', 'ppg', 'dec', 'bangor', 'punta', 'piper', 'dean']
#
# TOPIC  40
# PROB WORDS: ['lhe', 'lor', 'tor', 'brunswick', 'slock', 'thai', 'dealer', 'boat']
# FREX WORDS: ['lhe', 'brunswick', 'lor', 'tor', 'boat', 'slock', 'fmc', 'thai']
#
# TOPIC  41
# PROB WORDS: ['food', 'consum', 'fiscal', 'brand', 'meat', 'restaur', 'conagra', 'mill']
# FREX WORDS: ['food', 'conagra', 'meat', 'beef', 'restaur', 'heinz', 'mill', 'feed']
#
# TOPIC  42
# PROB WORDS: ['telephon', 'ventur', 'commun', 'bell', 'cabl', 'group', 'termin', 'execut']
# FREX WORDS: ['bell', 'telephon', 'cabl', 'ventur', 'georgia', 'telecom', 'radio', 'georgian']
#
# TOPIC  43
# PROB WORDS: ['claim', 'bankruptci', 'reorgan', 'file', 'chapter', 'owen', 'court', 'liabil']
# FREX WORDS: ['owen', 'bankruptci', 'chapter', 'corn', 'debtor', 'reorgan', 'asbestosrel', 'claim']
#
# TOPIC  44
# PROB WORDS: ['risk', 'loan', 'kei', 'bank', 'portfolio', 'bancorp', 'deriv', 'fair']
# FREX WORDS: ['bancorp', 'risk', 'securit', 'loan', 'portfolio', 'card', 'client', 'cit']
#
# TOPIC  45
# PROB WORDS: ['dealership', 'dealer', 'vehicl', 'sonic', 'acquisit', 'financ', 'bow', 'mail']
# FREX WORDS: ['dealership', 'sonic', 'pitnei', 'bow', 'tyler', 'meter', 'dealer', 'lyon']
#
# TOPIC  46
# PROB WORDS: ['percent', 'sharehold', 'perform', 'technolog', 'strong', 'commit', 'strategi', 'right']
# FREX WORDS: ['percent', 'strategi', 'global', 'cabot', 'focu', 'technolog', 'innov', 'sharehold']
#
# TOPIC  47
# PROB WORDS: ['ga', 'occident', 'oil', 'natur', 'pipelin', 'explor', 'prove', 'phillip']
# FREX WORDS: ['occident', 'ga', 'pipelin', 'oil', 'phillip', 'explor', 'drill', 'kerrmcge']
#
# TOPIC  48
# PROB WORDS: ['war', 'stockhold', 'cent', 'problem', 'organ', 'countri', 'month', 'public']
# FREX WORDS: ['war', 'arc', 'men', 'postwar', 'cent', 'hope', 'wage', 'civilian']
#
# TOPIC  49
# PROB WORDS: ['crane', 'dresser', 'ashland', 'kellogg', 'engin', 'marathon', 'dii', 'fluor']
# FREX WORDS: ['dresser', 'crane', 'ashland', 'marathon', 'kellogg', 'fluor', 'dii', 'halliburton']
#
# TOPIC  50
# PROB WORDS: ['court', 'action', 'claim', 'alleg', 'defend', 'file', 'district', 'appeal']
# FREX WORDS: ['court', 'alleg', 'plaintiff', 'defend', 'district', 'complaint', 'lawsuit', 'appeal']
#
# TOPIC  51
# PROB WORDS: ['energi', 'electr', 'ga', 'util', 'consum', 'dominion', 'risk', 'power']
# FREX WORDS: ['cm', 'dominion', 'energi', 'ga', 'electr', 'sce', 'xcel', 'decommiss']
#
# TOPIC  52
# PROB WORDS: ['store', 'com', 'brand', 'retail', 'want', 'internet', 'onlin', 'inform']
# FREX WORDS: ['store', 'onlin', 'internet', 'sear', 'vendor', 'brand', 'merchandis', 'want']
#
# TOPIC  53
# PROB WORDS: ['aircraft', 'system', 'air', 'defens', 'engin', 'forc', 'commerci', 'missil']
# FREX WORDS: ['aircraft', 'missil', 'navi', 'grumman', 'northrop', 'aerospac', 'defens', 'militari']
#
# TOPIC  54
# PROB WORDS: ['pension', 'oblig', 'fair', 'flow', 'recogn', 'assumpt', 'impair', 'liabil']
# FREX WORDS: ['postretir', 'pension', 'impair', 'sfa', 'hedg', 'assumpt', 'goodwil', 'fasb']
#
# TOPIC  55
# PROB WORDS: ['client', 'morgan', 'billion', 'revenu', 'paccar', 'guaranti', 'adp', 'employ']
# FREX WORDS: ['morgan', 'client', 'adp', 'paccar', 'guaranti', 'ge', 'gec', 'schwab']
#
# TOPIC  56
# PROB WORDS: ['die', 'corn', 'cooper', 'member', 'feed', 'farm', 'farmland', 'farmer']
# FREX WORDS: ['corn', 'die', 'farmland', 'cooper', 'adm', 'farmer', 'feed', 'soybean']
#
# TOPIC  57
# PROB WORDS: ['fiscal', 'june', 'juli', 'august', 'inventori', 'quarter', 'stapl', 'mattel']
# FREX WORDS: ['fiscal', 'mattel', 'stapl', 'toi', 'tallei', 'tjx', 'bj', 'genesco']
#
# TOPIC  58
# PROB WORDS: ['copper', 'mine', 'or', 'ton', 'dodg', 'phelp', 'metal', 'gold']
# FREX WORDS: ['copper', 'mine', 'ounc', 'phelp', 'or', 'dodg', 'newmont', 'gold']
#
# TOPIC  59
# PROB WORDS: ['system', 'electron', 'technolog', 'trw', 'commun', 'data', 'digit', 'inform']
# FREX WORDS: ['trw', 'digit', 'system', 'ibm', 'electron', 'semiconductor', 'machin', 'xerox']
#
# TOPIC  60
# PROB WORDS: ['committe', 'vote', 'proxi', 'sharehold', 'audit', 'execut', 'independ', 'list']
# FREX WORDS: ['committe', 'vote', 'proxi', 'audit', 'nomine', 'dana', 'shall', 'nomin']
#
# TOPIC  61
# PROB WORDS: ['hotel', 'leas', 'aircraft', 'continent', 'airlin', 'travel', 'fuel', 'twa']
# FREX WORDS: ['hotel', 'continent', 'aircraft', 'airlin', 'twa', 'marriott', 'ual', 'travel']
#
# TOPIC  62
# PROB WORDS: ['sugar', 'crop', 'fruit', 'agricultur', 'refin', 'corn', 'suppli', 'cotton']
# FREX WORDS: ['sugar', 'crop', 'fruit', 'banana', 'cotton', 'corn', 'cuba', 'castl']
#
# TOPIC  63
# PROB WORDS: ['televis', 'station', 'advertis', 'broadcast', 'cabl', 'radio', 'newspap', 'revenu']
# FREX WORDS: ['televis', 'broadcast', 'cb', 'radio', 'cabl', 'newspap', 'fcc', 'station']
#
# TOPIC  64
# PROB WORDS: ['leas', 'fair', 'impair', 'liabil', 'financ', 'guarante', 'flow', 'risk']
# FREX WORDS: ['textron', 'impair', 'fin', 'sfa', 'entiti', 'goodwil', 'eitf', 'longliv']
#
# TOPIC  65
# PROB WORDS: ['prefer', 'debentur', 'stockhold', 'seri', 'convert', 'properti', 'liabil', 'payabl']
# FREX WORDS: ['debentur', 'prefer', 'surplu', 'sink', 'redempt', 'redeem', 'shall', 'seri']
#
# TOPIC  66
# PROB WORDS: ['paper', 'pulp', 'wood', 'timber', 'forest', 'machin', 'packag', 'lumber']
# FREX WORDS: ['pulp', 'paper', 'timber', 'forest', 'lumber', 'wood', 'paperboard', 'machin']
#
# TOPIC  67
# PROB WORDS: ['brand', 'retail', 'apparel', 'footwear', 'shoe', 'consum', 'licens', 'store']
# FREX WORDS: ['apparel', 'maytag', 'brand', 'footwear', 'shoe', 'sara', 'lee', 'men']
#
# TOPIC  68
# PROB WORDS: ['grant', 'award', 'exercis', 'particip', 'employ', 'restrict', 'compens', 'perform']
# FREX WORDS: ['award', 'shall', 'grant', 'employ', 'exercis', 'bonu', 'committe', 'sar']
#
# TOPIC  69
# PROB WORDS: ['inflat', 'inventori', 'dollar', 'declin', 'debt', 'replac', 'longterm', 'method']
# FREX WORDS: ['inflat', 'inventori', 'cummin', 'eaton', 'lifo', 'monetari', 'recess', 'brigg']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %% [markdown]
# ### Descriptions: Based on year 1950

# %%
#run frex models, time = 20
frex_output_1950 = create_topic_word_data(model, corpus, frex_w =.5, time = 20)

for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=20, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output_1950, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['divis', 'engin', 'machin', 'tool', 'air', 'truck', 'car', 'part']
# FREX WORDS: ['machin', 'engin', 'truck', 'tool', 'car', 'valv', 'compressor', 'motor']
#
# TOPIC  1
# PROB WORDS: ['packag', 'food', 'milk', 'can', 'divis', 'beverag', 'drink', 'contain']
# FREX WORDS: ['milk', 'can', 'drink', 'beverag', 'bottl', 'food', 'borden', 'beer']
#
# TOPIC  2
# PROB WORDS: ['loan', 'bank', 'real', 'estat', 'borrow', 'financ', 'save', 'portfolio']
# FREX WORDS: ['loan', 'bank', 'estat', 'portfolio', 'mortgag', 'lend', 'chargeoff', 'real']
#
# TOPIC  3
# PROB WORDS: ['coal', 'mine', 'ton', 'vessel', 'ship', 'ga', 'energi', 'util']
# FREX WORDS: ['coal', 'mine', 'ton', 'vessel', 'caterpillar', 'kopper', 'ga', 'coke']
#
# TOPIC  4
# PROB WORDS: ['insur', 'premium', 'claim', 'reinsur', 'underwrit', 'risk', 'casualti', 'continent']
# FREX WORDS: ['reinsur', 'underwrit', 'casualti', 'insur', 'cna', 'berkshir', 'continent', 'premium']
#
# TOPIC  5
# PROB WORDS: ['store', 'retail', 'merchandis', 'leas', 'open', 'center', 'squar', 'shop']
# FREX WORDS: ['store', 'merchandis', 'retail', 'shop', 'supermarket', 'safewai', 'food', 'jewel']
#
# TOPIC  6
# PROB WORDS: ['insur', 'life', 'risk', 'liabil', 'lnc', 'annuiti', 'reinsur', 'premium']
# FREX WORDS: ['lnc', 'reinsur', 'annuiti', 'aon', 'policyhold', 'insur', 'prudenti', 'mortal']
#
# TOPIC  7
# PROB WORDS: ['technolog', 'revenu', 'softwar', 'ncr', 'system', 'solut', 'commun', 'patent']
# FREX WORDS: ['ncr', 'softwar', 'intel', 'microsoft', 'technolog', 'lucent', 'server', 'patent']
#
# TOPIC  8
# PROB WORDS: ['carrier', 'transport', 'leas', 'truck', 'fuel', 'trailer', 'freight', 'revenu']
# FREX WORDS: ['carrier', 'truck', 'trailer', 'transport', 'freight', 'emerson', 'fedex', 'fuel']
#
# TOPIC  9
# PROB WORDS: ['environment', 'site', 'remedi', 'liabil', 'regul', 'respons', 'parti', 'wast']
# FREX WORDS: ['environment', 'remedi', 'cleanup', 'site', 'epa', 'prp', 'contamin', 'wast']
#
# TOPIC  10
# PROB WORDS: ['health', 'care', 'drug', 'pharmaci', 'hospit', 'medic', 'medicar', 'claim']
# FREX WORDS: ['drug', 'pharmaci', 'medicar', 'prescript', 'care', 'health', 'patient', 'hospit']
#
# TOPIC  11
# PROB WORDS: ['claim', 'settlement', 'liabil', 'insur', 'asbesto', 'litig', 'file', 'pend']
# FREX WORDS: ['claim', 'asbesto', 'settlement', 'asbestosrel', 'claimant', 'injuri', 'liabil', 'litig']
#
# TOPIC  12
# PROB WORDS: ['aluminum', 'metal', 'kaiser', 'alcoa', 'alloi', 'reynold', 'fabric', 'ton']
# FREX WORDS: ['aluminum', 'kaiser', 'metal', 'alcoa', 'reynold', 'alloi', 'ferro', 'alumina']
#
# TOPIC  13
# PROB WORDS: ['oil', 'ga', 'drill', 'field', 'crude', 'barrel', 'explor', 'well']
# FREX WORDS: ['oil', 'drill', 'ga', 'barrel', 'crude', 'well', 'refineri', 'petroleum']
#
# TOPIC  14
# PROB WORDS: ['patient', 'diseas', 'research', 'treatment', 'drug', 'clinic', 'medic', 'approv']
# FREX WORDS: ['patient', 'diseas', 'clinic', 'drug', 'therapi', 'baxter', 'cancer', 'blood']
#
# TOPIC  15
# PROB WORDS: ['steel', 'armco', 'furnac', 'iron', 'ton', 'or', 'stainless', 'roll']
# FREX WORDS: ['steel', 'armco', 'furnac', 'iron', 'stainless', 'bethlehem', 'ton', 'or']
#
# TOPIC  16
# PROB WORDS: ['electr', 'power', 'ga', 'util', 'nuclear', 'commiss', 'energi', 'station']
# FREX WORDS: ['electr', 'ga', 'nuclear', 'kilowatt', 'power', 'edison', 'westinghous', 'steam']
#
# TOPIC  17
# PROB WORDS: ['refineri', 'cement', 'oil', 'crude', 'gasolin', 'refin', 'tosco', 'lyondel']
# FREX WORDS: ['refineri', 'cement', 'crude', 'tosco', 'gasolin', 'lyondel', 'tesoro', 'arco']
#
# TOPIC  18
# PROB WORDS: ['shall', 'section', 'lender', 'agent', 'borrow', 'viacom', 'administr', 'termin']
# FREX WORDS: ['shall', 'viacom', 'lender', 'hereund', 'articl', 'section', 'hereof', 'landlord']
#
# TOPIC  19
# PROB WORDS: ['chemic', 'research', 'plastic', 'divis', 'resin', 'fiber', 'raw', 'specialti']
# FREX WORDS: ['chemic', 'resin', 'plastic', 'dow', 'fiber', 'polym', 'polyest', 'chlorin']
#
# TOPIC  20
# PROB WORDS: ['visteon', 'tire', 'automot', 'ford', 'vehicl', 'motor', 'car', 'rubber']
# FREX WORDS: ['visteon', 'tire', 'ford', 'automot', 'rubber', 'motor', 'vehicl', 'car']
#
# TOPIC  21
# PROB WORDS: ['insur', 'life', 'colleg', 'school', 'premium', 'policyhold', 'annuiti', 'individu']
# FREX WORDS: ['policyhold', 'insur', 'colleg', 'annuiti', 'life', 'school', 'mcgrawhil', 'mortal']
#
# TOPIC  22
# PROB WORDS: ['divis', 'research', 'field', 'electron', 'engin', 'system', 'laboratori', 'instrument']
# FREX WORDS: ['laboratori', 'electron', 'research', 'sperri', 'field', 'tube', 'divis', 'machin']
#
# TOPIC  23
# PROB WORDS: ['home', 'hous', 'land', 'mortgag', 'disnei', 'financ', 'commun', 'residenti']
# FREX WORDS: ['home', 'hous', 'disnei', 'homebuild', 'land', 'recreat', 'mortgag', 'builder']
#
# TOPIC  24
# PROB WORDS: ['kodak', 'film', 'gatx', 'imag', 'parker', 'polaroid', 'camera', 'photograph']
# FREX WORDS: ['kodak', 'gatx', 'film', 'polaroid', 'parker', 'imag', 'camera', 'cocacola']
#
# TOPIC  25
# PROB WORDS: ['research', 'drug', 'abbott', 'pharmaceut', 'laboratori', 'introduc', 'divis', 'medic']
# FREX WORDS: ['abbott', 'pharmaceut', 'drug', 'laboratori', 'antibiot', 'clinic', 'pfizer', 'research']
#
# TOPIC  26
# PROB WORDS: ['nuclear', 'fuel', 'power', 'energi', 'southern', 'percent', 'regulatori', 'revenu']
# FREX WORDS: ['nuclear', 'fuel', 'fpl', 'decommiss', 'psc', 'gulf', 'nrc', 'ferc']
#
# TOPIC  27
# PROB WORDS: ['network', 'sprint', 'commun', 'wireless', 'revenu', 'fcc', 'att', 'access']
# FREX WORDS: ['sprint', 'wireless', 'att', 'fcc', 'network', 'cabl', 'cellular', 'broadband']
#
# TOPIC  28
# PROB WORDS: ['action', 'alleg', 'file', 'court', 'defend', 'district', 'damag', 'complaint']
# FREX WORDS: ['alleg', 'complaint', 'plaintiff', 'defend', 'court', 'violat', 'district', 'injunct']
#
# TOPIC  29
# PROB WORDS: ['risk', 'trade', 'deriv', 'merril', 'transact', 'lynch', 'instrument', 'equiti']
# FREX WORDS: ['risk', 'merril', 'lynch', 'counterparti', 'ppl', 'client', 'instrument', 'trade']
#
# TOPIC  30
# PROB WORDS: ['nuclear', 'energi', 'electr', 'util', 'power', 'clp', 'regulatori', 'firstenergi']
# FREX WORDS: ['clp', 'nuclear', 'firstenergi', 'millston', 'wmeco', 'decommiss', 'psnh', 'gpu']
#
# TOPIC  31
# PROB WORDS: ['currenc', 'foreign', 'hedg', 'risk', 'exchang', 'instrument', 'deriv', 'transact']
# FREX WORDS: ['currenc', 'hedg', 'foreign', 'global', 'swap', 'instrument', 'risk', 'euro']
#
# TOPIC  32
# PROB WORDS: ['divis', 'glass', 'fabric', 'textil', 'plastic', 'fiber', 'finish', 'instal']
# FREX WORDS: ['glass', 'fabric', 'textil', 'carpet', 'plastic', 'fiber', 'yarn', 'burlington']
#
# TOPIC  33
# PROB WORDS: ['bank', 'york', 'trust', 'branch', 'street', 'deposit', 'depart', 'citi']
# FREX WORDS: ['bank', 'branch', 'midland', 'trust', 'manhattan', 'marin', 'york', 'chase']
#
# TOPIC  34
# PROB WORDS: ['loan', 'mortgag', 'risk', 'fair', 'deriv', 'hedg', 'instrument', 'commit']
# FREX WORDS: ['loan', 'mortgag', 'hedg', 'securit', 'risk', 'msr', 'citigroup', 'instrument']
#
# TOPIC  35
# PROB WORDS: ['presid', 'vice', 'execut', 'chairman', 'york', 'chief', 'divis', 'william']
# FREX WORDS: ['vice', 'presid', 'chairman', 'william', 'treasur', 'robert', 'execut', 'chief']
#
# TOPIC  36
# PROB WORDS: ['aircraft', 'airlin', 'air', 'passeng', 'rout', 'twa', 'jet', 'travel']
# FREX WORDS: ['aircraft', 'airlin', 'passeng', 'twa', 'rout', 'jet', 'flight', 'boe']
#
# TOPIC  37
# PROB WORDS: ['railroad', 'car', 'freight', 'commiss', 'traffic', 'transport', 'revenu', 'pacif']
# FREX WORDS: ['railroad', 'car', 'railwai', 'freight', 'traffic', 'interst', 'passeng', 'locomot']
#
# TOPIC  38
# PROB WORDS: ['debt', 'acquisit', 'borrow', 'right', 'revolv', 'convert', 'exercis', 'leas']
# FREX WORDS: ['revolv', 'debt', 'subordin', 'borrow', 'acquisit', 'coven', 'redeem', 'senior']
#
# TOPIC  39
# PROB WORDS: ['monsanto', 'grace', 'dec', 'seed', 'roundup', 'agricultur', 'biotechnolog', 'crop']
# FREX WORDS: ['monsanto', 'grace', 'dec', 'seed', 'roundup', 'bangor', 'punta', 'biotechnolog']
#
# TOPIC  40
# PROB WORDS: ['lhe', 'lor', 'tor', 'fmc', 'deer', 'thai', 'ih', 'arc']
# FREX WORDS: ['lhe', 'lor', 'fmc', 'deer', 'tor', 'thai', 'rale', 'ih']
#
# TOPIC  41
# PROB WORDS: ['food', 'consum', 'brand', 'meat', 'restaur', 'conagra', 'mill', 'frozen']
# FREX WORDS: ['food', 'meat', 'conagra', 'restaur', 'flour', 'beef', 'bakeri', 'snack']
#
# TOPIC  42
# PROB WORDS: ['telephon', 'bell', 'commun', 'cabl', 'western', 'electr', 'system', 'switch']
# FREX WORDS: ['telephon', 'bell', 'cabl', 'itt', 'dial', 'switch', 'wire', 'radio']
#
# TOPIC  43
# PROB WORDS: ['claim', 'court', 'bankruptci', 'corco', 'reorgan', 'chapter', 'file', 'proceed']
# FREX WORDS: ['corco', 'bankruptci', 'chapter', 'debtor', 'court', 'creditor', 'reorgan', 'asbesto']
#
# TOPIC  44
# PROB WORDS: ['risk', 'portfolio', 'bank', 'card', 'billion', 'loan', 'kei', 'swap']
# FREX WORDS: ['risk', 'portfolio', 'card', 'swap', 'securit', 'chase', 'chargeoff', 'client']
#
# TOPIC  45
# PROB WORDS: ['vehicl', 'dealership', 'rental', 'financ', 'acquisit', 'franchis', 'automot', 'revenu']
# FREX WORDS: ['dealership', 'vehicl', 'automot', 'pitnei', 'bow', 'lyon', 'meter', 'alco']
#
# TOPIC  46
# PROB WORDS: ['percent', 'sharehold', 'technolog', 'perform', 'strong', 'achiev', 'commit', 'competit']
# FREX WORDS: ['percent', 'strategi', 'technolog', 'peopl', 'innov', 'focu', 'global', 'worldwid']
#
# TOPIC  47
# PROB WORDS: ['ga', 'oil', 'pipelin', 'natur', 'occident', 'crude', 'partnership', 'partner']
# FREX WORDS: ['ga', 'pipelin', 'occident', 'crude', 'oil', 'pennzoil', 'ferc', 'barrel']
#
# TOPIC  48
# PROB WORDS: ['war', 'stockhold', 'problem', 'cent', 'countri', 'organ', 'public', 'depart']
# FREX WORDS: ['war', 'postwar', 'men', 'arc', 'cent', 'civilian', 'surplu', 'hope']
#
# TOPIC  49
# PROB WORDS: ['ashland', 'marathon', 'dresser', 'group', 'usx', 'terex', 'septemb', 'oil']
# FREX WORDS: ['ashland', 'marathon', 'dresser', 'usx', 'terex', 'kellogg', 'halliburton', 'arch']
#
# TOPIC  50
# PROB WORDS: ['court', 'appeal', 'case', 'tobacco', 'district', 'decis', 'damag', 'action']
# FREX WORDS: ['court', 'tobacco', 'appeal', 'cigarett', 'suprem', 'kraft', 'plaintiff', 'district']
#
# TOPIC  51
# PROB WORDS: ['energi', 'ga', 'electr', 'consum', 'cm', 'risk', 'power', 'transmiss']
# FREX WORDS: ['cm', 'ga', 'energi', 'mcv', 'electr', 'transmiss', 'mpsc', 'columbia']
#
# TOPIC  52
# PROB WORDS: ['store', 'retail', 'com', 'group', 'sear', 'brand', 'open', 'internet']
# FREX WORDS: ['store', 'sear', 'carmax', 'rite', 'internet', 'merchandis', 'tandi', 'depot']
#
# TOPIC  53
# PROB WORDS: ['aircraft', 'system', 'air', 'defens', 'missil', 'militari', 'navi', 'forc']
# FREX WORDS: ['aircraft', 'missil', 'navi', 'militari', 'defens', 'mdc', 'flight', 'armi']
#
# TOPIC  54
# PROB WORDS: ['pension', 'oblig', 'liabil', 'assumpt', 'recogn', 'defer', 'longterm', 'impact']
# FREX WORDS: ['pension', 'postretir', 'actuari', 'retire', 'assumpt', 'oblig', 'unrecogn', 'restructur']
#
# TOPIC  55
# PROB WORDS: ['client', 'billion', 'smith', 'risk', 'student', 'revenu', 'educ', 'global']
# FREX WORDS: ['client', 'smith', 'student', 'csc', 'barnei', 'salomon', 'gec', 'schwab']
#
# TOPIC  56
# PROB WORDS: ['die', 'cooper', 'farm', 'agricultur', 'corn', 'farmer', 'feed', 'agwai']
# FREX WORDS: ['die', 'farm', 'agwai', 'corn', 'farmer', 'cooper', 'feed', 'grain']
#
# TOPIC  57
# PROB WORDS: ['fiscal', 'septemb', 'june', 'stapl', 'mattel', 'juli', 'octob', 'inventori']
# FREX WORDS: ['fiscal', 'stapl', 'mattel', 'toi', 'septemb', 'tjx', 'sysco', 'june']
#
# TOPIC  58
# PROB WORDS: ['mine', 'copper', 'or', 'ton', 'gold', 'metal', 'lead', 'zinc']
# FREX WORDS: ['copper', 'mine', 'or', 'zinc', 'ton', 'gold', 'ounc', 'smelter']
#
# TOPIC  59
# PROB WORDS: ['system', 'ibm', 'technolog', 'inform', 'data', 'xerox', 'electron', 'digit']
# FREX WORDS: ['ibm', 'xerox', 'semiconductor', 'honeywel', 'gould', 'trw', 'copier', 'digit']
#
# TOPIC  60
# PROB WORDS: ['proxi', 'committe', 'vote', 'sharehold', 'stockhold', 'audit', 'independ', 'propos']
# FREX WORDS: ['committe', 'proxi', 'vote', 'nomine', 'dana', 'audit', 'pseg', 'auditor']
#
# TOPIC  61
# PROB WORDS: ['aircraft', 'hotel', 'airlin', 'leas', 'fuel', 'northwest', 'airwai', 'revenu']
# FREX WORDS: ['aircraft', 'airlin', 'hotel', 'airwai', 'northwest', 'resort', 'delta', 'flight']
#
# TOPIC  62
# PROB WORDS: ['sugar', 'crop', 'refin', 'ton', 'raw', 'export', 'puerto', 'agricultur']
# FREX WORDS: ['sugar', 'crop', 'cuban', 'banana', 'quota', 'cane', 'cotton', 'cuba']
#
# TOPIC  63
# PROB WORDS: ['televis', 'advertis', 'newspap', 'publish', 'station', 'broadcast', 'revenu', 'radio']
# FREX WORDS: ['televis', 'newspap', 'broadcast', 'advertis', 'cb', 'radio', 'film', 'magazin']
#
# TOPIC  64
# PROB WORDS: ['fair', 'sfa', 'impair', 'liabil', 'flow', 'risk', 'perform', 'impact']
# FREX WORDS: ['sfa', 'impair', 'goodwil', 'intang', 'longliv', 'fin', 'hedg', 'eitf']
#
# TOPIC  65
# PROB WORDS: ['prefer', 'stockhold', 'properti', 'excess', 'liabil', 'seri', 'debentur', 'payabl']
# FREX WORDS: ['surplu', 'prefer', 'sink', 'debentur', 'redempt', 'shall', 'par', 'refund']
#
# TOPIC  66
# PROB WORDS: ['paper', 'pulp', 'timber', 'forest', 'wood', 'lumber', 'machin', 'mill']
# FREX WORDS: ['pulp', 'paper', 'timber', 'forest', 'lumber', 'wood', 'plywood', 'paperboard']
#
# TOPIC  67
# PROB WORDS: ['brand', 'apparel', 'retail', 'divis', 'shoe', 'consum', 'women', 'whirlpool']
# FREX WORDS: ['apparel', 'shoe', 'whirlpool', 'brand', 'footwear', 'sportswear', 'fashion', 'cloth']
#
# TOPIC  68
# PROB WORDS: ['particip', 'grant', 'employ', 'retir', 'shall', 'exercis', 'award', 'compens']
# FREX WORDS: ['shall', 'employ', 'particip', 'bonu', 'committe', 'award', 'disabl', 'dell']
#
# TOPIC  69
# PROB WORDS: ['inflat', 'inventori', 'dollar', 'replac', 'percent', 'method', 'engin', 'leas']
# FREX WORDS: ['chrysler', 'inflat', 'cummin', 'inventori', 'monetari', 'lifo', 'recess', 'engin']

# %% [markdown]
# # Topics over time

# %% [markdown]
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html
# ##https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (36479, 70)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['Filename']]
topic_document_distribution['Filename'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["Filename", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "Filename", "topic"])
print(dtm.head())
# Out:
#             Filename  Year topic        weight
# 21217   88178299.xml  1930     0  0.0003058104
# 57696   88178299.xml  1930     1  0.0003058104
# 94175   88178299.xml  1930     2  0.0003058104
# 130654  88178299.xml  1930     3  0.0003058104
# 167133  88178299.xml  1930     4  0.0003058104

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#        Filename  Year topic        weight                           keywords
# 0  88178299.xml  1930     0  0.0003058104  divis engin tool machin truck air
# 1  88178309.xml  1930     0  0.0002967359  divis engin tool machin truck air
# 2  88178340.xml  1930     0  0.0001044932  divis engin tool machin truck air
# 3  88178352.xml  1930     0  0.0010309278  divis engin tool machin truck air
# 4  88178376.xml  1930     0  0.0011494253  divis engin tool machin truck air

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9979322744980523
# Min: 1.890370353995673e-07
# Average: 0.014285714285708786
# Median: 2.668801708033095e-05
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['Filename'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.set_xticklabels(rotation=45)
    n = 5  # Keeps every 5th label
    [l.set_visible(False) for (i,l) in enumerate(p.ax.xaxis.get_ticklabels()) if i % n != 0]
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
