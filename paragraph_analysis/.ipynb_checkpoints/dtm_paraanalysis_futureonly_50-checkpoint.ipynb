# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Set topic number

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic_para_futonly_50.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 50

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/bow_corpus.pkl', 'rb') )

# %% [markdown]
# ### IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# ### extract term-topic matrix (note this will be over all the time slices)

# %% [markdown]
# # get_topics for DTM
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %% [markdown]
# ## Frex output

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['account', 'sfa', 'effect', 'adopt', 'result', 'pro', 'statement', 'forma']
# FREX WORDS: ['sfa', 'adopt', 'account', 'pro', 'forma', 'statement', 'fasb', 'method']
#
# TOPIC  1
# PROB WORDS: ['year', 'industri', 'nation', 'time', 'busi', 'problem', 'peopl', 'import']
# FREX WORDS: ['peopl', 'problem', 'todai', 'nation', 'confid', 'look', 'war', 'world']
#
# TOPIC  2
# PROB WORDS: ['share', 'stock', 'dividend', 'common', 'prefer', 'earn', 'cash', 'board']
# FREX WORDS: ['stock', 'share', 'dividend', 'common', 'prefer', 'director', 'board', 'declar']
#
# TOPIC  3
# PROB WORDS: ['invest', 'secur', 'equiti', 'receiv', 'valu', 'market', 'interest', 'retain']
# FREX WORDS: ['invest', 'secur', 'equiti', 'securit', 'interest', 'valu', 'matur', 'portfolio']
#
# TOPIC  4
# PROB WORDS: ['million', 'approxim', 'decemb', 'billion', 'total', 'respect', 'year', 'end']
# FREX WORDS: ['million', 'billion', 'approxim', 'decemb', 'total', 'respect', 'end', 'registr']
#
# TOPIC  5
# PROB WORDS: ['increas', 'cost', 'price', 'continu', 'year', 'level', 'improv', 'higher']
# FREX WORDS: ['price', 'increas', 'improv', 'higher', 'cost', 'inflat', 'declin', 'lower']
#
# TOPIC  6
# PROB WORDS: ['claim', 'settlement', 'court', 'asbesto', 'file', 'case', 'bankruptci', 'pend']
# FREX WORDS: ['claim', 'asbesto', 'court', 'settlement', 'file', 'asbestosrel', 'bankruptci', 'injuri']
#
# TOPIC  7
# PROB WORDS: ['store', 'bank', 'retail', 'open', 'new', 'merchandis', 'center', 'distribut']
# FREX WORDS: ['store', 'bank', 'retail', 'merchandis', 'open', 'center', 'branch', 'offic']
#
# TOPIC  8
# PROB WORDS: ['contract', 'inventori', 'price', 'purchas', 'sale', 'product', 'cost', 'market']
# FREX WORDS: ['contract', 'inventori', 'price', 'purchas', 'sale', 'product', 'backlog', 'deliveri']
#
# TOPIC  9
# PROB WORDS: ['net', 'loss', 'million', 'incom', 'gain', 'result', 'increas', 'expens']
# FREX WORDS: ['million', 'loss', 'gain', 'net', 'incom', 'decreas', 'expens', 'charg']
#
# TOPIC  10
# PROB WORDS: ['option', 'stock', 'share', 'plan', 'grant', 'exercis', 'award', 'compens']
# FREX WORDS: ['option', 'stock', 'grant', 'share', 'exercis', 'award', 'plan', 'common']
#
# TOPIC  11
# PROB WORDS: ['energi', 'electr', 'power', 'util', 'fuel', 'gener', 'regulatori', 'nuclear']
# FREX WORDS: ['energi', 'electr', 'power', 'fuel', 'nuclear', 'ga', 'regulatori', 'custom']
#
# TOPIC  12
# PROB WORDS: ['revenu', 'sale', 'fiscal', 'quarter', 'custom', 'servic', 'product', 'gross']
# FREX WORDS: ['fiscal', 'revenu', 'sale', 'quarter', 'custom', 'fourth', 'margin', 'gross']
#
# TOPIC  13
# PROB WORDS: ['growth', 'year', 'new', 'product', 'continu', 'market', 'develop', 'sale']
# FREX WORDS: ['growth', 'research', 'product', 'improv', 'profit', 'expans', 'develop', 'sale']
#
# TOPIC  14
# PROB WORDS: ['hedg', 'risk', 'rate', 'currenc', 'contract', 'foreign', 'instrument', 'deriv']
# FREX WORDS: ['hedg', 'currenc', 'instrument', 'risk', 'deriv', 'exchang', 'contract', 'swap']
#
# TOPIC  15
# PROB WORDS: ['ga', 'oil', 'natur', 'product', 'pipelin', 'crude', 'drill', 'explor']
# FREX WORDS: ['ga', 'oil', 'pipelin', 'crude', 'drill', 'natur', 'well', 'petroleum']
#
# TOPIC  16
# PROB WORDS: ['busi', 'custom', 'growth', 'continu', 'market', 'servic', 'opportun', 'posit']
# FREX WORDS: ['custom', 'growth', 'strong', 'peopl', 'opportun', 'sharehold', 'success', 'focu']
#
# TOPIC  17
# PROB WORDS: ['tax', 'credit', 'loss', 'carryforward', 'incom', 'oper', 'expir', 'avail']
# FREX WORDS: ['tax', 'credit', 'carryforward', 'loss', 'expir', 'incom', 'offset', 'taxabl']
#
# TOPIC  18
# PROB WORDS: ['benefit', 'plan', 'pension', 'employe', 'retir', 'cost', 'servic', 'oblig']
# FREX WORDS: ['benefit', 'pension', 'plan', 'employe', 'retir', 'postretir', 'care', 'health']
#
# TOPIC  19
# PROB WORDS: ['servic', 'network', 'licens', 'commun', 'advertis', 'televis', 'cabl', 'program']
# FREX WORDS: ['network', 'licens', 'televis', 'commun', 'cabl', 'advertis', 'digit', 'internet']
#
# TOPIC  20
# PROB WORDS: ['tax', 'incom', 'defer', 'liabil', 'earn', 'differ', 'feder', 'provis']
# FREX WORDS: ['tax', 'incom', 'defer', 'liabil', 'feder', 'statement', 'deduct', 'differ']
#
# TOPIC  21
# PROB WORDS: ['environment', 'cost', 'regul', 'site', 'remedi', 'law', 'oper', 'requir']
# FREX WORDS: ['environment', 'site', 'remedi', 'regul', 'law', 'complianc', 'cost', 'wast']
#
# TOPIC  22
# PROB WORDS: ['agreement', 'payment', 'guarante', 'credit', 'note', 'certain', 'facil', 'oblig']
# FREX WORDS: ['agreement', 'guarante', 'credit', 'senior', 'payment', 'facil', 'oblig', 'note']
#
# TOPIC  23
# PROB WORDS: ['leas', 'minimum', 'payment', 'oper', 'rental', 'commit', 'oblig', 'equip']
# FREX WORDS: ['leas', 'minimum', 'rental', 'payment', 'oblig', 'noncancel', 'subleas', 'commit']
#
# TOPIC  24
# PROB WORDS: ['materi', 'matter', 'result', 'advers', 'financi', 'effect', 'oper', 'claim']
# FREX WORDS: ['matter', 'advers', 'litig', 'claim', 'outcom', 'proceed', 'materi', 'legal']
#
# TOPIC  25
# PROB WORDS: ['rate', 'return', 'asset', 'expect', 'increas', 'assumpt', 'percent', 'discount']
# FREX WORDS: ['rate', 'return', 'assumpt', 'discount', 'asset', 'pension', 'percent', 'averag']
#
# TOPIC  26
# PROB WORDS: ['product', 'new', 'manufactur', 'market', 'industri', 'equip', 'line', 'sale']
# FREX WORDS: ['product', 'manufactur', 'chemic', 'equip', 'divis', 'automot', 'plant', 'machin']
#
# TOPIC  27
# PROB WORDS: ['estim', 'financi', 'liabil', 'statement', 'manag', 'base', 'result', 'chang']
# FREX WORDS: ['estim', 'statement', 'financi', 'assumpt', 'liabil', 'actual', 'judgment', 'inform']
#
# TOPIC  28
# PROB WORDS: ['insur', 'life', 'fund', 'polici', 'reserv', 'policyhold', 'invest', 'payment']
# FREX WORDS: ['insur', 'life', 'fund', 'policyhold', 'surplu', 'agent', 'dividend', 'annuiti']
#
# TOPIC  29
# PROB WORDS: ['statement', 'forwardlook', 'result', 'report', 'includ', 'expect', 'factor', 'risk']
# FREX WORDS: ['statement', 'forwardlook', 'risk', 'secur', 'uncertainti', 'factor', 'actual', 'report']
#
# TOPIC  30
# PROB WORDS: ['reserv', 'ga', 'estim', 'oil', 'prove', 'net', 'price', 'product']
# FREX WORDS: ['reserv', 'ga', 'oil', 'prove', 'estim', 'price', 'flow', 'discount']
#
# TOPIC  31
# PROB WORDS: ['cost', 'amort', 'properti', 'depreci', 'expens', 'equip', 'asset', 'period']
# FREX WORDS: ['cost', 'amort', 'depreci', 'properti', 'equip', 'straightlin', 'expens', 'live']
#
# TOPIC  32
# PROB WORDS: ['acquisit', 'busi', 'acquir', 'oper', 'segment', 'purchas', 'merger', 'includ']
# FREX WORDS: ['acquisit', 'acquir', 'busi', 'merger', 'segment', 'integr', 'transact', 'strateg']
#
# TOPIC  33
# PROB WORDS: ['food', 'mine', 'product', 'unit', 'canada', 'oper', 'copper', 'mexico']
# FREX WORDS: ['mine', 'food', 'copper', 'corn', 'mexico', 'canada', 'feed', 'mattel']
#
# TOPIC  34
# PROB WORDS: ['ventur', 'joint', 'america', 'north', 'paper', 'europ', 'forest', 'timber']
# FREX WORDS: ['ventur', 'joint', 'america', 'paper', 'north', 'europ', 'merck', 'forest']
#
# TOPIC  35
# PROB WORDS: ['manag', 'offic', 'execut', 'presid', 'board', 'director', 'employe', 'corpor']
# FREX WORDS: ['presid', 'offic', 'execut', 'director', 'board', 'employe', 'chairman', 'chief']
#
# TOPIC  36
# PROB WORDS: ['debt', 'cash', 'financ', 'fund', 'capit', 'flow', 'oper', 'credit']
# FREX WORDS: ['debt', 'cash', 'financ', 'fund', 'flow', 'borrow', 'capit', 'credit']
#
# TOPIC  37
# PROB WORDS: ['insur', 'polici', 'claim', 'liabil', 'premium', 'reserv', 'loss', 'life']
# FREX WORDS: ['insur', 'claim', 'premium', 'polici', 'loss', 'reinsur', 'coverag', 'reserv']
#
# TOPIC  38
# PROB WORDS: ['loan', 'mortgag', 'loss', 'real', 'estat', 'receiv', 'credit', 'servic']
# FREX WORDS: ['loan', 'mortgag', 'estat', 'real', 'loss', 'credit', 'portfolio', 'hospit']
#
# TOPIC  39
# PROB WORDS: ['aircraft', 'partnership', 'airlin', 'air', 'continent', 'unit', 'transport', 'boe']
# FREX WORDS: ['aircraft', 'partnership', 'airlin', 'continent', 'air', 'boe', 'passeng', 'travel']
#
# TOPIC  40
# PROB WORDS: ['steel', 'materi', 'coal', 'raw', 'suppli', 'ton', 'aluminum', 'metal']
# FREX WORDS: ['steel', 'coal', 'raw', 'materi', 'ton', 'mohawk', 'suppli', 'aluminum']
#
# TOPIC  41
# PROB WORDS: ['oper', 'result', 'chang', 'affect', 'market', 'busi', 'condit', 'advers']
# FREX WORDS: ['advers', 'affect', 'abil', 'competit', 'factor', 'risk', 'condit', 'impact']
#
# TOPIC  42
# PROB WORDS: ['new', 'plant', 'oper', 'build', 'citi', 'construct', 'facil', 'servic']
# FREX WORDS: ['citi', 'railroad', 'land', 'plant', 'construct', 'build', 'car', 'california']
#
# TOPIC  43
# PROB WORDS: ['defer', 'asset', 'tax', 'allow', 'valuat', 'realiz', 'incom', 'net']
# FREX WORDS: ['tax', 'defer', 'valuat', 'asset', 'allow', 'realiz', 'taxabl', 'incom']
#
# TOPIC  44
# PROB WORDS: ['year', 'end', 'earn', 'reserv', 'decemb', 'net', 'balanc', 'total']
# FREX WORDS: ['year', 'end', 'reserv', 'cent', 'charg', 'earn', 'profit', 'incom']
#
# TOPIC  45
# PROB WORDS: ['capit', 'expenditur', 'facil', 'project', 'requir', 'construct', 'capac', 'invest']
# FREX WORDS: ['capit', 'expenditur', 'facil', 'construct', 'capac', 'spend', 'project', 'expans']
#
# TOPIC  46
# PROB WORDS: ['cost', 'charg', 'restructur', 'relat', 'record', 'associ', 'facil', 'close']
# FREX WORDS: ['cost', 'charg', 'restructur', 'decommiss', 'quarter', 'exit', 'facil', 'asset']
#
# TOPIC  47
# PROB WORDS: ['develop', 'research', 'system', 'technolog', 'engin', 'program', 'product', 'new']
# FREX WORDS: ['research', 'system', 'engin', 'develop', 'technolog', 'electron', 'defens', 'laboratori']
#
# TOPIC  48
# PROB WORDS: ['valu', 'asset', 'impair', 'fair', 'cash', 'flow', 'estim', 'carri']
# FREX WORDS: ['impair', 'valu', 'fair', 'asset', 'flow', 'goodwil', 'cash', 'carri']
#
# TOPIC  49
# PROB WORDS: ['fund', 'trust', 'bond', 'debentur', 'convert', 'note', 'requir', 'princip']
# FREX WORDS: ['trust', 'fund', 'bond', 'debentur', 'subordin', 'redempt', 'sink', 'convert']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %%
#https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/
#https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/

# %% [markdown]
# # Topics over time
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts_paragraphs_futureonly/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect_paragraphs_futureonly.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")
metadata['paragraph_filetime']= metadata['Filename'].str.replace(".xml", "") + "_P" + metadata['Paragraph'].astype(str) + ".txt"

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (149145, 50)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['paragraph_filetime']]
topic_document_distribution['paragraph_filetime'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution_parafutureonly.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["paragraph_filetime", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "paragraph_filetime", "topic"])
print(dtm.head())
# Out:
#        paragraph_filetime  Year topic        weight
# 120113    88178377_P0.txt  1930     0  0.0002197802
# 269258    88178377_P0.txt  1930     1  0.1942724751
# 418403    88178377_P0.txt  1930     2  0.0002197802
# 567548    88178377_P0.txt  1930     3  0.0002197802
# 716693    88178377_P0.txt  1930     4  0.0002197802

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#   paragraph_filetime  Year topic        weight  \
# 0    88178377_P0.txt  1930     0  0.0002197802
# 1    88178441_P0.txt  1930     0  0.0001081081
# 2    88178441_P1.txt  1930     0  0.0000956938
# 3    88178441_P2.txt  1930     0  0.0001360544
# 4    88178460_P0.txt  1930     0  0.0002150538
#
#                               keywords
# 0  account sfa effect adopt result pro
# 1  account sfa effect adopt result pro
# 2  account sfa effect adopt result pro
# 3  account sfa effect adopt result pro
# 4  account sfa effect adopt result pro

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9991335101679931
# Min: 1.2944983818770225e-05
# Average: 0.019999999999904504
# Median: 0.00017391304347826088
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['paragraph_filetime'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.set_xticklabels(rotation=45)
    n = 5  # Keeps every 5th label
    [l.set_visible(False) for (i,l) in enumerate(p.ax.xaxis.get_ticklabels()) if i % n != 0]
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
