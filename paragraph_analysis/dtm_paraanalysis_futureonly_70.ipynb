# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Set topic number

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic_para_futonly_70.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 70

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/bow_corpus.pkl', 'rb') )

# %% [markdown]
# ### IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# ### extract term-topic matrix (note this will be over all the time slices)

# %% [markdown]
# # get_topics for DTM
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %% [markdown]
# ## Frex output

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['care', 'health', 'medic', 'product', 'hospit', 'drug', 'pharmaceut', 'medicar']
# FREX WORDS: ['care', 'health', 'medic', 'drug', 'hospit', 'merck', 'pharmaceut', 'medicar']
#
# TOPIC  1
# PROB WORDS: ['plan', 'employe', 'benefit', 'retir', 'contribut', 'fund', 'servic', 'pension']
# FREX WORDS: ['employe', 'retir', 'benefit', 'plan', 'contribut', 'pension', 'fund', 'elig']
#
# TOPIC  2
# PROB WORDS: ['tax', 'defer', 'asset', 'incom', 'realiz', 'valuat', 'allow', 'liabil']
# FREX WORDS: ['tax', 'defer', 'asset', 'incom', 'valuat', 'allow', 'realiz', 'taxabl']
#
# TOPIC  3
# PROB WORDS: ['acquisit', 'acquir', 'result', 'pro', 'forma', 'oper', 'purchas', 'merger']
# FREX WORDS: ['acquisit', 'acquir', 'pro', 'forma', 'merger', 'purchas', 'unaudit', 'alloc']
#
# TOPIC  4
# PROB WORDS: ['million', 'approxim', 'decemb', 'total', 'respect', 'year', 'end', 'includ']
# FREX WORDS: ['million', 'approxim', 'decemb', 'total', 'respect', 'net', 'end', 'pretax']
#
# TOPIC  5
# PROB WORDS: ['sale', 'product', 'inventori', 'custom', 'revenu', 'cost', 'servic', 'order']
# FREX WORDS: ['sale', 'inventori', 'custom', 'product', 'revenu', 'backlog', 'order', 'vendor']
#
# TOPIC  6
# PROB WORDS: ['rate', 'debt', 'swap', 'fix', 'chang', 'variabl', 'dominion', 'increas']
# FREX WORDS: ['rate', 'dominion', 'debt', 'swap', 'variabl', 'fix', 'fixedr', 'float']
#
# TOPIC  7
# PROB WORDS: ['develop', 'product', 'research', 'new', 'technolog', 'engin', 'process', 'advanc']
# FREX WORDS: ['research', 'develop', 'product', 'technolog', 'engin', 'new', 'system', 'electron']
#
# TOPIC  8
# PROB WORDS: ['busi', 'market', 'growth', 'servic', 'custom', 'continu', 'opportun', 'invest']
# FREX WORDS: ['growth', 'custom', 'busi', 'strateg', 'opportun', 'strategi', 'focu', 'technolog']
#
# TOPIC  9
# PROB WORDS: ['increas', 'cost', 'result', 'oper', 'expens', 'profit', 'reduc', 'lower']
# FREX WORDS: ['increas', 'margin', 'decreas', 'cost', 'lower', 'higher', 'profit', 'reduct']
#
# TOPIC  10
# PROB WORDS: ['statement', 'forwardlook', 'result', 'includ', 'factor', 'expect', 'risk', 'report']
# FREX WORDS: ['statement', 'forwardlook', 'risk', 'factor', 'uncertainti', 'actual', 'express', 'word']
#
# TOPIC  11
# PROB WORDS: ['insur', 'polici', 'life', 'premium', 'benefit', 'policyhold', 'reserv', 'annuiti']
# FREX WORDS: ['insur', 'life', 'polici', 'premium', 'benefit', 'policyhold', 'annuiti', 'contract']
#
# TOPIC  12
# PROB WORDS: ['claim', 'insur', 'liabil', 'loss', 'reserv', 'estim', 'cost', 'coverag']
# FREX WORDS: ['claim', 'insur', 'loss', 'reserv', 'liabil', 'estim', 'coverag', 'asbesto']
#
# TOPIC  13
# PROB WORDS: ['dividend', 'earn', 'cash', 'paid', 'share', 'stock', 'board', 'common']
# FREX WORDS: ['dividend', 'stock', 'board', 'director', 'common', 'paid', 'share', 'declar']
#
# TOPIC  14
# PROB WORDS: ['regul', 'law', 'environment', 'requir', 'complianc', 'oper', 'state', 'legisl']
# FREX WORDS: ['regul', 'environment', 'law', 'complianc', 'legisl', 'feder', 'emiss', 'compli']
#
# TOPIC  15
# PROB WORDS: ['valu', 'fair', 'market', 'estim', 'cash', 'base', 'discount', 'flow']
# FREX WORDS: ['valu', 'fair', 'estim', 'discount', 'flow', 'cash', 'rate', 'market']
#
# TOPIC  16
# PROB WORDS: ['plant', 'product', 'new', 'manufactur', 'facil', 'divis', 'oper', 'chemic']
# FREX WORDS: ['plant', 'product', 'divis', 'chemic', 'manufactur', 'facil', 'capac', 'expans']
#
# TOPIC  17
# PROB WORDS: ['agreement', 'right', 'licens', 'patent', 'negoti', 'term', 'enter', 'certain']
# FREX WORDS: ['agreement', 'licens', 'right', 'patent', 'negoti', 'royalti', 'enter', 'agre']
#
# TOPIC  18
# PROB WORDS: ['program', 'train', 'system', 'develop', 'defens', 'space', 'manag', 'personnel']
# FREX WORDS: ['program', 'train', 'defens', 'system', 'space', 'personnel', 'missil', 'forc']
#
# TOPIC  19
# PROB WORDS: ['option', 'share', 'grant', 'stock', 'plan', 'exercis', 'price', 'date']
# FREX WORDS: ['option', 'grant', 'stock', 'share', 'exercis', 'common', 'price', 'employe']
#
# TOPIC  20
# PROB WORDS: ['manag', 'year', 'continu', 'employe', 'success', 'confid', 'peopl', 'sharehold']
# FREX WORDS: ['employe', 'confid', 'peopl', 'success', 'challeng', 'sharehold', 'team', 'look']
#
# TOPIC  21
# PROB WORDS: ['year', 'growth', 'continu', 'market', 'increas', 'sale', 'new', 'earn']
# FREX WORDS: ['growth', 'improv', 'sale', 'strong', 'profit', 'market', 'earn', 'grow']
#
# TOPIC  22
# PROB WORDS: ['contract', 'purchas', 'price', 'commit', 'commod', 'forward', 'enter', 'sale']
# FREX WORDS: ['contract', 'price', 'purchas', 'commod', 'commit', 'ga', 'forward', 'swap']
#
# TOPIC  23
# PROB WORDS: ['aircraft', 'air', 'airlin', 'commerci', 'continent', 'boe', 'transport', 'travel']
# FREX WORDS: ['aircraft', 'airlin', 'air', 'continent', 'boe', 'jet', 'passeng', 'travel']
#
# TOPIC  24
# PROB WORDS: ['court', 'order', 'commiss', 'propos', 'file', 'decis', 'approv', 'issu']
# FREX WORDS: ['court', 'commiss', 'propos', 'file', 'district', 'order', 'appeal', 'approv']
#
# TOPIC  25
# PROB WORDS: ['energi', 'power', 'electr', 'fuel', 'gener', 'ga', 'plant', 'util']
# FREX WORDS: ['energi', 'power', 'electr', 'fuel', 'ga', 'plant', 'transmiss', 'nuclear']
#
# TOPIC  26
# PROB WORDS: ['offic', 'board', 'execut', 'presid', 'director', 'chairman', 'chief', 'vice']
# FREX WORDS: ['offic', 'presid', 'board', 'execut', 'director', 'chairman', 'chief', 'vice']
#
# TOPIC  27
# PROB WORDS: ['claim', 'bankruptci', 'asbesto', 'trust', 'reorgan', 'plan', 'corn', 'settlement']
# FREX WORDS: ['bankruptci', 'claim', 'asbesto', 'trust', 'reorgan', 'corn', 'claimant', 'settlement']
#
# TOPIC  28
# PROB WORDS: ['net', 'fiscal', 'loss', 'year', 'gain', 'incom', 'earn', 'end']
# FREX WORDS: ['fiscal', 'loss', 'net', 'gain', 'ventur', 'incom', 'joint', 'share']
#
# TOPIC  29
# PROB WORDS: ['loan', 'bank', 'mortgag', 'loss', 'real', 'estat', 'reserv', 'credit']
# FREX WORDS: ['loan', 'bank', 'mortgag', 'estat', 'real', 'loss', 'reserv', 'credit']
#
# TOPIC  30
# PROB WORDS: ['claim', 'litig', 'matter', 'proceed', 'settlement', 'legal', 'pend', 'action']
# FREX WORDS: ['claim', 'litig', 'proceed', 'defend', 'matter', 'pend', 'lawsuit', 'settlement']
#
# TOPIC  31
# PROB WORDS: ['dispos', 'wast', 'water', 'oper', 'facil', 'hazard', 'environment', 'landfil']
# FREX WORDS: ['dispos', 'wast', 'water', 'closur', 'hazard', 'environment', 'landfil', 'facil']
#
# TOPIC  32
# PROB WORDS: ['leas', 'minimum', 'payment', 'oper', 'rental', 'year', 'equip', 'term']
# FREX WORDS: ['leas', 'minimum', 'rental', 'payment', 'noncancel', 'subleas', 'equip', 'capit']
#
# TOPIC  33
# PROB WORDS: ['build', 'center', 'die', 'advertis', 'construct', 'offic', 'facil', 'squar']
# FREX WORDS: ['build', 'center', 'die', 'advertis', 'squar', 'offic', 'construct', 'space']
#
# TOPIC  34
# PROB WORDS: ['reserv', 'ga', 'oil', 'prove', 'estim', 'cost', 'net', 'product']
# FREX WORDS: ['reserv', 'ga', 'oil', 'prove', 'estim', 'price', 'net', 'flow']
#
# TOPIC  35
# PROB WORDS: ['food', 'product', 'consum', 'brand', 'market', 'packag', 'sale', 'new']
# FREX WORDS: ['food', 'consum', 'brand', 'product', 'packag', 'feed', 'restaur', 'beverag']
#
# TOPIC  36
# PROB WORDS: ['financi', 'statement', 'report', 'discuss', 'consolid', 'oper', 'note', 'result']
# FREX WORDS: ['financi', 'statement', 'discuss', 'consolid', 'note', 'report', 'analysi', 'inform']
#
# TOPIC  37
# PROB WORDS: ['home', 'televis', 'paper', 'cabl', 'commun', 'network', 'digit', 'program']
# FREX WORDS: ['televis', 'home', 'cabl', 'paper', 'network', 'digit', 'broadcast', 'commun']
#
# TOPIC  38
# PROB WORDS: ['tax', 'incom', 'credit', 'feder', 'year', 'purpos', 'earn', 'loss']
# FREX WORDS: ['tax', 'incom', 'credit', 'feder', 'carryforward', 'foreign', 'defer', 'deduct']
#
# TOPIC  39
# PROB WORDS: ['price', 'product', 'demand', 'market', 'suppli', 'industri', 'cost', 'materi']
# FREX WORDS: ['price', 'demand', 'suppli', 'raw', 'product', 'market', 'inflat', 'competit']
#
# TOPIC  40
# PROB WORDS: ['cost', 'regulatori', 'rate', 'util', 'recoveri', 'recov', 'custom', 'nuclear']
# FREX WORDS: ['regulatori', 'rate', 'decommiss', 'cost', 'nuclear', 'recov', 'recoveri', 'fuel']
#
# TOPIC  41
# PROB WORDS: ['oblig', 'guarante', 'payment', 'liabil', 'certain', 'conting', 'requir', 'agreement']
# FREX WORDS: ['oblig', 'guarante', 'payment', 'liabil', 'agreement', 'conting', 'contractu', 'arrang']
#
# TOPIC  42
# PROB WORDS: ['benefit', 'plan', 'pension', 'rate', 'cost', 'oblig', 'increas', 'actuari']
# FREX WORDS: ['benefit', 'pension', 'rate', 'postretir', 'plan', 'oblig', 'actuari', 'assumpt']
#
# TOPIC  43
# PROB WORDS: ['year', 'present', 'time', 'problem', 'possibl', 'busi', 'new', 'larg']
# FREX WORDS: ['problem', 'war', 'hope', 'monei', 'year', 'stockhold', 'arc', 'figur']
#
# TOPIC  44
# PROB WORDS: ['peopl', 'help', 'world', 'todai', 'need', 'wai', 'commun', 'work']
# FREX WORDS: ['peopl', 'help', 'todai', 'world', 'wai', 'know', 'educ', 'live']
#
# TOPIC  45
# PROB WORDS: ['servic', 'new', 'citi', 'railroad', 'york', 'california', 'transport', 'oper']
# FREX WORDS: ['citi', 'railroad', 'york', 'servic', 'california', 'transport', 'car', 'southern']
#
# TOPIC  46
# PROB WORDS: ['state', 'unit', 'govern', 'nation', 'countri', 'corpor', 'feder', 'public']
# FREX WORDS: ['govern', 'state', 'unit', 'nation', 'countri', 'feder', 'export', 'congress']
#
# TOPIC  47
# PROB WORDS: ['product', 'manufactur', 'vehicl', 'automot', 'system', 'equip', 'machin', 'motor']
# FREX WORDS: ['vehicl', 'automot', 'system', 'machin', 'motor', 'manufactur', 'truck', 'car']
#
# TOPIC  48
# PROB WORDS: ['oil', 'ga', 'natur', 'pipelin', 'product', 'crude', 'drill', 'explor']
# FREX WORDS: ['oil', 'ga', 'pipelin', 'crude', 'drill', 'explor', 'well', 'petroleum']
#
# TOPIC  49
# PROB WORDS: ['billion', 'secur', 'debt', 'invest', 'equiti', 'longterm', 'matur', 'bond']
# FREX WORDS: ['billion', 'debt', 'secur', 'invest', 'equiti', 'matur', 'bond', 'longterm']
#
# TOPIC  50
# PROB WORDS: ['charg', 'quarter', 'cost', 'relat', 'restructur', 'record', 'fourth', 'million']
# FREX WORDS: ['quarter', 'charg', 'restructur', 'fourth', 'million', 'cost', 'exit', 'record']
#
# TOPIC  51
# PROB WORDS: ['sfa', 'adopt', 'account', 'control', 'effect', 'financi', 'report', 'issu']
# FREX WORDS: ['sfa', 'adopt', 'control', 'account', 'statement', 'fasb', 'procedur', 'report']
#
# TOPIC  52
# PROB WORDS: ['cash', 'financ', 'credit', 'fund', 'flow', 'oper', 'requir', 'capit']
# FREX WORDS: ['financ', 'cash', 'credit', 'fund', 'flow', 'capit', 'borrow', 'debt']
#
# TOPIC  53
# PROB WORDS: ['plan', 'compens', 'award', 'incent', 'stock', 'restrict', 'unit', 'number']
# FREX WORDS: ['award', 'compens', 'incent', 'plan', 'stock', 'restrict', 'vest', 'equiti']
#
# TOPIC  54
# PROB WORDS: ['note', 'senior', 'debt', 'credit', 'facil', 'subordin', 'debentur', 'princip']
# FREX WORDS: ['note', 'senior', 'debt', 'subordin', 'indebted', 'credit', 'debentur', 'coven']
#
# TOPIC  55
# PROB WORDS: ['risk', 'market', 'manag', 'instrument', 'deriv', 'trade', 'exposur', 'chang']
# FREX WORDS: ['risk', 'instrument', 'deriv', 'market', 'exposur', 'trade', 'manag', 'portfolio']
#
# TOPIC  56
# PROB WORDS: ['foreign', 'currenc', 'hedg', 'exchang', 'cash', 'flow', 'dollar', 'deriv']
# FREX WORDS: ['foreign', 'currenc', 'hedg', 'exchang', 'flow', 'deriv', 'cash', 'dollar']
#
# TOPIC  57
# PROB WORDS: ['return', 'percent', 'rate', 'asset', 'expect', 'invest', 'averag', 'longterm']
# FREX WORDS: ['percent', 'return', 'rate', 'asset', 'averag', 'invest', 'longterm', 'weight']
#
# TOPIC  58
# PROB WORDS: ['receiv', 'allow', 'collect', 'account', 'custom', 'occident', 'credit', 'doubt']
# FREX WORDS: ['receiv', 'allow', 'collect', 'occident', 'account', 'doubt', 'custom', 'credit']
#
# TOPIC  59
# PROB WORDS: ['store', 'retail', 'close', 'open', 'union', 'merchandis', 'new', 'sale']
# FREX WORDS: ['store', 'retail', 'union', 'merchandis', 'carbid', 'close', 'open', 'shop']
#
# TOPIC  60
# PROB WORDS: ['asset', 'impair', 'valu', 'cash', 'flow', 'carri', 'goodwil', 'fair']
# FREX WORDS: ['impair', 'asset', 'valu', 'goodwil', 'flow', 'fair', 'cash', 'intang']
#
# TOPIC  61
# PROB WORDS: ['steel', 'coal', 'mine', 'metal', 'ton', 'or', 'copper', 'oper']
# FREX WORDS: ['steel', 'mine', 'coal', 'metal', 'ton', 'copper', 'or', 'miner']
#
# TOPIC  62
# PROB WORDS: ['estim', 'assumpt', 'base', 'actual', 'chang', 'manag', 'differ', 'requir']
# FREX WORDS: ['estim', 'assumpt', 'actual', 'judgment', 'differ', 'factor', 'chang', 'base']
#
# TOPIC  63
# PROB WORDS: ['oper', 'result', 'busi', 'advers', 'affect', 'abil', 'condit', 'financi']
# FREX WORDS: ['advers', 'abil', 'affect', 'busi', 'financi', 'impact', 'materi', 'condit']
#
# TOPIC  64
# PROB WORDS: ['land', 'timber', 'forest', 'acr', 'wood', 'agricultur', 'farm', 'paper']
# FREX WORDS: ['land', 'timber', 'forest', 'wood', 'acr', 'agricultur', 'farm', 'pulp']
#
# TOPIC  65
# PROB WORDS: ['capit', 'expenditur', 'project', 'invest', 'spend', 'construct', 'facil', 'work']
# FREX WORDS: ['capit', 'expenditur', 'project', 'spend', 'construct', 'invest', 'facil', 'expans']
#
# TOPIC  66
# PROB WORDS: ['account', 'balanc', 'incom', 'liabil', 'expens', 'sheet', 'asset', 'record']
# FREX WORDS: ['account', 'balanc', 'sheet', 'incom', 'liabil', 'consolid', 'statement', 'expens']
#
# TOPIC  67
# PROB WORDS: ['environment', 'cost', 'site', 'remedi', 'liabil', 'estim', 'parti', 'potenti']
# FREX WORDS: ['environment', 'site', 'remedi', 'cost', 'liabil', 'estim', 'cleanup', 'parti']
#
# TOPIC  68
# PROB WORDS: ['cost', 'depreci', 'amort', 'properti', 'method', 'equip', 'asset', 'year']
# FREX WORDS: ['depreci', 'cost', 'amort', 'method', 'properti', 'equip', 'plant', 'inflat']
#
# TOPIC  69
# PROB WORDS: ['share', 'stock', 'common', 'prefer', 'purchas', 'outstand', 'issu', 'seri']
# FREX WORDS: ['stock', 'share', 'common', 'prefer', 'seri', 'repurchas', 'convert', 'outstand']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %%
#https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/
#https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/

# %% [markdown]
# # Topics over time
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts_paragraphs_futureonly/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect_paragraphs_futureonly.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")
metadata['paragraph_filetime']= metadata['Filename'].str.replace(".xml", "") + "_P" + metadata['Paragraph'].astype(str) + ".txt"

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (149145, 70)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['paragraph_filetime']]
topic_document_distribution['paragraph_filetime'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution_parafutureonly.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["paragraph_filetime", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "paragraph_filetime", "topic"])
print(dtm.head())
# Out:
#        paragraph_filetime  Year topic        weight
# 120113    88178377_P0.txt  1930     0  0.0002188184
# 269258    88178377_P0.txt  1930     1  0.0002188184
# 418403    88178377_P0.txt  1930     2  0.0002188184
# 567548    88178377_P0.txt  1930     3  0.0002188184
# 716693    88178377_P0.txt  1930     4  0.0002188184

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#   paragraph_filetime  Year topic        weight  \
# 0    88178377_P0.txt  1930     0  0.0002188184
# 1    88178441_P0.txt  1930     0  0.0001078749
# 2    88178441_P1.txt  1930     0  0.0000955110
# 3    88178441_P2.txt  1930     0  0.0001356852
# 4    88178460_P0.txt  1930     0  0.0002141328
#
#                                 keywords
# 0  care health medic product hospit drug
# 1  care health medic product hospit drug
# 2  care health medic product hospit drug
# 3  care health medic product hospit drug
# 4  care health medic product hospit drug

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9952965235173832
# Min: 1.2941633234114152e-05
# Average: 0.014285714285556046
# Median: 0.00017035775127768318
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['paragraph_filetime'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.set_xticklabels(rotation=45)
    n = 5  # Keeps every 5th label
    [l.set_visible(False) for (i,l) in enumerate(p.ax.xaxis.get_ticklabels()) if i % n != 0]
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
