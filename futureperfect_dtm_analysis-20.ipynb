# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
#import 
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Open Model

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic20.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 20

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/corpus.pkl', 'rb') )

# %% [markdown]
# # IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %% [markdown]
# ### Descriptions: Based on year 2005

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['product', 'new', 'plant', 'year', 'market', 'compani', 'sale', 'oper']
# FREX WORDS: ['steel', 'aluminum', 'plant', 'metal', 'plastic', 'chemic', 'ton', 'resin']
#
# TOPIC  1
# PROB WORDS: ['loan', 'risk', 'rate', 'credit', 'bank', 'manag', 'market', 'corpor']
# FREX WORDS: ['loan', 'bancorp', 'bank', 'risk', 'portfolio', 'securit', 'lynch', 'merril']
#
# TOPIC  2
# PROB WORDS: ['energi', 'cost', 'million', 'rate', 'ga', 'price', 'electr', 'market']
# FREX WORDS: ['cm', 'ga', 'dominion', 'electr', 'energi', 'keyspan', 'pef', 'decommiss']
#
# TOPIC  3
# PROB WORDS: ['compani', 'servic', 'year', 'oper', 'new', 'railroad', 'increas', 'aircraft']
# FREX WORDS: ['railroad', 'aircraft', 'airlin', 'passeng', 'traffic', 'freight', 'car', 'railwai']
#
# TOPIC  4
# PROB WORDS: ['oil', 'ga', 'compani', 'product', 'reserv', 'develop', 'drill', 'field']
# FREX WORDS: ['ga', 'oil', 'drill', 'barrel', 'crude', 'occident', 'refineri', 'well']
#
# TOPIC  5
# PROB WORDS: ['million', 'cost', 'oper', 'environment', 'price', 'requir', 'compani', 'facil']
# FREX WORDS: ['copper', 'lyondel', 'mine', 'phelp', 'environment', 'landfil', 'equistar', 'dodg']
#
# TOPIC  6
# PROB WORDS: ['million', 'compani', 'rate', 'asset', 'valu', 'financi', 'result', 'statement']
# FREX WORDS: ['hedg', 'sfa', 'swap', 'gatx', 'impair', 'goodwil', 'postretir', 'longliv']
#
# TOPIC  7
# PROB WORDS: ['year', 'new', 'compani', 'increas', 'product', 'continu', 'busi', 'oper']
# FREX WORDS: ['war', 'branch', 'bank', 'machin', 'men', 'pulp', 'timber', 'arc']
#
# TOPIC  8
# PROB WORDS: ['store', 'compani', 'new', 'year', 'oper', 'sale', 'retail', 'fiscal']
# FREX WORDS: ['store', 'merchandis', 'apparel', 'retail', 'dealership', 'brand', 'footwear', 'shoe']
#
# TOPIC  9
# PROB WORDS: ['compani', 'servic', 'oper', 'result', 'million', 'revenu', 'includ', 'certain']
# FREX WORDS: ['medicar', 'softwar', 'internet', 'ncr', 'caremark', 'pharmaci', 'outsourc', 'client']
#
# TOPIC  10
# PROB WORDS: ['product', 'compani', 'new', 'market', 'research', 'develop', 'sale', 'drug']
# FREX WORDS: ['patient', 'pharmaceut', 'clinic', 'abbott', 'drug', 'merck', 'medicin', 'pfizer']
#
# TOPIC  11
# PROB WORDS: ['compani', 'director', 'committe', 'shall', 'plan', 'execut', 'busi', 'board']
# FREX WORDS: ['shall', 'corn', 'peterstar', 'magticom', 'aramark', 'committe', 'televis', 'broadcast']
#
# TOPIC  12
# PROB WORDS: ['compani', 'power', 'cost', 'electr', 'gener', 'plant', 'million', 'rate']
# FREX WORDS: ['mohawk', 'niagara', 'nuclear', 'electr', 'ga', 'kilowatt', 'gpu', 'aep']
#
# TOPIC  13
# PROB WORDS: ['compani', 'stock', 'share', 'year', 'tax', 'corpor', 'incom', 'common']
# FREX WORDS: ['sink', 'surplu', 'bank', 'stock', 'debentur', 'share', 'prefer', 'corpor']
#
# TOPIC  14
# PROB WORDS: ['insur', 'life', 'compani', 'invest', 'polici', 'loss', 'claim', 'premium']
# FREX WORDS: ['reinsur', 'policyhold', 'underwrit', 'annuiti', 'insur', 'safeco', 'cna', 'casualti']
#
# TOPIC  15
# PROB WORDS: ['food', 'product', 'year', 'market', 'fiscal', 'compani', 'oper', 'price']
# FREX WORDS: ['food', 'conagra', 'sugar', 'meat', 'beef', 'grain', 'milk', 'feed']
#
# TOPIC  16
# PROB WORDS: ['product', 'new', 'year', 'develop', 'sale', 'engin', 'program', 'divis']
# FREX WORDS: ['aircraft', 'missil', 'navi', 'grumman', 'engin', 'northrop', 'rca', 'air']
#
# TOPIC  17
# PROB WORDS: ['compani', 'claim', 'million', 'cost', 'liabil', 'plan', 'estim', 'futur']
# FREX WORDS: ['asbesto', 'delphi', 'eastman', 'environment', 'asbestosrel', 'dow', 'claim', 'claimant']
#
# TOPIC  18
# PROB WORDS: ['million', 'compani', 'busi', 'market', 'growth', 'product', 'percent', 'custom']
# FREX WORDS: ['textron', 'caterpillar', 'trw', 'global', 'digit', 'technolog', 'softwar', 'nucor']
#
# TOPIC  19
# PROB WORDS: ['shall', 'borrow', 'loan', 'agreement', 'lender', 'section', 'secur', 'date']
# FREX WORDS: ['shall', 'owen', 'lender', 'debtor', 'loan', 'bankruptci', 'corco', 'chapter']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %% [markdown]
# ### Descriptions: Based on year 1950

# %%
#run frex models, time = 20
frex_output_1950 = create_topic_word_data(model, corpus, frex_w =.5, time = 20)

for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=20, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output_1950, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['product', 'plant', 'new', 'year', 'market', 'compani', 'sale', 'increas']
# FREX WORDS: ['steel', 'plant', 'aluminum', 'plastic', 'armco', 'metal', 'glass', 'chemic']
#
# TOPIC  1
# PROB WORDS: ['loan', 'bank', 'corpor', 'rate', 'risk', 'credit', 'manag', 'market']
# FREX WORDS: ['loan', 'bank', 'portfolio', 'risk', 'lynch', 'merril', 'mortgag', 'chargeoff']
#
# TOPIC  2
# PROB WORDS: ['energi', 'million', 'ga', 'cost', 'rate', 'contract', 'market', 'asset']
# FREX WORDS: ['cm', 'ga', 'mcv', 'energi', 'ferc', 'electr', 'decommiss', 'mpsc']
#
# TOPIC  3
# PROB WORDS: ['compani', 'railroad', 'new', 'servic', 'year', 'increas', 'oper', 'car']
# FREX WORDS: ['railroad', 'passeng', 'aircraft', 'car', 'railwai', 'traffic', 'airlin', 'freight']
#
# TOPIC  4
# PROB WORDS: ['oil', 'ga', 'product', 'compani', 'crude', 'drill', 'develop', 'oper']
# FREX WORDS: ['ga', 'oil', 'crude', 'drill', 'barrel', 'refineri', 'corco', 'well']
#
# TOPIC  5
# PROB WORDS: ['million', 'cost', 'oper', 'environment', 'price', 'requir', 'product', 'estim']
# FREX WORDS: ['copper', 'occident', 'mine', 'environment', 'pulp', 'ashland', 'timber', 'or']
#
# TOPIC  6
# PROB WORDS: ['compani', 'million', 'asset', 'valu', 'rate', 'financi', 'result', 'oper']
# FREX WORDS: ['hedg', 'sfa', 'swap', 'gatx', 'impair', 'mattel', 'longliv', 'goodwil']
#
# TOPIC  7
# PROB WORDS: ['year', 'compani', 'new', 'product', 'increas', 'busi', 'continu', 'oper']
# FREX WORDS: ['war', 'postwar', 'men', 'machin', 'arc', 'pulp', 'lumber', 'timber']
#
# TOPIC  8
# PROB WORDS: ['compani', 'store', 'new', 'oper', 'year', 'market', 'sale', 'retail']
# FREX WORDS: ['store', 'merchandis', 'retail', 'stapl', 'apparel', 'shoe', 'dealership', 'brand']
#
# TOPIC  9
# PROB WORDS: ['servic', 'oper', 'includ', 'result', 'million', 'revenu', 'provid', 'financi']
# FREX WORDS: ['visteon', 'wireless', 'softwar', 'pharmaci', 'sprint', 'avaya', 'fcc', 'medicar']
#
# TOPIC  10
# PROB WORDS: ['product', 'compani', 'new', 'market', 'research', 'develop', 'sale', 'year']
# FREX WORDS: ['clinic', 'pharmaceut', 'abbott', 'drug', 'patient', 'laboratori', 'diseas', 'pfizer']
#
# TOPIC  11
# PROB WORDS: ['plan', 'shall', 'particip', 'benefit', 'date', 'compani', 'stock', 'committe']
# FREX WORDS: ['shall', 'viacom', 'bonu', 'dell', 'newspap', 'hereund', 'gannett', 'committe']
#
# TOPIC  12
# PROB WORDS: ['compani', 'electr', 'power', 'cost', 'million', 'plant', 'rate', 'gener']
# FREX WORDS: ['electr', 'nuclear', 'ga', 'kilowatt', 'edison', 'transmiss', 'coal', 'fuel']
#
# TOPIC  13
# PROB WORDS: ['compani', 'stock', 'year', 'share', 'tax', 'corpor', 'incom', 'common']
# FREX WORDS: ['surplu', 'sink', 'debentur', 'bank', 'prefer', 'arc', 'renegoti', 'loan']
#
# TOPIC  14
# PROB WORDS: ['insur', 'life', 'invest', 'compani', 'polici', 'premium', 'loss', 'year']
# FREX WORDS: ['reinsur', 'policyhold', 'insur', 'annuiti', 'underwrit', 'lnc', 'cna', 'casualti']
#
# TOPIC  15
# PROB WORDS: ['food', 'product', 'market', 'year', 'sugar', 'fiscal', 'price', 'increas']
# FREX WORDS: ['sugar', 'food', 'monsanto', 'meat', 'milk', 'can', 'grain', 'conagra']
#
# TOPIC  16
# PROB WORDS: ['new', 'product', 'develop', 'year', 'engin', 'equip', 'program', 'sale']
# FREX WORDS: ['aircraft', 'missil', 'engin', 'televis', 'navi', 'militari', 'machin', 'flight']
#
# TOPIC  17
# PROB WORDS: ['compani', 'million', 'cost', 'result', 'liabil', 'financi', 'estim', 'oper']
# FREX WORDS: ['sanminasci', 'asbesto', 'environment', 'asbestosrel', 'remedi', 'cleanup', 'sfa', 'hedg']
#
# TOPIC  18
# PROB WORDS: ['million', 'market', 'compani', 'busi', 'product', 'custom', 'growth', 'technolog']
# FREX WORDS: ['chrysler', 'technolog', 'mdc', 'cummin', 'digit', 'semiconductor', 'global', 'ibm']
#
# TOPIC  19
# PROB WORDS: ['court', 'compani', 'claim', 'file', 'receiv', 'date', 'corpor', 'agreement']
# FREX WORDS: ['court', 'shall', 'bankruptci', 'debtor', 'chapter', 'creditor', 'plaintiff', 'lender']

# %% [markdown]
# # Topics over time

# %% [markdown]
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html
# ##https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (36479, 20)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['Filename']]
topic_document_distribution['Filename'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["Filename", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "Filename", "topic"])
print(dtm.head())
# Out:
#             Filename  Year topic        weight
# 21217   88178299.xml  1930     0  0.0156084305
# 57696   88178299.xml  1930     1  0.0001246883
# 94175   88178299.xml  1930     2  0.0001246883
# 130654  88178299.xml  1930     3  0.0001246883
# 167133  88178299.xml  1930     4  0.0001246883

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#        Filename  Year topic        weight  \
# 0  88178299.xml  1930     0  0.0156084305
# 1  88178309.xml  1930     0  0.0001811594
# 2  88178340.xml  1930     0  0.0000640205
# 3  88178352.xml  1930     0  0.0003311258
# 4  88178376.xml  1930     0  0.0005813953
#
#                                 keywords
# 0  product new plant year market compani
# 1  product new plant year market compani
# 2  product new plant year market compani
# 3  product new plant year market compani
# 4  product new plant year market compani

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9996231654105515
# Min: 4.115192467551707e-07
# Average: 0.04999999999999412
# Median: 0.00010615711252653925
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['Filename'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.set_xticklabels(rotation=45)
    n = 5  # Keeps every 5th label
    [l.set_visible(False) for (i,l) in enumerate(p.ax.xaxis.get_ticklabels()) if i % n != 0]
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
