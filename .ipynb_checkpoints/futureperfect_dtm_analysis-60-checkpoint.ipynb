# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Set topic number

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic60.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 60

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/corpus.pkl', 'rb') )

# %% [markdown]
# ### IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# ### extract term-topic matrix (note this will be over all the time slices)

# %% [markdown]
# # get_topics for DTM
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %% [markdown]
# ## Frex output

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['valu', 'asset', 'financi', 'rate', 'statement', 'fair', 'million', 'cash']
# FREX WORDS: ['hedg', 'impair', 'sfa', 'swap', 'risk', 'goodwil', 'fair', 'forwardlook']
#
# TOPIC  1
# PROB WORDS: ['delphi', 'ford', 'ppl', 'billion', 'trust', 'decemb', 'contract', 'vehicl']
# FREX WORDS: ['delphi', 'ford', 'ppl', 'uaw', 'montana', 'hourli', 'vehicl', 'dep']
#
# TOPIC  2
# PROB WORDS: ['textron', 'financ', 'bell', 'receiv', 'motor', 'restaur', 'aircraft', 'wesco']
# FREX WORDS: ['textron', 'bell', 'wesco', 'motor', 'restaur', 'aircraft', 'helicopt', 'gm']
#
# TOPIC  3
# PROB WORDS: ['financ', 'bow', 'leas', 'pitnei', 'mail', 'equip', 'custom', 'xerox']
# FREX WORDS: ['bow', 'pitnei', 'xerox', 'copier', 'mail', 'copi', 'haloid', 'fuji']
#
# TOPIC  4
# PROB WORDS: ['product', 'eastman', 'kodak', 'film', 'chemic', 'manufactur', 'fiber', 'polym']
# FREX WORDS: ['eastman', 'maytag', 'kodak', 'film', 'polym', 'celanes', 'chemic', 'camera']
#
# TOPIC  5
# PROB WORDS: ['televis', 'station', 'cabl', 'broadcast', 'radio', 'fcc', 'oper', 'program']
# FREX WORDS: ['televis', 'broadcast', 'cabl', 'radio', 'fcc', 'station', 'film', 'entertain']
#
# TOPIC  6
# PROB WORDS: ['advertis', 'newspap', 'program', 'magazin', 'publish', 'new', 'compani', 'revenu']
# FREX WORDS: ['newspap', 'magazin', 'advertis', 'circul', 'kaplan', 'televis', 'gannett', 'newsprint']
#
# TOPIC  7
# PROB WORDS: ['corpor', 'asset', 'oper', 'financi', 'busi', 'rate', 'result', 'manag']
# FREX WORDS: ['corpor', 'sara', 'lee', 'fedex', 'pepsico', 'pbg', 'kimberlyclark', 'dean']
#
# TOPIC  8
# PROB WORDS: ['dealer', 'vehicl', 'manufactur', 'dealership', 'sonic', 'motor', 'sale', 'smith']
# FREX WORDS: ['dealer', 'dealership', 'sonic', 'vehicl', 'mattel', 'motor', 'smith', 'toi']
#
# TOPIC  9
# PROB WORDS: ['occident', 'oil', 'ga', 'pipelin', 'product', 'price', 'futur', 'oper']
# FREX WORDS: ['occident', 'pipelin', 'oil', 'ga', 'crude', 'pennzoil', 'refineri', 'apach']
#
# TOPIC  10
# PROB WORDS: ['million', 'cost', 'tax', 'plan', 'benefit', 'oper', 'expect', 'financi']
# FREX WORDS: ['pension', 'benefit', 'tax', 'actuari', 'postretir', 'million', 'retire', 'discount']
#
# TOPIC  11
# PROB WORDS: ['oil', 'ga', 'product', 'compani', 'develop', 'drill', 'reserv', 'field']
# FREX WORDS: ['oil', 'ga', 'drill', 'barrel', 'crude', 'refineri', 'well', 'field']
#
# TOPIC  12
# PROB WORDS: ['compani', 'power', 'electr', 'plant', 'gener', 'ga', 'unit', 'construct']
# FREX WORDS: ['electr', 'nuclear', 'ga', 'kilowatt', 'power', 'aep', 'plant', 'coal']
#
# TOPIC  13
# PROB WORDS: ['die', 'chemic', 'monsanto', 'grace', 'agricultur', 'unit', 'busi', 'product']
# FREX WORDS: ['die', 'chemic', 'monsanto', 'herbicid', 'grace', 'hershei', 'rohm', 'haa']
#
# TOPIC  14
# PROB WORDS: ['steel', 'facil', 'product', 'goodyear', 'ton', 'tire', 'metal', 'capac']
# FREX WORDS: ['steel', 'goodyear', 'furnac', 'tire', 'iron', 'ltv', 'metal', 'ton']
#
# TOPIC  15
# PROB WORDS: ['aircraft', 'airlin', 'servic', 'new', 'continent', 'air', 'american', 'oper']
# FREX WORDS: ['aircraft', 'airlin', 'continent', 'boe', 'passeng', 'fare', 'flight', 'twa']
#
# TOPIC  16
# PROB WORDS: ['energi', 'cost', 'market', 'electr', 'risk', 'manag', 'price', 'power']
# FREX WORDS: ['energi', 'xcel', 'decommiss', 'nuclear', 'nrg', 'bge', 'nsp', 'constel']
#
# TOPIC  17
# PROB WORDS: ['railroad', 'car', 'increas', 'transport', 'freight', 'compani', 'servic', 'year']
# FREX WORDS: ['railroad', 'car', 'freight', 'traffic', 'railwai', 'rail', 'interst', 'yard']
#
# TOPIC  18
# PROB WORDS: ['packag', 'glass', 'contain', 'beverag', 'crown', 'ball', 'can', 'mead']
# FREX WORDS: ['glass', 'packag', 'crown', 'beverag', 'can', 'mead', 'ball', 'beer']
#
# TOPIC  19
# PROB WORDS: ['store', 'fiscal', 'retail', 'sale', 'merchandis', 'oper', 'plan', 'custom']
# FREX WORDS: ['store', 'fiscal', 'merchandis', 'vendor', 'retail', 'catalog', 'inventori', 'warehous']
#
# TOPIC  20
# PROB WORDS: ['product', 'new', 'year', 'plant', 'market', 'sale', 'compani', 'divis']
# FREX WORDS: ['plant', 'divis', 'machin', 'chemic', 'product', 'research', 'laboratori', 'plastic']
#
# TOPIC  21
# PROB WORDS: ['pennsylvania', 'util', 'gpu', 'subsidiari', 'gener', 'penn', 'cost', 'ga']
# FREX WORDS: ['gpu', 'penn', 'pennsylvania', 'jcpl', 'ugi', 'penelec', 'firstenergi', 'mete']
#
# TOPIC  22
# PROB WORDS: ['dow', 'union', 'wast', 'landfil', 'cost', 'alli', 'carbid', 'chemic']
# FREX WORDS: ['dow', 'carbid', 'landfil', 'alli', 'union', 'olin', 'postclosur', 'wast']
#
# TOPIC  23
# PROB WORDS: ['shall', 'execut', 'plan', 'termin', 'section', 'agreement', 'term', 'particip']
# FREX WORDS: ['shall', 'aramark', 'employ', 'salari', 'hereund', 'execut', 'successor', 'neubauer']
#
# TOPIC  24
# PROB WORDS: ['risk', 'credit', 'manag', 'rate', 'loan', 'valu', 'market', 'secur']
# FREX WORDS: ['bancorp', 'risk', 'loan', 'lynch', 'morgan', 'securit', 'msr', 'merril']
#
# TOPIC  25
# PROB WORDS: ['paper', 'pulp', 'wood', 'timber', 'corco', 'forest', 'million', 'capac']
# FREX WORDS: ['pulp', 'paper', 'timber', 'wood', 'forest', 'corco', 'lumber', 'paperboard']
#
# TOPIC  26
# PROB WORDS: ['claim', 'asbesto', 'bankruptci', 'plan', 'file', 'reorgan', 'court', 'liabil']
# FREX WORDS: ['asbesto', 'owen', 'bankruptci', 'claim', 'chapter', 'debtor', 'reorgan', 'claimant']
#
# TOPIC  27
# PROB WORDS: ['leas', 'financ', 'rental', 'equip', 'oper', 'gatx', 'transport', 'servic']
# FREX WORDS: ['leas', 'gatx', 'rental', 'car', 'tank', 'vessel', 'lessor', 'equip']
#
# TOPIC  28
# PROB WORDS: ['product', 'market', 'year', 'sale', 'increas', 'million', 'oper', 'compani']
# FREX WORDS: ['truck', 'caterpillar', 'engin', 'brunswick', 'boat', 'crane', 'percent', 'machineri']
#
# TOPIC  29
# PROB WORDS: ['year', 'compani', 'increas', 'product', 'oper', 'busi', 'sale', 'industri']
# FREX WORDS: ['war', 'arc', 'cent', 'surplu', 'postwar', 'hope', 'men', 'stockhold']
#
# TOPIC  30
# PROB WORDS: ['rate', 'fuel', 'cost', 'million', 'energi', 'power', 'sce', 'pef']
# FREX WORDS: ['pef', 'pec', 'sce', 'fuel', 'edison', 'em', 'ferc', 'cpuc']
#
# TOPIC  31
# PROB WORDS: ['presid', 'vice', 'year', 'compani', 'new', 'store', 'chairman', 'manag']
# FREX WORDS: ['vice', 'presid', 'store', 'chairman', 'men', 'apparel', 'shoe', 'merchandis']
#
# TOPIC  32
# PROB WORDS: ['dominion', 'util', 'cost', 'electr', 'ga', 'rate', 'power', 'energi']
# FREX WORDS: ['dominion', 'cinergi', 'ga', 'pge', 'electr', 'cge', 'psi', 'cpuc']
#
# TOPIC  33
# PROB WORDS: ['compani', 'oper', 'result', 'million', 'expect', 'manag', 'busi', 'financi']
# FREX WORDS: ['compani', 'currenc', 'risk', 'health', 'bax', 'segment', 'disclosur', 'brink']
#
# TOPIC  34
# PROB WORDS: ['corn', 'busi', 'product', 'segment', 'come', 'technolog', 'impair', 'foreign']
# FREX WORDS: ['corn', 'lyon', 'pcc', 'glass', 'spx', 'optic', 'lcd', 'telecommun']
#
# TOPIC  35
# PROB WORDS: ['consum', 'ga', 'mohawk', 'niagara', 'energi', 'electr', 'contract', 'custom']
# FREX WORDS: ['cm', 'mohawk', 'niagara', 'ga', 'energi', 'electr', 'consum', 'mpsc']
#
# TOPIC  36
# PROB WORDS: ['environment', 'million', 'site', 'cost', 'remedi', 'oper', 'requir', 'regul']
# FREX WORDS: ['environment', 'remedi', 'site', 'prp', 'cleanup', 'epa', 'contamin', 'closur']
#
# TOPIC  37
# PROB WORDS: ['court', 'action', 'claim', 'file', 'alleg', 'defend', 'state', 'district']
# FREX WORDS: ['court', 'alleg', 'plaintiff', 'defend', 'complaint', 'lawsuit', 'district', 'dismiss']
#
# TOPIC  38
# PROB WORDS: ['servic', 'client', 'contract', 'million', 'revenu', 'busi', 'outsourc', 'provid']
# FREX WORDS: ['client', 'adp', 'tyler', 'ed', 'outsourc', 'hte', 'mmc', 'fluor']
#
# TOPIC  39
# PROB WORDS: ['contract', 'aircraft', 'program', 'develop', 'govern', 'system', 'air', 'engin']
# FREX WORDS: ['aircraft', 'missil', 'navi', 'grumman', 'northrop', 'militari', 'aerospac', 'flight']
#
# TOPIC  40
# PROB WORDS: ['valu', 'busi', 'berkshir', 'loss', 'insur', 'invest', 'cigna', 'annuiti']
# FREX WORDS: ['berkshir', 'cigna', 'reinsur', 'annuiti', 'lincoln', 'lnc', 'pkn', 'health']
#
# TOPIC  41
# PROB WORDS: ['new', 'electron', 'system', 'develop', 'equip', 'divis', 'record', 'rca']
# FREX WORDS: ['rca', 'electron', 'ibm', 'cb', 'color', 'tube', 'mcgrawhil', 'radio']
#
# TOPIC  42
# PROB WORDS: ['stock', 'share', 'compani', 'common', 'option', 'year', 'corpor', 'dividend']
# FREX WORDS: ['stock', 'share', 'prefer', 'debentur', 'option', 'dividend', 'common', 'compani']
#
# TOPIC  43
# PROB WORDS: ['mine', 'copper', 'price', 'aluminum', 'product', 'ton', 'or', 'oper']
# FREX WORDS: ['copper', 'mine', 'aluminum', 'or', 'ounc', 'phelp', 'dodg', 'gold']
#
# TOPIC  44
# PROB WORDS: ['hotel', 'disnei', 'brand', 'footwear', 'properti', 'million', 'sport', 'oper']
# FREX WORDS: ['hotel', 'disnei', 'footwear', 'guest', 'marriott', 'sport', 'brand', 'apparel']
#
# TOPIC  45
# PROB WORDS: ['compani', 'care', 'servic', 'health', 'manag', 'medic', 'provid', 'oper']
# FREX WORDS: ['pharmaci', 'patient', 'medicar', 'care', 'hospit', 'caremark', 'medic', 'health']
#
# TOPIC  46
# PROB WORDS: ['committe', 'director', 'board', 'plan', 'award', 'execut', 'meet', 'offic']
# FREX WORDS: ['committe', 'director', 'board', 'award', 'vote', 'proxi', 'bonu', 'audit']
#
# TOPIC  47
# PROB WORDS: ['busi', 'servic', 'oper', 'network', 'commun', 'telephon', 'level', 'ventur']
# FREX WORDS: ['peterstar', 'telephon', 'telecom', 'telecommun', 'wireless', 'georgia', 'network', 'telephoni']
#
# TOPIC  48
# PROB WORDS: ['loan', 'bank', 'rate', 'credit', 'million', 'loss', 'year', 'mortgag']
# FREX WORDS: ['loan', 'bank', 'mortgag', 'fargo', 'lend', 'well', 'home', 'estat']
#
# TOPIC  49
# PROB WORDS: ['busi', 'new', 'market', 'growth', 'year', 'compani', 'custom', 'product']
# FREX WORDS: ['peopl', 'growth', 'percent', 'want', 'help', 'innov', 'weve', 'todai']
#
# TOPIC  50
# PROB WORDS: ['licens', 'csx', 'license', 'product', 'agreement', 'shall', 'approv', 'cki']
# FREX WORDS: ['licens', 'csx', 'license', 'cki', 'shall', 'licensor', 'conrail', 'warnaco']
#
# TOPIC  51
# PROB WORDS: ['foreign', 'currenc', 'exchang', 'product', 'rate', 'europ', 'global', 'countri']
# FREX WORDS: ['currenc', 'foreign', 'global', 'europ', 'hedg', 'china', 'euro', 'brand']
#
# TOPIC  52
# PROB WORDS: ['product', 'research', 'develop', 'new', 'drug', 'market', 'pharmaceut', 'merck']
# FREX WORDS: ['patient', 'pharmaceut', 'drug', 'abbott', 'merck', 'clinic', 'medicin', 'diseas']
#
# TOPIC  53
# PROB WORDS: ['keyspan', 'ga', 'lyondel', 'energi', 'txu', 'facil', 'price', 'corp']
# FREX WORDS: ['keyspan', 'lyondel', 'txu', 'ga', 'equistar', 'lcr', 'energi', 'ravenswood']
#
# TOPIC  54
# PROB WORDS: ['new', 'bank', 'year', 'offic', 'life', 'insur', 'fund', 'servic']
# FREX WORDS: ['bank', 'branch', 'colleg', 'policyown', 'life', 'annuiti', 'transamerica', 'mutual']
#
# TOPIC  55
# PROB WORDS: ['trw', 'automot', 'system', 'vehicl', 'honeywel', 'technolog', 'dana', 'autoliv']
# FREX WORDS: ['trw', 'honeywel', 'automot', 'dana', 'airbag', 'autoliv', 'bendix', 'vehicl']
#
# TOPIC  56
# PROB WORDS: ['product', 'custom', 'servic', 'busi', 'fiscal', 'result', 'oper', 'technolog']
# FREX WORDS: ['ncr', 'softwar', 'digit', 'gatewai', 'fiscal', 'internet', 'microsoft', 'server']
#
# TOPIC  57
# PROB WORDS: ['shall', 'borrow', 'lender', 'loan', 'agreement', 'section', 'agent', 'subsidiari']
# FREX WORDS: ['shall', 'lender', 'loan', 'magticom', 'tranch', 'agent', 'borrow', 'thereof']
#
# TOPIC  58
# PROB WORDS: ['food', 'product', 'year', 'fiscal', 'market', 'oper', 'sale', 'increas']
# FREX WORDS: ['food', 'conagra', 'fiscal', 'feed', 'meat', 'milk', 'sugar', 'beef']
#
# TOPIC  59
# PROB WORDS: ['insur', 'claim', 'loss', 'invest', 'life', 'polici', 'compani', 'reserv']
# FREX WORDS: ['reinsur', 'insur', 'policyhold', 'underwrit', 'safeco', 'cna', 'claim', 'casualti']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %%
#https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/
#https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/

# %% [markdown]
# # Topics over time
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (36479, 60)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['Filename']]
topic_document_distribution['Filename'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["Filename", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "Filename", "topic"])
print(dtm.head())
# Out:
#             Filename  Year topic        weight
# 21217   88178299.xml  1930     0  0.0001240695
# 57696   88178299.xml  1930     1  0.0001240695
# 94175   88178299.xml  1930     2  0.0001240695
# 130654  88178299.xml  1930     3  0.0001240695
# 167133  88178299.xml  1930     4  0.0001240695

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#        Filename  Year topic        weight  \
# 0  88178299.xml  1930     0  0.0001240695
# 1  88178309.xml  1930     0  0.0001798561
# 2  88178340.xml  1930     0  0.0918969798
# 3  88178352.xml  1930     0  0.0003267974
# 4  88178376.xml  1930     0  0.0005681818
#
#                                  keywords
# 0  valu asset financi rate statement fair
# 1  valu asset financi rate statement fair
# 2  valu asset financi rate statement fair
# 3  valu asset financi rate statement fair
# 4  valu asset financi rate statement fair

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9990903484428
# Min: 1.4951311165912097e-07
# Average: 0.016666666666667565
# Median: 1.8096272167933408e-05
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['Filename'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, size=5, aspect=1.5, title=""):
    p = sns.factorplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  size=size, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, size=5, aspect=1.5, title=""):
    p = sns.factorplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, size=size, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
