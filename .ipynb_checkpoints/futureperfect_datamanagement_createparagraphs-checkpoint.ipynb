# %% [markdown]
# '''
# This program selects future-oriented text and cleans text
# #Date: Dec 3 2019
# #Update: Mar 25, 2019
# #update: June 27, 2020
# #Author: Carly Knight
# '''

# %% [markdown]
# ### Import packages

# %%
import os
from zipfile import ZipFile
import xml.etree.ElementTree as ET
from xml import etree
import csv
import re
import dateutil.parser as parser
from enchant.tokenize import get_tokenizer
import enchant
import pandas as pd
from itertools import chain
import random

# %% [markdown]
# ## get liwc list

# %%
liwclist= "/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/LIWC/liwc2015dict.csv"
lw= pd.read_csv(liwclist)

#select FocusFuture
future= lw.loc[lw['var'] == 'FocusFuture']
futurelist = future['word'].tolist()

#stems versus words
futurelist_stem = [s.strip('*') for s in futurelist if "*" in s]
futurelist_word = [s for s in futurelist if "*" not in s]

#add/remove
futurelist_word.extend(["Future", "will", "is heading", "are heading", "aim","could", "doubt", "has begun", "intend", "intends", "intending", "is expected", "is likely to", "it is hoped", "optimism", "pessimism", "uncertainty", "projected", "certainty", "as yet", "not yet", "may", "outlook", "should", "risk", "risky", "risk-taking", "is planned", "is planning", "is scheduled", "a planned", "the planned", "optimistic", "pessimistic", "next generation", "well positioned", "next-generation", "well-positioned", "is scheduled", "are scheduled"])
futurelist_word.remove("plan")
futurelist_word.remove("plans")
futurelist_word.remove("planner")
futurelist_word.remove("planning")

futurelist_stem.extend(["confident"])
futurelist_stem.remove("headin")
futurelist_stem.remove("prepar")

#notwordlist
notwordlist=["shareholders will", "Shareholders will", "will be of interest", "good will", "GOOD WILL", "Good will", "you will", "was expected", "were expected", "TABLE OF CONTENTS", "table of contents", "should have", "could have", "would have", "should not have", "could not have", "would not have", "may have", "accounting standards"]

#financial statement list
financialstatement = ["Notes to Consolidated Financial Statements", "Notes to Financial Statements"]

#paragrapsh to exclude list
phrasetoexclude = financialstatement + ['financial accounting', "the following table", "transfer agent", "annual meeting of shareholders", "annual meeting of stockholders", "next annual meeting"]

#test examples
example_list = ["possible"]
example_container_lists = [ [] for i in range(len(example_list)) ]

print(futurelist_word)
print(futurelist_stem)
print(notwordlist)
#Other potential options:
#Risk, Money, Quant, Verb, Tentat, Certain, Time
# Out:
# ['ahead', 'anticipation', 'approaching', 'attainable', 'coming', 'eventual', 'eventually', 'fate', 'fated', 'fates', 'feasible', 'finna', 'fixin', "fixin'", 'foresight', 'forseeable', 'forthcoming', 'going', 'gon', 'gonna', 'gotta', 'gunna', "he'll", 'henceforth', 'hope', 'hopeful', 'hopefully', 'hoping', "i'll", "i'mma", 'ima', 'imma', 'imminent', 'impending', "it'll", 'itll', 'looming', 'may', 'might', 'obtainable', 'oncoming', 'onward', 'pray', 'prayed', 'praying', 'promising', 'shall', "shan't", 'shant', "she'll", 'someday', 'sometime', 'soon', 'sooner', 'soonest', "that'll", 'thatll', 'Future', 'will', 'is heading', 'are heading', 'aim', 'could', 'doubt', 'has begun', 'intend', 'intends', 'intending', 'is expected', 'is likely to', 'it is hoped', 'optimism', 'pessimism', 'uncertainty', 'projected', 'certainty', 'as yet', 'not yet', 'may', 'outlook', 'should', 'risk', 'risky', 'risk-taking', 'is planned', 'is planning', 'is scheduled', 'a planned', 'the planned', 'optimistic', 'pessimistic', 'next generation', 'well positioned', 'next-generation', 'well-positioned', 'is scheduled', 'are scheduled']
# ['anticipate', 'destin', 'expect', 'forbod', 'foresee', 'foreshadow', 'futur', 'potential', 'prayer', 'predict', 'prospect', 'confident']
# ['shareholders will', 'Shareholders will', 'will be of interest', 'good will', 'GOOD WILL', 'Good will', 'you will', 'was expected', 'were expected', 'TABLE OF CONTENTS', 'table of contents', 'should have', 'could have', 'would have', 'should not have', 'could not have', 'would not have', 'may have', 'accounting standards']

# %% [markdown]
# # Prep + helper functions

# %% [markdown]
# ### Input and Output Data Location

# %%
directory = "/Users/carlyknight/Documents/Data/Annual Report/XML/"
results= "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"
results_paragraphs = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts_paragraphs/"
test_files= "/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/keyword_test_files/"
test_paragraphs = "/Users/carlyknight/Dropbox/PROJECTS/Corporate_Futures_for_Hesu/paragraphs/"

# %% [markdown]
# ### Help function: spell checker

# %%
#function to calculate the percent
def calculate_percent_correct(text):
	true =0
	total = 0.0
	for word in tknzr(text):
		word1 =word[0]
		total +=1
		if d2.check(word1):
			true +=1
	if total !=0:
		percent = true*1.0/total
	else:
		percent =0
	return percent

'''INITIATE SPELLCHECKER'''
d2 = enchant.DictWithPWL("en_US")
tknzr = get_tokenizer("en_US")

# %% [markdown]
# ### Helper function: clean text

# %%
def get_fulltext(root):
	full = root.find('FullText')
	if full is None:
		fulltext = ""
	else:
		fulltext=full.text
	return fulltext

# %%
def clean_punction(fulltext):
    #remove various kinds of superfluous punction
    fulltext = re.sub(r'[;:$-*><=|^·\,\\-]','',fulltext)
    fulltext.replace(u'No.', u'No')
    fulltext.replace("\\", "") 
    #replace series of periods with one period
    fulltext = re.sub(r'(\.\s*\.\s*)+', '', fulltext)
    return fulltext

# %% [markdown]
# ### Regex Compile

# %%
pattern_word = r"(?<=\W)(%s)\b" % "|".join(futurelist_word)
regex_word = re.compile(pattern_word)

pattern_stem = r"(?<=\W)(%s)" % "|".join(futurelist_stem)
regex_stem = re.compile(pattern_stem)

pattern_finance = r"(?<=\W)(%s)" % "|".join(financialstatement)
regex_financestatement = re.compile(pattern_finance)

#note: we don't care about case sensitivity for the removals
pattern_remove = r"(?<=\W)(%s)" % "|".join(phrasetoexclude)
regex_remove = re.compile(pattern_remove, re.IGNORECASE)

# %% [markdown]
# ### Helper fuction: Wordsearch functions

# %%
#identify paragraphs
def paragraph_split(fulltext):
    splits= re.split('(\.{3,}[-_\s]*\.{2,}[-_\s]*)|(\_{3,})|(\-{3,})|(\s{3,}[0-9]{1,}\s{3,})|(\s{5,}[A-Z\s]+\s{5,})', fulltext)
    splits=[split for split in splits if split is not None if split.strip() is not '']
    return splits

#combine paragraphs if they are too short
def paragraph_combine(si, length):
    si = iter(si)
    while True:
        try:
            current = next(si)
        except StopIteration:
            return
        try:
            while len(current) < length:
                current += ' ' + next(si)
        except StopIteration:
            return
        try:
            yield current
        except StopIteration:
            return

# %%
#identify future paragraphs
def paragraph_wordsearch(paragraphs):
    selected_paragraphs = []
    for paragraph in paragraphs:
        #search paragraph for wordlist
        num_matches=len(regex_stem.findall(paragraph)) + len(regex_word.findall(paragraph))
        if num_matches > 0: #if there is a match
            #chain the word and stem iterators:
            chain_iter = chain(regex_stem.finditer(paragraph), regex_word.finditer(paragraph))
            #iterate through chain
            for match in chain_iter:
                #make sure only match is not in not-match list:
                if [m for m in notwordlist if m in paragraph[match.start()-10: match.end()+10]]:
                    continue
                else:
                    #replace with asterisks
                    paragraph =paragraph.replace(match.group(), "***" + match.group())
            #substitute due to loop problems
            paragraph = re.sub(r'\*+', "***", paragraph)
            #if there are asterisks, then append
            if "***" in paragraph:
                selected_paragraphs.append(paragraph)
    return selected_paragraphs

# %%
#remove paragraphs contain content we know we don't want
def paragraph_remove(paragraphs):
    selected_paragraphs = []
    for paragraph in paragraphs:
        #search for what to remove
        if len(regex_remove.findall(paragraph))>0: #if there is something to remove
            #print("FOUND PARAGRAPH TO REMOVE")
            continue
        elif "NOTE" in paragraph:
            #print("WORD 'NOTE' FOUND")
            continue
        else:
            selected_paragraphs.append(paragraph)
    return selected_paragraphs

# %%
#identify future paragraphs for examples
def paragraph_example_wordsearch(selected_text):
    paragraphs = selected_text.split("####")
    for paragraph in paragraphs: #iterate through paragraph
        for i,item in enumerate(example_list): #for each paragraph, test for each item
            if re.search(r"(?<=\*\*\*)" + item + r"\b", paragraph):
                example_container_lists[i].append(paragraph)

# %%
#find financial statement and remove text after
def find_financialstatement(fulltext):
    matches = regex_financestatement.finditer(fulltext)
    text_length = len(fulltext)
    if matches: 
        for m in matches:
            location = m.start()
            finance_location = location/text_length
            #print(m.start(), m.group(), finance_location)
            #if finance location in back fourth of document, remove everything after that location
            if finance_location >= 2/3:
                fulltext = fulltext[:location]
                return(fulltext)
                break
    return(fulltext)

# %% [markdown]
# ### Helper function: get metadata

# %%
def get_metadata(root):
    date= root.find('AlphaPubDate').text
    datenum = root.find('NumericPubDate').text
    year = parser.parse(date).year
    url = root.find('URLDocView').text
    child = root.find('Terms')
    #create empty containers for terms
    company = ''
    naics=''
    code = ''
    classic = ''
    #iterate through terms
    for alltags in child.findall('.//'):
        if alltags.tag == "CompanyName":
            company = alltags.text
        elif alltags.tag == "CompanyNAIC":
            naics = alltags.text
        elif alltags.tag == "ClassCode":
            code = alltags.text
        elif alltags.tag == "ClassExpansion":
            classic = alltags.text
    # put the flexterms into a dictionary
    dict = {}
    for elem in root.iter('FlexTerm'):
        dict[elem.find('FlexTermName').text] = elem.find('FlexTermValue').text
    # create terms from dictionary
    ancode, ancashd, ancashs, anasd, anass, anrevd, anrevs, anearnd, anearns = [dict.get(k) for k in
                                                                            ['AnrClassCode1IdxLit',
                                                                             'AnrCashDispIdxNum',
                                                                             'AnrCashSrchIdxNum',
                                                                             'AnrAssetDispIdxNum',
                                                                             'AnrAssetSrchIdxNum',
                                                                             'AnrRevDispIdxNum',
                                                                             'AnrRevSrchIdxNum',
                                                                             'AnrEarnDispIdxNum',
                                                                             'AnrEarnSrchIdxNum']]
    # if variables above are NONE, recode as empty string
    ancode, ancashd, ancashs, anasd, anass, anrevd, anrevs, anearnd, anearns = [k or "" for k in
                                                                            [ancode, ancashd, ancashs, anasd,
                                                                             anass, anrevd, anrevs, anearnd,
                                                                             anearns]]
    #create list of alternative company names
    altnames =[]
    for elem in root.iter('FlexTerm'):
        if elem.find('FlexTermName').text == "AnrRelCoNameIdxLit":
            altnames.append(elem.find('FlexTermValue').text)
    relnames='; '.join(altnames)
    return date, datenum, year, url, company, naics, code, classic, ancode, ancashd, ancashs, anasd, anass, anrevd, anrevs, anearnd, anearns, relnames

# %% [markdown]
# # Main loop

# %% [markdown]
# ### create list for random selection to check

# %%
random_selection = []

# %% [markdown]
# ### create list of zip-files

# %%
zippaths=[]
for zipped in os.listdir(directory):
	if not zipped.endswith('.zip'):continue
	zippaths.append(os.path.join(directory, zipped))

# %% [markdown]
# ### open csv for metadata- paragraph

# %%
csvfile = open(results + 'metadata_futureperfect_paragraphs.csv', 'w')
fieldnames = ['Location', 'Filename', "Paragraph", 'RecordTitle', 'Date', 'Date1', 'Year', 'URL', 'CompanyName', 'NAIC', 'ClassCode', 'Classification', 'AnrAssetDispIdxNum', 'numwordstotal', "numwordsparagraph", 'num_paragraphs_prespellcheck', 'num_paragraphs_postspellcheck']
writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
writer.writeheader()

# %% [markdown]
# # TEST

# %%
# zip1 = [zippaths[4]]
# for filename in zip1:
#     with ZipFile(filename, "r") as zf:
#         for name in zf.namelist():
#             print("FILE :", name)
#             data= zf.read(name)
#             root = ET.fromstring(data)
#             date, datenum, year, url, company, naics, code, classic, ancode, ancashd, ancashs, anasd, anass, anrevd, anrevs, anearnd, anearns, relnames= get_metadata(root)
#             #get fulltext
#             fulltext= get_fulltext(root)
#             #clean fulltext
#             fulltext=clean_punction(fulltext)
#             #find and remove financial statements later in document
#             fulltext=find_financialstatement(fulltext)
#             #identify paragraphs
#             paragraphs1 = paragraph_split(fulltext)
#             paragraphs2 = list(paragraph_combine(paragraphs1, 200))
#             #wordsearch paragraphs
#             paragraphs3= paragraph_wordsearch(paragraphs2)
#             n_paragraphs_pre= len(paragraphs3)
#             #select only quality paragraphs
#             paragraphs4 = select_good_paragraphs(paragraphs3)
#             #remove bad phrases
#             paragraphs5 = paragraph_remove(paragraphs4)
#             if paragraphs5 is None or len(paragraphs5)==0:
#                 print(str(i), name, "No results returned")
#                 continue
#             #combine paragraphs again for STM analysis (into 500 words)
#             paragraphs6 = paragraph_combine(paragraphs5, 500)

# %% [markdown]
# # Loop

# %%
i=1
for filename in zippaths:
    with ZipFile(filename, "r") as zf:
        for name in zf.namelist():
            data= zf.read(name)
            root = ET.fromstring(data)
            date, datenum, year, url, company, naics, code, classic, ancode, ancashd, ancashs, anasd, anass, anrevd, anrevs, anearnd, anearns, relnames= get_metadata(root)
            #get fulltext
            fulltext= get_fulltext(root)
            #clean fulltext
            fulltext=clean_punction(fulltext)
            #find and remove financial statements later in document
            fulltext=find_financialstatement(fulltext)
            #identify paragraphs
            paragraphs1 = paragraph_split(fulltext)
            paragraphs2 = list(paragraph_combine(paragraphs1, 200))
            #wordsearch paragraphs
            paragraphs3= paragraph_wordsearch(paragraphs2)
            #select only quality paragraphs
            paragraphs4 = select_good_paragraphs(paragraphs3)
            #remove bad phrases
            paragraphs5 = paragraph_remove(paragraphs4)
            #combine paragraphs again for STM analysis (into 500 words)
            paragraphs6 = list(paragraph_combine(paragraphs5, 500))
            n_paragraphs_post= len(paragraphs6)
            if paragraphs6 is None or len(paragraphs6)==0:
                print(str(i), name, "No results returned")
                continue
            #select a random paragraph for Barbara analysis in post 1900 period
            if year >1990:
                selection = random.choice(paragraphs6)
                random_selection.append([name, selection])
            #paragraph_example_wordsearch(selected_text)
            #join text
            selected_text= "####".join(paragraphs6)
            #calculate number of words
            numwordstotal = len(selected_text.split())
            #write out full document
            with open(results + re.sub(".xml", ".txt", name), "w") as text_file:
                _=text_file.write(selected_text)
            #iterate through paragraphs and write file
            for p, paragraph in enumerate(paragraphs6):
                #length of paragraph
                numwordspara = len(paragraph)
                #put results in a dict
                resultsdict= {'Filename': name, "Paragraph": p, 'RecordTitle': id, 'Date': date, "Date1": datenum, 'Year': year, 'URL': url, 'CompanyName': company.encode('utf-8'), 'NAIC': naics, 'ClassCode': code, 'Classification': classic.encode('utf-8'), 'AnrAssetDispIdxNum': anasd, 'numwordstotal': numwordstotal, 'numwordsparagraph': numwordspara, 'num_paragraphs_prespellcheck': n_paragraphs_pre, 'num_paragraphs_postspellcheck': n_paragraphs_post}
                #write to metadata file
                writer.writerow(resultsdict)
                #write out selected text
                filenm = re.sub(".xml", "", name)
                pname = filenm + "_P" + str(p) + ".txt"
                with open(results_paragraphs + pname, "w") as text_file2:
                    _=text_file2.write(paragraph)
            print(str(i), name, "Written")
            i+=1
# Out:
# 1 88201676.xml Written
# 2 88179860.xml Written
# 3 88198679.xml Written
# 4 88190194.xml Written
# 5 88178029.xml Written
# 6 88198719.xml Written
# 7 88177949.xml Written
# 8 88180180.xml Written
# 9 88205316.xml Written
# 10 88180349.xml Written
# 11 88203156.xml Written
# 12 88179900.xml Written
# 13 88179100.xml Written
# 14 88178669.xml No results returned
# 14 88175669.xml Written
# 15 88197156.xml Written
# 16 88177269.xml No results returned
# 16 88201519.xml Written
# 17 88193154.xml Written
# 18 88200119.xml Written
# 19 88179620.xml Written
# 20 88176989.xml No results returned
# 20 88178229.xml No results returned
# 20 88191354.xml Written
# 21 88179420.xml Written
# 22 88197999.xml Written
# 23 88176869.xml Written
# 24 88189354.xml Written
# 25 88175429.xml Written
# 26 88204516.xml Written
# 27 88178909.xml Written
# 28 88173700.xml Written
# 29 88180420.xml No results returned
# 29 88177220.xml Written
# 30 88176909.xml Written
# 31 88174700.xml Written
# 32 88180900.xml Written
# 33 88175509.xml Written
# 34 88178069.xml Written
# 35 88180389.xml Written
# 36 88176020.xml Written
# 37 88201279.xml Written
# 38 88173669.xml Written
# 39 88177869.xml Written
# 40 88178540.xml Written
# 41 88178060.xml Written
# 42 88177509.xml Written
# 43 88175060.xml Written
# 44 88175380.xml Written
# 45 88175469.xml No results returned
# 45 88176900.xml Written
# 46 88173589.xml Written
# 47 88176060.xml Written
# 48 88173829.xml Written
# 49 88178864.xml Written
# 50 88173949.xml Written
# 51 88178989.xml Written
# 52 88179829.xml Written
# 53 88180429.xml Written
# 54 88180260.xml Written
# 55 88173900.xml No results returned
# 55 88176140.xml Written
# 56 88179069.xml Written
# 57 88178709.xml No results returned
# 57 88174829.xml Written
# 58 88204121.xml Written
# 59 88184117.xml Written
# 60 88180837.xml Written
# 61 88198041.xml Written
# 62 88214841.xml Written
# 63 88179758.xml Written
# 64 88198721.xml Written
# 65 88177118.xml No results returned
# 65 88207241.xml Written
# 66 88178518.xml No results returned
# 66 88197241.xml Written
# 67 88177318.xml No results returned
# 67 88202521.xml Written
# 68 88200041.xml Written
# 69 88180358.xml Written
# 70 88179798.xml Written
# 71 88208881.xml Written
# 72 88175638.xml Written
# 73 88204881.xml Written
# 74 88202201.xml Written
# 75 88181838.xml Written
# 76 88180317.xml No results returned
# 76 88207601.xml Written
# 77 88198524.xml Written
# 78 88176557.xml Written
# 79 88192359.xml No results returned
# 79 88214921.xml Written
# 80 88203041.xml Written
# 81 88197804.xml Written
# 82 88203001.xml Written
# 83 88195694.xml Written
# 84 88197891.xml Written
# 85 88205691.xml Written
# 86 88201171.xml Written
# 87 88201331.xml Written
# 88 88194654.xml Written
# 89 88197411.xml Written
# 90 88192294.xml No results returned
# 90 88206331.xml Written
# 91 88204251.xml Written
# 92 88196334.xml Written
# 93 88198254.xml Written
# 94 88196131.xml Written
# 95 88198091.xml Written
# 96 88191374.xml Written
# 97 88192934.xml Written
# 98 88192574.xml Written
# 99 88199971.xml Written
# 100 88194611.xml Written
# 101 88190654.xml Written
# 102 88207531.xml Written
# 103 88200411.xml Written
# 104 88196934.xml Written
# 105 88204651.xml Written
# 106 88196451.xml Written
# 107 88206451.xml Written
# 108 88193891.xml Written
# 109 88197691.xml Written
# 110 88205531.xml Written
# 111 88193851.xml Written
# 112 88201971.xml Written
# 113 88194331.xml Written
# 114 88202251.xml Written
# 115 88231151.xml Written
# 116 88197524.xml Written
# 117 88173312.xml No results returned
# 117 88213514.xml Written
# 118 88173675.xml Written
# 119 88214866.xml Written
# 120 88196484.xml Written
# 121 88225394.xml Written
# 122 88175996.xml No results returned
# 122 88203564.xml Written
# 123 88201609.xml Written
# 124 88201368.xml Written
# 125 88198353.xml Written
# 126 88220434.xml Written
# 127 88175523.xml Written
# 128 88177703.xml Written
# 129 88179074.xml Written
# 130 88175623.xml Written
# 131 88191078.xml Written
# 132 88185155.xml No results returned
# 132 88229351.xml Written
# 133 88201008.xml Written
# 134 88193521.xml Written
# 135 88207624.xml Written
# 136 88193561.xml Written
# 137 88175674.xml Written
# 138 88172836.xml No results returned
# 138 88189470.xml Written
# 139 88173756.xml No results returned
# 139 88179463.xml Written
# 140 88200246.xml Written
# 141 88189350.xml No results returned
# 141 88182310.xml Written
# 142 88198033.xml Written
# 143 88207604.xml Written
# 144 88172872.xml Written
# 145 88207946.xml Written
# 146 88189070.xml Written
# 147 88195241.xml Written
# 148 88174476.xml Written
# 149 88179022.xml Written
# 150 88219081.xml Written
# 151 88202444.xml Written
# 152 88203488.xml Written
# 153 88173558.xml Written
# 154 88200766.xml Written
# 155 88186355.xml Written
# 156 88224706.xml Written
# 157 88216746.xml Written
# 158 88186715.xml Written
# 159 88187910.xml No results returned
# 159 88176270.xml Written
# 160 88186310.xml No results returned
# 160 88194521.xml Written
# 161 88202606.xml Written
# 162 88229874.xml Written
# 163 88190284.xml Written
# 164 88200326.xml Written
# 165 88172875.xml Written
# 166 88187915.xml Written
# 167 88173317.xml Written
# 168 88229194.xml Written
# 169 88184955.xml No results returned
# 169 88178823.xml Written
# 170 88195793.xml Written
# 171 88200206.xml Written
# 172 88173676.xml Written
# 173 88172710.xml Written
# 174 88188063.xml Written
# 175 88176342.xml Written
# 176 88173116.xml No results returned
# 176 88195564.xml Written
# 177 88212961.xml Written
# 178 88187943.xml Written
# 179 88175883.xml No results returned
# 179 88203528.xml Written
# 180 88199524.xml Written
# 181 88194681.xml Written
# 182 88175077.xml No results returned
# 182 88175150.xml No results returned
# 182 88175550.xml Written
# 183 88180542.xml Written
# 184 88173154.xml Written
# 185 88183543.xml Written
# 186 88183670.xml Written
# 187 88173483.xml Written
# 188 88200288.xml Written
# 189 88207641.xml Written
# 190 88209626.xml Written
# 191 88205784.xml Written
# 192 88190431.xml Written
# 193 88203088.xml Written
# 194 88214706.xml Written
# 195 88206146.xml Written
# 196 88221441.xml Written
# 197 88176795.xml Written
# 198 88201681.xml Written
# 199 88174515.xml Written
# 200 88187630.xml Written
# 201 88186278.xml No results returned
# 201 88189750.xml Written
# 202 88196324.xml No results returned
# 202 88189078.xml Written
# 203 88186943.xml Written
# 204 88187183.xml Written
# 205 88206321.xml Written
# 206 88188427.xml Written
# 207 88202046.xml Written
# 208 88196408.xml Written
# 209 88198321.xml Written
# 210 88205964.xml Written
# 211 88173914.xml Written
# 212 88173912.xml No results returned
# 212 88195688.xml Written
# 213 88201208.xml Written
# 214 88205644.xml Written
# 215 88177502.xml Written
# 216 88180703.xml Written
# 217 88180943.xml Written
# 218 88207921.xml Written
# 219 88179062.xml No results returned
# 219 88187587.xml Written
# 220 88207564.xml Written
# 221 88215361.xml Written
# 222 88200444.xml Written
# 223 88204241.xml Written
# 224 88197684.xml Written
# 225 88205328.xml Written
# 226 88174990.xml Written
# 227 88175595.xml Written
# 228 88175675.xml Written
# 229 88191118.xml Written
# 230 88176995.xml No results returned
# 230 88191110.xml Written
# 231 88175350.xml No results returned
# 231 88184422.xml Written
# 232 88212386.xml Written
# 233 88202689.xml Written
# 234 88175232.xml Written
# 235 88206001.xml Written
# 236 88175438.xml No results returned
# 236 88175230.xml Written
# 237 88174552.xml Written
# 238 88189830.xml Written
# 239 88185798.xml Written
# 240 88176155.xml Written
# 241 88191631.xml Written
# 242 88177342.xml No results returned
# 242 88188147.xml Written
# 243 88176083.xml No results returned
# 243 88207664.xml Written
# 244 88206666.xml Written
# 245 88205286.xml Written
# 246 88201481.xml Written
# 247 88201441.xml Written
# 248 88195361.xml Written
# 249 88192558.xml Written
# 250 88212361.xml Written
# 251 88176994.xml Written
# 252 88206364.xml Written
# 253 88204964.xml Written
# 254 88184790.xml No results returned
# 254 88202946.xml Written
# 255 88186712.xml Written
# 256 88204786.xml Written
# 257 88173017.xml Written
# 258 88197720.xml Written
# 259 88191629.xml Written
# 260 88175297.xml Written
# 261 88174016.xml No results returned
# 261 88173975.xml Written
# 262 88182027.xml Written
# 263 88182507.xml Written
# 264 88174735.xml No results returned
# 264 88203782.xml Written
# 265 88200300.xml Written
# 266 88177348.xml Written
# 267 88191874.xml Written
# 268 88179508.xml Written
# 269 88206342.xml Written
# 270 88173610.xml Written
# 271 88206625.xml Written
# 272 88192114.xml Written
# 273 88186342.xml No results returned
# 273 88173417.xml Written
# 274 88195354.xml Written
# 275 88173170.xml No results returned
# 275 88195960.xml Written
# 276 88181228.xml Written
# 277 88195120.xml Written
# 278 88173051.xml Written
# 279 88191834.xml Written
# 280 88172895.xml No results returned
# 280 88214451.xml Written
# 281 88213811.xml Written
# 282 88193074.xml Written
# 283 88208091.xml Written
# 284 88183627.xml Written
# 285 88172699.xml Written
# 286 88183267.xml No results returned
# 286 88174055.xml Written
# 287 88205371.xml Written
# 288 88181268.xml Written
# 289 88201451.xml Written
# 290 88208105.xml Written
# 291 88205942.xml Written
# 292 88208185.xml Written
# 293 88175868.xml No results returned
# 293 88177308.xml No results returned
# 293 88173335.xml No results returned
# 293 88199980.xml Written
# 294 88181307.xml Written
# 295 88190634.xml Written
# 296 88179387.xml No results returned
# 296 88182788.xml Written
# 297 88205611.xml Written
# 298 88191714.xml Written
# 299 88176588.xml No results returned
# 299 88191394.xml Written
# 300 88172977.xml Written
# 301 88176948.xml Written
# 302 88207785.xml Written
# 303 88185707.xml Written
# 304 88182588.xml Written
# 305 88173497.xml No results returned
# 305 88174698.xml Written
# 306 88175932.xml Written
# 307 88177867.xml Written
# 308 88192045.xml Written
# 309 88179708.xml Written
# 310 88205251.xml Written
# 311 88190074.xml Written
# 312 88173091.xml Written
# 313 88173452.xml Written
# 314 88209531.xml Written
# 315 88211385.xml Written
# 316 88197578.xml Written
# 317 88192594.xml Written
# 318 88196098.xml Written
# 319 88173498.xml Written
# 320 88196665.xml Written
# 321 88206102.xml Written
# 322 88172856.xml Written
# 323 88192085.xml Written
# 324 88175577.xml Written
# 325 88192349.xml Written
# 326 88182987.xml Written
# 327 88204265.xml Written
# 328 88182468.xml Written
# 329 88205625.xml Written
# 330 88201011.xml Written
# 331 88181948.xml Written
# 332 88174018.xml Written
# 333 88177428.xml Written
# 334 88174496.xml Written
# 335 88202265.xml Written
# 336 88180068.xml Written
# 337 88173217.xml Written
# 338 88191989.xml Written
# 339 88207582.xml Written
# 340 88209382.xml Written
# 341 88205062.xml Written
# 342 88195825.xml Written
# 343 88175732.xml Written
# 344 88172810.xml Written
# 345 88179588.xml No results returned
# 345 88221091.xml Written
# 346 88208865.xml Written
# 347 88172690.xml No results returned
# 347 88200580.xml Written
# 348 88180227.xml No results returned
# 348 88197580.xml Written
# 349 88175097.xml No results returned
# 349 88193805.xml Written
# 350 88192925.xml Written
# 351 88176228.xml Written
# 352 88205500.xml Written
# 353 88179227.xml Written
# 354 88177708.xml Written
# 355 88196365.xml Written
# 356 88188914.xml Written
# 357 88204029.xml Written
# 358 88199747.xml Written
# 359 88208601.xml Written
# 360 88205481.xml Written
# 361 88206681.xml Written
# 362 88212281.xml Written
# 363 88196881.xml Written
# 364 88203801.xml Written
# 365 88201641.xml Written
# 366 88203521.xml Written
# 367 88205441.xml Written
# 368 88197081.xml Written
# 369 88194764.xml Written
# 370 88207441.xml Written
# 371 88199681.xml Written
# 372 88200561.xml Written
# 373 88194244.xml Written
# 374 88194881.xml Written
# 375 88208401.xml Written
# 376 88194924.xml Written
# 377 88197001.xml Written
# 378 88197124.xml Written
# 379 88195804.xml Written
# 380 88203881.xml Written
# 381 88198841.xml Written
# 382 88199481.xml Written
# 383 88202401.xml Written
# 384 88201201.xml Written
# 385 88180482.xml No results returned
# 385 88197964.xml Written
# 386 88183037.xml Written
# 387 88201801.xml Written
# 388 88202841.xml Written
# 389 88184837.xml Written
# 390 88176838.xml No results returned
# 390 88179598.xml Written
# 391 88197881.xml Written
# 392 88178397.xml No results returned
# 392 88198444.xml Written
# 393 88178718.xml No results returned
# 393 88180078.xml No results returned
# 393 88183158.xml No results returned
# 393 88182797.xml Written
# 394 88176678.xml No results returned
# 394 88182237.xml Written
# 395 88205321.xml Written
# 396 88176558.xml No results returned
# 396 88208521.xml Written
# 397 88178717.xml Written
# 398 88185357.xml Written
# 399 88197284.xml Written
# 400 88178478.xml Written
# 401 88181277.xml Written
# 402 88179197.xml Written
# 403 88201601.xml Written
# 404 88203961.xml Written
# 405 88206161.xml Written
# 406 88177237.xml Written
# 407 88176438.xml No results returned
# 407 88172870.xml No results returned
# 407 88191439.xml Written
# 408 88174477.xml Written
# 409 88180158.xml Written
# 410 88177437.xml No results returned
# 410 88179877.xml Written
# 411 88176878.xml No results returned
# 411 88197764.xml Written
# 412 88174118.xml No results returned
# 412 88199321.xml Written
# 413 88173715.xml Written
# 414 88197444.xml Written
# 415 88198484.xml Written
# 416 88172757.xml Written
# 417 88200961.xml Written
# 418 88185517.xml Written
# 419 88179518.xml No results returned
# 419 88191319.xml Written
# 420 88179158.xml Written
# 421 88173518.xml Written
# 422 88173995.xml Written
# 423 88176837.xml Written
# 424 88200721.xml Written
# 425 88182397.xml Written
# 426 88172751.xml Written
# 427 88174918.xml No results returned
# 427 88181398.xml Written
# 428 88191679.xml Written
# 429 88174158.xml Written
# 430 88172832.xml Written
# 431 88183118.xml Written
# 432 88206481.xml Written
# 433 88173475.xml Written
# 434 88174317.xml Written
# 435 88203561.xml Written
# 436 88174318.xml Written
# 437 88198561.xml Written
# 438 88172631.xml Written
# 439 88184357.xml Written
# 440 88185117.xml Written
# 441 88174396.xml Written
# 442 88180838.xml No results returned
# 442 88174998.xml Written
# 443 88206441.xml Written
# 444 88177838.xml Written
# 445 88172911.xml Written
# 446 88174596.xml Written
# 447 88213001.xml Written
# 448 88174517.xml Written
# 449 88175478.xml Written
# 450 88182978.xml Written
# 451 88178737.xml Written
# 452 88194376.xml No results returned
# 452 88176377.xml Written
# 453 88190979.xml Written
# 454 88181498.xml Written
# 455 88177771.xml No results returned
# 455 88174358.xml Written
# 456 88178651.xml No results returned
# 456 88173992.xml Written
# 457 88174516.xml Written
# 458 88192859.xml Written
# 459 88173915.xml Written
# 460 88188939.xml Written
# 461 88173236.xml Written
# 462 88189459.xml Written
# 463 88174277.xml Written
# 464 88187419.xml Written
# 465 88178091.xml Written
# 466 88188859.xml Written
# 467 88173592.xml Written
# 468 88186059.xml No results returned
# 468 88180778.xml No results returned
# 468 88190539.xml Written
# 469 88178771.xml Written
# 470 88182737.xml Written
# 471 88174038.xml No results returned
# 471 88180337.xml No results returned
# 471 88176218.xml Written
# 472 88176777.xml Written
# 473 88178451.xml Written
# 474 88185816.xml Written
# 475 88184338.xml No results returned
# 475 88173470.xml Written
# 476 88185018.xml Written
# 477 88180377.xml No results returned
# 477 88193856.xml Written
# 478 88185817.xml Written
# 479 88173677.xml Written
# 480 88191659.xml Written
# 481 88173352.xml No results returned
# 481 88177171.xml Written
# 482 88187216.xml Written
# 483 88186097.xml Written
# 484 88190976.xml Written
# 485 88179298.xml Written
# 486 88191059.xml Written
# 487 88190056.xml Written
# 488 88189419.xml Written
# 489 88185337.xml Written
# 490 88179658.xml Written
# 491 88185017.xml No results returned
# 491 88181417.xml Written
# 492 88192016.xml Written
# 493 88191816.xml Written
# 494 88189859.xml Written
# 495 88187296.xml Written
# 496 88178017.xml Written
# 497 88188256.xml Written
# 498 88195216.xml Written
# 499 88177131.xml Written
# 500 88182818.xml Written
# 501 88190496.xml Written
# 502 88178098.xml Written
# 503 88179818.xml Written
# 504 88180938.xml Written
# 505 88178131.xml Written
# 506 88178251.xml Written
# 507 88177257.xml Written
# 508 88179138.xml Written
# 509 88176811.xml No results returned
# 509 88184937.xml Written
# 510 88194176.xml Written
# 511 88180978.xml No results returned
# 511 88188776.xml Written
# 512 88188819.xml Written
# 513 88194336.xml Written
# 514 88175891.xml Written
# 515 88185338.xml Written
# 516 88190419.xml Written
# 517 88188096.xml Written
# 518 88179338.xml Written
# 519 88184818.xml Written
# 520 88176138.xml Written
# 521 88189219.xml Written
# 522 88183818.xml No results returned
# 522 88176058.xml Written
# 523 88182857.xml Written
# 524 88186056.xml Written
# 525 88178378.xml Written
# 526 88180577.xml Written
# 527 88184978.xml Written
# 528 88178458.xml Written
# 529 88178897.xml No results returned
# 529 88183937.xml Written
# 530 88192339.xml Written
# 531 88188056.xml Written
# 532 88192179.xml Written
# 533 88174411.xml Written
# 534 88173971.xml Written
# 535 88192296.xml Written
# 536 88186496.xml Written
# 537 88180897.xml Written
# 538 88182138.xml Written
# 539 88195336.xml Written
# 540 88189216.xml Written
# 541 88185257.xml Written
# 542 88187139.xml Written
# 543 88173131.xml Written
# 544 88173571.xml Written
# 545 88177371.xml Written
# 546 88205756.xml Written
# 547 88209476.xml Written
# 548 88224356.xml Written
# 549 88225916.xml Written
# 550 88216596.xml Written
# 551 88176912.xml Written
# 552 88206116.xml Written
# 553 88223676.xml Written
# 554 88207156.xml Written
# 555 88178632.xml Written
# 556 88207076.xml Written
# 557 88218116.xml Written
# 558 88208236.xml Written
# 559 88223996.xml Written
# 560 88207756.xml Written
# 561 88223116.xml Written
# 562 88220916.xml Written
# 563 88222116.xml Written
# 564 88228836.xml Written
# 565 88181913.xml Written
# 566 88228803.xml Written
# 567 88181393.xml No results returned
# 567 88223756.xml Written
# 568 88180352.xml Written
# 569 88180032.xml Written
# 570 88228916.xml Written
# 571 88212916.xml Written
# 572 88223316.xml Written
# 573 88181193.xml Written
# 574 88180913.xml Written
# 575 88206516.xml Written
# 576 88208476.xml Written
# 577 88206076.xml Written
# 578 88223569.xml Written
# 579 88176872.xml No results returned
# 579 88180832.xml Written
# 580 88209196.xml Written
# 581 88223969.xml Written
# 582 88176552.xml No results returned
# 582 88207716.xml Written
# 583 88206196.xml Written
# 584 88231290.xml Written
# 585 88216556.xml Written
# 586 88212796.xml Written
# 587 88230046.xml Written
# 588 88205876.xml Written
# 589 88229130.xml Written
# 590 88216996.xml Written
# 591 88178792.xml Written
# 592 88176792.xml Written
# 593 88179992.xml Written
# 594 88178552.xml Written
# 595 88230736.xml Written
# 596 88181633.xml Written
# 597 88206436.xml Written
# 598 88180392.xml Written
# 599 88176512.xml Written
# 600 88215031.xml Written
# 601 88201598.xml Written
# 602 88175867.xml Written
# 603 88175387.xml No results returned
# 603 88175346.xml Written
# 604 88174184.xml No results returned
# 604 88213631.xml Written
# 605 88175347.xml Written
# 606 88174220.xml Written
# 607 88175102.xml Written
# 608 88199754.xml Written
# 609 88206311.xml Written
# 610 88178980.xml Written
# 611 88195638.xml Written
# 612 88172929.xml Written
# 613 88201634.xml Written
# 614 88175900.xml No results returned
# 614 88176904.xml Written
# 615 88173860.xml Written
# 616 88211231.xml Written
# 617 88174747.xml Written
# 618 88207591.xml Written
# 619 88211511.xml Written
# 620 88177340.xml Written
# 621 88177265.xml No results returned
# 621 88175260.xml Written
# 622 88172664.xml Written
# 623 88173446.xml Written
# 624 88176864.xml Written
# 625 88197718.xml Written
# 626 88195918.xml Written
# 627 88199878.xml Written
# 628 88176333.xml No results returned
# 628 88182112.xml No results returned
# 628 88190957.xml Written
# 629 88190136.xml Written
# 630 88192736.xml No results returned
# 630 88177453.xml No results returned
# 630 88183218.xml Written
# 631 88214598.xml Written
# 632 88183154.xml Written
# 633 88188793.xml Written
# 634 88200557.xml Written
# 635 88188296.xml Written
# 636 88208558.xml Written
# 637 88179714.xml Written
# 638 88224038.xml Written
# 639 88198997.xml Written
# 640 88194416.xml Written
# 641 88188033.xml Written
# 642 88194016.xml Written
# 643 88179898.xml No results returned
# 643 88182479.xml Written
# 644 88181338.xml Written
# 645 88207518.xml Written
# 646 88219158.xml Written
# 647 88202978.xml Written
# 648 88205814.xml Written
# 649 88181738.xml No results returned
# 649 88208494.xml Written
# 650 88186197.xml Written
# 651 88229078.xml Written
# 652 88189536.xml No results returned
# 652 88182872.xml Written
# 653 88186397.xml Written
# 654 88207694.xml Written
# 655 88203574.xml Written
# 656 88180818.xml No results returned
# 656 88204014.xml Written
# 657 88183993.xml Written
# 658 88173173.xml Written
# 659 88199397.xml Written
# 660 88184698.xml Written
# 661 88180674.xml Written
# 662 88206774.xml Written
# 663 88184658.xml Written
# 664 88195357.xml Written
# 665 88203774.xml Written
# 666 88183992.xml No results returned
# 666 88199357.xml Written
# 667 88191416.xml Written
# 668 88183193.xml Written
# 669 88182578.xml Written
# 670 88213718.xml Written
# 671 88193016.xml Written
# 672 88208174.xml Written
# 673 88186473.xml Written
# 674 88207614.xml Written
# 675 88194256.xml Written
# 676 88179133.xml No results returned
# 676 88199797.xml Written
# 677 88203258.xml Written
# 678 88192856.xml Written
# 679 88186136.xml Written
# 680 88191677.xml Written
# 681 88181378.xml Written
# 682 88176773.xml Written
# 683 88211678.xml Written
# 684 88182098.xml Written
# 685 88177613.xml Written
# 686 88205098.xml Written
# 687 88191233.xml Written
# 688 88173213.xml Written
# 689 88183316.xml No results returned
# 689 88205334.xml Written
# 690 88184873.xml Written
# 691 88221598.xml Written
# 692 88189717.xml Written
# 693 88188117.xml Written
# 694 88204054.xml Written
# 695 88208638.xml Written
# 696 88218318.xml Written
# 697 88198677.xml Written
# 698 88175251.xml No results returned
# 698 88205178.xml Written
# 699 88186176.xml Written
# 700 88195757.xml Written
# 701 88204298.xml Written
# 702 88184392.xml Written
# 703 88176973.xml Written
# 704 88207854.xml Written
# 705 88183872.xml Written
# 706 88183034.xml Written
# 707 88181432.xml Written
# 708 88208998.xml Written
# 709 88185273.xml Written
# 710 88185912.xml Written
# 711 88190193.xml Written
# 712 88191157.xml Written
# 713 88203654.xml Written
# 714 88188456.xml Written
# 715 88186957.xml Written
# 716 88180213.xml Written
# 717 88226158.xml Written
# 718 88222038.xml Written
# 719 88191317.xml Written
# 720 88181039.xml Written
# 721 88180298.xml Written
# 722 88183113.xml Written
# 723 88190033.xml Written
# 724 88180218.xml No results returned
# 724 88174772.xml No results returned
# 724 88185163.xml Written
# 725 88189915.xml Written
# 726 88198074.xml Written
# 727 88186082.xml Written
# 728 88192430.xml Written
# 729 88197274.xml Written
# 730 88174650.xml No results returned
# 730 88189123.xml Written
# 731 88183642.xml Written
# 732 88196234.xml Written
# 733 88197070.xml Written
# 734 88183403.xml Written
# 735 88188927.xml Written
# 736 88194470.xml Written
# 737 88193634.xml Written
# 738 88205036.xml Written
# 739 88186807.xml Written
# 740 88173374.xml Written
# 741 88187323.xml Written
# 742 88195475.xml Written
# 743 88194110.xml No results returned
# 743 88175574.xml Written
# 744 88189795.xml Written
# 745 88194235.xml Written
# 746 88194430.xml Written
# 747 88176290.xml Written
# 748 88190994.xml No results returned
# 748 88174010.xml No results returned
# 748 88188714.xml Written
# 749 88196751.xml Written
# 750 88194475.xml Written
# 751 88197591.xml Written
# 752 88184883.xml No results returned
# 752 88195351.xml Written
# 753 88184122.xml Written
# 754 88205516.xml Written
# 755 88193790.xml Written
# 756 88203436.xml Written
# 757 88184643.xml Written
# 758 88175290.xml No results returned
# 758 88195434.xml Written
# 759 88191315.xml Written
# 760 88175694.xml No results returned
# 760 88191594.xml Written
# 761 88196115.xml Written
# 762 88187843.xml Written
# 763 88183402.xml Written
# 764 88193990.xml Written
# 765 88184682.xml Written
# 766 88189287.xml Written
# 767 88175497.xml No results returned
# 767 88193151.xml No results returned
# 767 88184922.xml Written
# 768 88188834.xml Written
# 769 88196954.xml Written
# 770 88174977.xml Written
# 771 88186563.xml Written
# 772 88174454.xml Written
# 773 88192750.xml Written
# 774 88176736.xml No results returned
# 774 88194070.xml Written
# 775 88192434.xml Written
# 776 88175617.xml No results returned
# 776 88188127.xml Written
# 777 88204836.xml Written
# 778 88174814.xml No results returned
# 778 88204996.xml Written
# 779 88175854.xml Written
# 780 88195111.xml Written
# 781 88187443.xml Written
# 782 88192635.xml Written
# 783 88178454.xml No results returned
# 783 88202118.xml Written
# 784 88187310.xml Written
# 785 88183379.xml Written
# 786 88205472.xml Written
# 787 88198678.xml Written
# 788 88220113.xml Written
# 789 88217833.xml Written
# 790 88187819.xml Written
# 791 88200478.xml Written
# 792 88208924.xml Written
# 793 88200274.xml Written
# 794 88183950.xml Written
# 795 88186725.xml Written
# 796 88196963.xml No results returned
# 796 88186750.xml Written
# 797 88196592.xml Written
# 798 88218644.xml Written
# 799 88196392.xml Written
# 800 88193283.xml Written
# 801 88200032.xml Written
# 802 88199434.xml Written
# 803 88208644.xml Written
# 804 88186339.xml Written
# 805 88186270.xml Written
# 806 88186734.xml No results returned
# 806 88186845.xml Written
# 807 88224684.xml Written
# 808 88190499.xml Written
# 809 88185854.xml Written
# 810 88200394.xml Written
# 811 88194923.xml Written
# 812 88201918.xml Written
# 813 88195763.xml Written
# 814 88214153.xml Written
# 815 88184654.xml Written
# 816 88232361.xml Written
# 817 88179374.xml Written
# 818 88192843.xml Written
# 819 88213393.xml Written
# 820 88204232.xml Written
# 821 88193723.xml Written
# 822 88200392.xml Written
# 823 88184816.xml Written
# 824 88196043.xml No results returned
# 824 88205075.xml Written
# 825 88204115.xml Written
# 826 88197392.xml Written
# 827 88195643.xml Written
# 828 88203192.xml Written
# 829 88189518.xml Written
# 830 88189798.xml Written
# 831 88199312.xml Written
# 832 88187005.xml Written
# 833 88231164.xml Written
# 834 88204194.xml Written
# 835 88180457.xml Written
# 836 88177777.xml No results returned
# 836 88176897.xml Written
# 837 88180174.xml Written
# 838 88202438.xml Written
# 839 88190758.xml Written
# 840 88214233.xml Written
# 841 88186678.xml Written
# 842 88192963.xml Written
# 843 88197123.xml Written
# 844 88198598.xml Written
# 845 88192118.xml Written
# 846 88198672.xml Written
# 847 88193523.xml Written
# 848 88188099.xml Written
# 849 88187958.xml Written
# 850 88220553.xml Written
# 851 88183979.xml No results returned
# 851 88206152.xml Written
# 852 88205352.xml Written
# 853 88213433.xml Written
# 854 88221004.xml Written
# 855 88191878.xml Written
# 856 88182174.xml No results returned
# 856 88197312.xml Written
# 857 88225547.xml Written
# 858 88214032.xml Written
# 859 88230232.xml Written
# 860 88229435.xml Written
# 861 88216072.xml Written
# 862 88216272.xml Written
# 863 88206432.xml Written
# 864 88230195.xml Written
# 865 88229115.xml Written
# 866 88218991.xml Written
# 867 88229235.xml Written
# 868 88220512.xml Written
# 869 88200754.xml Written
# 870 88221831.xml Written
# 871 88217112.xml Written
# 872 88193465.xml Written
# 873 88229307.xml Written
# 874 88206832.xml Written
# 875 88211351.xml Written
# 876 88207392.xml Written
# 877 88230832.xml Written
# 878 88194305.xml Written
# 879 88200598.xml Written
# 880 88220995.xml Written
# 881 88230667.xml Written
# 882 88195185.xml Written
# 883 88230312.xml Written
# 884 88218151.xml Written
# 885 88218631.xml Written
# 886 88205591.xml Written
# 887 88223675.xml Written
# 888 88211595.xml Written
# 889 88229632.xml Written
# 890 88225755.xml Written
# 891 88188865.xml Written
# 892 88211626.xml Written
# 893 88192831.xml Written
# 894 88188598.xml Written
# 895 88184521.xml Written
# 896 88186841.xml Written
# 897 88182240.xml Written
# 898 88188718.xml Written
# 899 88173673.xml No results returned
# 899 88182840.xml Written
# 900 88172989.xml Written
# 901 88201358.xml Written
# 902 88187641.xml Written
# 903 88185590.xml Written
# 904 88178622.xml No results returned
# 904 88207914.xml Written
# 905 88179502.xml Written
# 906 88185950.xml Written
# 907 88182601.xml No results returned
# 907 88178902.xml No results returned
# 907 88192678.xml Written
# 908 88182920.xml Written
# 909 88191038.xml Written
# 910 88206556.xml Written
# 911 88203354.xml Written
# 912 88176463.xml Written
# 913 88202034.xml Written
# 914 88192401.xml Written
# 915 88183161.xml Written
# 916 88182561.xml No results returned
# 916 88195318.xml Written
# 917 88173466.xml Written
# 918 88227266.xml Written
# 919 88176462.xml Written
# 920 88183510.xml Written
# 921 88179233.xml Written
# 922 88192151.xml Written
# 923 88203554.xml Written
# 924 88182241.xml Written
# 925 88192471.xml Written
# 926 88202358.xml Written
# 927 88180903.xml Written
# 928 88182103.xml Written
# 929 88193319.xml Written
# 930 88202198.xml Written
# 931 88173782.xml Written
# 932 88174828.xml Written
# 933 88183550.xml No results returned
# 933 88173866.xml Written
# 934 88204634.xml Written
# 935 88192231.xml Written
# 936 88208356.xml Written
# 937 88179143.xml No results returned
# 937 88187950.xml Written
# 938 88190320.xml Written
# 939 88184200.xml Written
# 940 88176103.xml No results returned
# 940 88192391.xml Written
# 941 88209986.xml Written
# 942 88191591.xml Written
# 943 88184201.xml Written
# 944 88177632.xml Written
# 945 88218676.xml Written
# 946 88181952.xml No results returned
# 946 88179152.xml Written
# 947 88183192.xml Written
# 948 88185352.xml Written
# 949 88177672.xml No results returned
# 949 88184512.xml Written
# 950 88177512.xml Written
# 951 88213996.xml Written
# 952 88205828.xml Written
# 953 88185424.xml Written
# 954 88202076.xml Written
# 955 88182464.xml Written
# 956 88191507.xml Written
# 957 88184333.xml Written
# 958 88197843.xml Written
# 959 88197195.xml Written
# 960 88221547.xml Written
# 961 88207587.xml Written
# 962 88187810.xml Written
# 963 88183572.xml Written
# 964 88198910.xml Written
# 965 88201602.xml Written
# 966 88200682.xml Written
# 967 88195756.xml Written
# 968 88189978.xml No results returned
# 968 88189467.xml Written
# 969 88192743.xml Written
# 970 88187450.xml Written
# 971 88188658.xml Written
# 972 88192063.xml Written
# 973 88198519.xml Written
# 974 88186507.xml Written
# 975 88213907.xml Written
# 976 88199116.xml Written
# 977 88186618.xml Written
# 978 88195118.xml Written
# 979 88183264.xml Written
# 980 88199656.xml Written
# 981 88203845.xml Written
# 982 88203019.xml Written
# 983 88229621.xml Written
# 984 88189227.xml Written
# 985 88225696.xml Written
# 986 88195419.xml Written
# 987 88194983.xml Written
# 988 88186210.xml Written
# 989 88205282.xml Written
# 990 88195639.xml Written
# 991 88188344.xml Written
# 992 88179212.xml Written
# 993 88191840.xml Written
# 994 88192347.xml Written
# 995 88190298.xml Written
# 996 88202876.xml Written
# 997 88192005.xml Written
# 998 88200563.xml Written
# 999 88193659.xml Written
# 1000 88207668.xml Written
# 1001 88189298.xml Written
# 1002 88186022.xml Written
# 1003 88186389.xml Written
# 1004 88189667.xml Written
# 1005 88196176.xml Written
# 1006 88224347.xml Written
# 1007 88176372.xml No results returned
# 1007 88194943.xml Written
# 1008 88208107.xml Written
# 1009 88200319.xml Written
# 1010 88186698.xml Written
# 1011 88200499.xml Written
# 1012 88199543.xml Written
# 1013 88198259.xml Written
# 1014 88186229.xml Written
# 1015 88195776.xml Written
# 1016 88185463.xml Written
# 1017 88198623.xml Written
# 1018 88196383.xml Written
# 1019 88189587.xml Written
# 1020 88176627.xml No results returned
# 1020 88230767.xml Written
# 1021 88192103.xml Written
# 1022 88198359.xml Written
# 1023 88208365.xml Written
# 1024 88198419.xml Written
# 1025 88190347.xml Written
# 1026 88218110.xml Written
# 1027 88190330.xml No results returned
# 1027 88184813.xml Written
# 1028 88229901.xml Written
# 1029 88184532.xml Written
# 1030 88195458.xml Written
# 1031 88183829.xml Written
# 1032 88187290.xml Written
# 1033 88186450.xml Written
# 1034 88186029.xml Written
# 1035 88190789.xml Written
# 1036 88230021.xml Written
# 1037 88193699.xml Written
# 1038 88188463.xml Written
# 1039 88230367.xml Written
# 1040 88183944.xml Written
# 1041 88186149.xml Written
# 1042 88188703.xml Written
# 1043 88178652.xml Written
# 1044 88206828.xml Written
# 1045 88229424.xml Written
# 1046 88198190.xml Written
# 1047 88196379.xml Written
# 1048 88200316.xml Written
# 1049 88232119.xml Written
# 1050 88186383.xml Written
# 1051 88198579.xml Written
# 1052 88190578.xml Written
# 1053 88198039.xml Written
# 1054 88182863.xml No results returned
# 1054 88177347.xml No results returned
# 1054 88189707.xml Written
# 1055 88226216.xml Written
# 1056 88181024.xml Written
# 1057 88195115.xml Written
# 1058 88187130.xml Written
# 1059 88186183.xml Written
# 1060 88208227.xml Written
# 1061 88206187.xml Written
# 1062 88201196.xml Written
# 1063 88189429.xml Written
# 1064 88198418.xml Written
# 1065 88216797.xml Written
# 1066 88195880.xml Written
# 1067 88175695.xml Written
# 1068 88230517.xml Written
# 1069 88174012.xml No results returned
# 1069 88175295.xml Written
# 1070 88224517.xml Written
# 1071 88173732.xml No results returned
# 1071 88200211.xml Written
# 1072 88191710.xml Written
# 1073 88197545.xml Written
# 1074 88211811.xml Written
# 1075 88195738.xml Written
# 1076 88194605.xml Written
# 1077 88174252.xml Written
# 1078 88174532.xml Written
# 1079 88203731.xml Written
# 1080 88224077.xml Written
# 1081 88197905.xml Written
# 1082 88174896.xml No results returned
# 1082 88230197.xml Written
# 1083 88199240.xml Written
# 1084 88191870.xml Written
# 1085 88221357.xml Written
# 1086 88174295.xml Written
# 1087 88198120.xml Written
# 1088 88204700.xml Written
# 1089 88190355.xml Written
# 1090 88218411.xml Written
# 1091 88204300.xml Written
# 1092 88176097.xml Written
# 1093 88196858.xml Written
# 1094 88199360.xml Written
# 1095 88226517.xml Written
# 1096 88173937.xml No results returned
# 1096 88224317.xml Written
# 1097 88204460.xml Written
# 1098 88174376.xml Written
# 1099 88198685.xml Written
# 1100 88199414.xml Written
# 1101 88200811.xml Written
# 1102 88229757.xml Written
# 1103 88195480.xml Written
# 1104 88199160.xml Written
# 1105 88215491.xml Written
# 1106 88218277.xml Written
# 1107 88175735.xml Written
# 1108 88175540.xml Written
# 1109 88176464.xml Written
# 1110 88176986.xml No results returned
# 1110 88175506.xml Written
# 1111 88176425.xml No results returned
# 1111 88176146.xml Written
# 1112 88177304.xml No results returned
# 1112 88174744.xml Written
# 1113 88175865.xml Written
# 1114 88178304.xml No results returned
# 1114 88178384.xml Written
# 1115 88175225.xml Written
# 1116 88177745.xml No results returned
# 1116 88174584.xml Written
# 1117 88173780.xml Written
# 1118 88174820.xml No results returned
# 1118 88176220.xml Written
# 1119 88176345.xml Written
# 1120 88174300.xml Written
# 1121 88176465.xml No results returned
# 1121 88175145.xml Written
# 1122 88175466.xml No results returned
# 1122 88174824.xml No results returned
# 1122 88176705.xml No results returned
# 1122 88176062.xml No results returned
# 1122 88175224.xml Written
# 1123 88173620.xml Written
# 1124 88176624.xml Written
# 1125 88175265.xml Written
# 1126 88175186.xml Written
# 1127 88176184.xml Written
# 1128 88177585.xml No results returned
# 1128 88174985.xml No results returned
# 1128 88199055.xml Written
# 1129 88201375.xml Written
# 1130 88199530.xml Written
# 1131 88182081.xml No results returned
# 1131 88184841.xml Written
# 1132 88183187.xml Written
# 1133 88179948.xml No results returned
# 1133 88207676.xml Written
# 1134 88200815.xml Written
# 1135 88192429.xml Written
# 1136 88178752.xml Written
# 1137 88189201.xml Written
# 1138 88178913.xml No results returned
# 1138 88182353.xml Written
# 1139 88224956.xml Written
# 1140 88185281.xml No results returned
# 1140 88185232.xml Written
# 1141 88179268.xml Written
# 1142 88199970.xml Written
# 1143 88184592.xml Written
# 1144 88182392.xml No results returned
# 1144 88176081.xml No results returned
# 1144 88232137.xml Written
# 1145 88182032.xml Written
# 1146 88184121.xml Written
# 1147 88182393.xml Written
# 1148 88179632.xml Written
# 1149 88188641.xml Written
# 1150 88213796.xml Written
# 1151 88188226.xml Written
# 1152 88200050.xml Written
# 1153 88200975.xml Written
# 1154 88181353.xml Written
# 1155 88185108.xml Written
# 1156 88176952.xml Written
# 1157 88177387.xml No results returned
# 1157 88197250.xml Written
# 1158 88180921.xml No results returned
# 1158 88214756.xml Written
# 1159 88180512.xml Written
# 1160 88207516.xml Written
# 1161 88197770.xml Written
# 1162 88179193.xml Written
# 1163 88180593.xml Written
# 1164 88207916.xml Written
# 1165 88194166.xml Written
# 1166 88197335.xml Written
# 1167 88184681.xml Written
# 1168 88212596.xml Written
# 1169 88200895.xml Written
# 1170 88180201.xml Written
# 1171 88181387.xml Written
# 1172 88214036.xml Written
# 1173 88182708.xml Written
# 1174 88182593.xml Written
# 1175 88204930.xml Written
# 1176 88177232.xml Written
# 1177 88212196.xml Written
# 1178 88176472.xml Written
# 1179 88184027.xml Written
# 1180 88180872.xml Written
# 1181 88203130.xml Written
# 1182 88177907.xml Written
# 1183 88173201.xml Written
# 1184 88179921.xml No results returned
# 1184 88176628.xml No results returned
# 1184 88207316.xml Written
# 1185 88185946.xml Written
# 1186 88207116.xml Written
# 1187 88195206.xml Written
# 1188 88184188.xml Written
# 1189 88187812.xml Written
# 1190 88183801.xml Written
# 1191 88198255.xml Written
# 1192 88182033.xml Written
# 1193 88201615.xml Written
# 1194 88185587.xml Written
# 1195 88202055.xml Written
# 1196 88208036.xml Written
# 1197 88186740.xml Written
# 1198 88205201.xml Written
# 1199 88189468.xml Written
# 1200 88194444.xml Written
# 1201 88206361.xml Written
# 1202 88189420.xml Written
# 1203 88197761.xml Written
# 1204 88196924.xml Written
# 1205 88187740.xml Written
# 1206 88197244.xml Written
# 1207 88191221.xml Written
# 1208 88197161.xml Written
# 1209 88182380.xml Written
# 1210 88185020.xml Written
# 1211 88195001.xml Written
# 1212 88189140.xml Written
# 1213 88203081.xml Written
# 1214 88193601.xml Written
# 1215 88194761.xml Written
# 1216 88189708.xml Written
# 1217 88206241.xml Written
# 1218 88207761.xml Written
# 1219 88222793.xml Written
# 1220 88174327.xml No results returned
# 1220 88174487.xml Written
# 1221 88217030.xml Written
# 1222 88172842.xml Written
# 1223 88174522.xml Written
# 1224 88175887.xml No results returned
# 1224 88173888.xml Written
# 1225 88224192.xml Written
# 1226 88212230.xml Written
# 1227 88230192.xml Written
# 1228 88222232.xml Written
# 1229 88175288.xml No results returned
# 1229 88177925.xml No results returned
# 1229 88175165.xml Written
# 1230 88214155.xml Written
# 1231 88207230.xml Written
# 1232 88222952.xml Written
# 1233 88213230.xml Written
# 1234 88173244.xml Written
# 1235 88175326.xml Written
# 1236 88173484.xml Written
# 1237 88174045.xml Written
# 1238 88173087.xml Written
# 1239 88220352.xml Written
# 1240 88225195.xml Written
# 1241 88214072.xml Written
# 1242 88206510.xml Written
# 1243 88173527.xml Written
# 1244 88175368.xml Written
# 1245 88174927.xml Written
# 1246 88216270.xml Written
# 1247 88207870.xml Written
# 1248 88175647.xml No results returned
# 1248 88230032.xml Written
# 1249 88221672.xml Written
# 1250 88175568.xml No results returned
# 1250 88177885.xml No results returned
# 1250 88173447.xml Written
# 1251 88214235.xml Written
# 1252 88174326.xml Written
# 1253 88174448.xml Written
# 1254 88175846.xml Written
# 1255 88231552.xml Written
# 1256 88220435.xml Written
# 1257 88221590.xml Written
# 1258 88216030.xml Written
# 1259 88220875.xml Written
# 1260 88174882.xml Written
# 1261 88213915.xml Written
# 1262 88231075.xml Written
# 1263 88179744.xml No results returned
# 1263 88192944.xml Written
# 1264 88177986.xml Written
# 1265 88180771.xml Written
# 1266 88230870.xml Written
# 1267 88188489.xml Written
# 1268 88180178.xml No results returned
# 1268 88181458.xml Written
# 1269 88189824.xml Written
# 1270 88193136.xml Written
# 1271 88189784.xml Written
# 1272 88195707.xml Written
# 1273 88184346.xml Written
# 1274 88179709.xml No results returned
# 1274 88197680.xml Written
# 1275 88176269.xml No results returned
# 1275 88195645.xml Written
# 1276 88191771.xml Written
# 1277 88193976.xml Written
# 1278 88177258.xml No results returned
# 1278 88175826.xml Written
# 1279 88174851.xml Written
# 1280 88181698.xml Written
# 1281 88177247.xml No results returned
# 1281 88181109.xml Written
# 1282 88187136.xml Written
# 1283 88193424.xml Written
# 1284 88178549.xml Written
# 1285 88190587.xml Written
# 1286 88194104.xml Written
# 1287 88193896.xml Written
# 1288 88192496.xml Written
# 1289 88202069.xml Written
# 1290 88186707.xml Written
# 1291 88189747.xml Written
# 1292 88184783.xml Written
# 1293 88192251.xml Written
# 1294 88200000.xml Written
# 1295 88178784.xml Written
# 1296 88176771.xml Written
# 1297 88175309.xml No results returned
# 1297 88173749.xml Written
# 1298 88179949.xml Written
# 1299 88183903.xml Written
# 1300 88185382.xml Written
# 1301 88184226.xml Written
# 1302 88184418.xml Written
# 1303 88187291.xml Written
# 1304 88182666.xml Written
# 1305 88176144.xml Written
# 1306 88178789.xml Written
# 1307 88180626.xml No results returned
# 1307 88182026.xml Written
# 1308 88180500.xml No results returned
# 1308 88186891.xml Written
# 1309 88193584.xml Written
# 1310 88186971.xml Written
# 1311 88181466.xml Written
# 1312 88179546.xml Written
# 1313 88195827.xml Written
# 1314 88180291.xml Written
# 1315 88203069.xml Written
# 1316 88200125.xml Written
# 1317 88178509.xml Written
# 1318 88179669.xml No results returned
# 1318 88182989.xml Written
# 1319 88175585.xml No results returned
# 1319 88177189.xml No results returned
# 1319 88195085.xml Written
# 1320 88189891.xml No results returned
# 1320 88173064.xml Written
# 1321 88182851.xml Written
# 1322 88174131.xml Written
# 1323 88188103.xml Written
# 1324 88199320.xml Written
# 1325 88185466.xml Written
# 1326 88176109.xml Written
# 1327 88193565.xml Written
# 1328 88178749.xml Written
# 1329 88175571.xml Written
# 1330 88176626.xml No results returned
# 1330 88174771.xml Written
# 1331 88177858.xml Written
# 1332 88201626.xml Written
# 1333 88183069.xml Written
# 1334 88179504.xml Written
# 1335 88190783.xml Written
# 1336 88229559.xml Written
# 1337 88180149.xml Written
# 1338 88177825.xml No results returned
# 1338 88189704.xml Written
# 1339 88178144.xml Written
# 1340 88178826.xml Written
# 1341 88190016.xml Written
# 1342 88177380.xml Written
# 1343 88229593.xml Written
# 1344 88195325.xml Written
# 1345 88177229.xml No results returned
# 1345 88183044.xml Written
# 1346 88200565.xml Written
# 1347 88175451.xml No results returned
# 1347 88189416.xml Written
# 1348 88189783.xml Written
# 1349 88177580.xml Written
# 1350 88189451.xml Written
# 1351 88229239.xml Written
# 1352 88173291.xml Written
# 1353 88193581.xml Written
# 1354 88181146.xml Written
# 1355 88189503.xml Written
# 1356 88199866.xml Written
# 1357 88188731.xml Written
# 1358 88182909.xml Written
# 1359 88183651.xml Written
# 1360 88201186.xml Written
# 1361 88202026.xml Written
# 1362 88187049.xml No results returned
# 1362 88185204.xml Written
# 1363 88180746.xml Written
# 1364 88177346.xml Written
# 1365 88187849.xml No results returned
# 1365 88174589.xml Written
# 1366 88192624.xml Written
# 1367 88187376.xml Written
# 1368 88190609.xml Written
# 1369 88181229.xml Written
# 1370 88187084.xml Written
# 1371 88179106.xml Written
# 1372 88174651.xml Written
# 1373 88188649.xml Written
# 1374 88184009.xml No results returned
# 1374 88182778.xml Written
# 1375 88192864.xml Written
# 1376 88172904.xml Written
# 1377 88190743.xml Written
# 1378 88182549.xml No results returned
# 1378 88181746.xml Written
# 1379 88194656.xml Written
# 1380 88194056.xml Written
# 1381 88193301.xml Written
# 1382 88230390.xml Written
# 1383 88191064.xml Written
# 1384 88177264.xml Written
# 1385 88191176.xml Written
# 1386 88181408.xml Written
# 1387 88191569.xml Written
# 1388 88208926.xml Written
# 1389 88212467.xml Written
# 1390 88177467.xml No results returned
# 1390 88199202.xml Written
# 1391 88178468.xml Written
# 1392 88204442.xml Written
# 1393 88181722.xml Written
# 1394 88205885.xml Written
# 1395 88195425.xml Written
# 1396 88203343.xml Written
# 1397 88193140.xml Written
# 1398 88207263.xml Written
# 1399 88181247.xml No results returned
# 1399 88176188.xml Written
# 1400 88199462.xml Written
# 1401 88225526.xml Written
# 1402 88222806.xml Written
# 1403 88188945.xml Written
# 1404 88182807.xml Written
# 1405 88180208.xml Written
# 1406 88175828.xml Written
# 1407 88179048.xml Written
# 1408 88175908.xml No results returned
# 1408 88178187.xml Written
# 1409 88205783.xml Written
# 1410 88178208.xml Written
# 1411 88207783.xml Written
# 1412 88181687.xml No results returned
# 1412 88192869.xml Written
# 1413 88177868.xml Written
# 1414 88183907.xml Written
# 1415 88192425.xml Written
# 1416 88197122.xml Written
# 1417 88181242.xml Written
# 1418 88205543.xml Written
# 1419 88179628.xml Written
# 1420 88182962.xml Written
# 1421 88211523.xml Written
# 1422 88179947.xml Written
# 1423 88183467.xml Written
# 1424 88180168.xml Written
# 1425 88182927.xml Written
# 1426 88191942.xml Written
# 1427 88180748.xml Written
# 1428 88181348.xml No results returned
# 1428 88178388.xml No results returned
# 1428 88203802.xml Written
# 1429 88191265.xml Written
# 1430 88176242.xml No results returned
# 1430 88183243.xml Written
# 1431 88178508.xml Written
# 1432 88204343.xml Written
# 1433 88181762.xml Written
# 1434 88195220.xml Written
# 1435 88195585.xml Written
# 1436 88223206.xml Written
# 1437 88178308.xml Written
# 1438 88184327.xml No results returned
# 1438 88191985.xml Written
# 1439 88180087.xml Written
# 1440 88200962.xml Written
# 1441 88181947.xml Written
# 1442 88200742.xml Written
# 1443 88193462.xml Written
# 1444 88207882.xml Written
# 1445 88218187.xml Written
# 1446 88183947.xml Written
# 1447 88192749.xml Written
# 1448 88181748.xml Written
# 1449 88192185.xml Written
# 1450 88181048.xml Written
# 1451 88198822.xml Written
# 1452 88201482.xml Written
# 1453 88206463.xml Written
# 1454 88225307.xml Written
# 1455 88199102.xml Written
# 1456 88207122.xml Written
# 1457 88176388.xml Written
# 1458 88221463.xml Written
# 1459 88221406.xml Written
# 1460 88182528.xml Written
# 1461 88204602.xml Written
# 1462 88184947.xml Written
# 1463 88228347.xml Written
# 1464 88186766.xml No results returned
# 1464 88191669.xml Written
# 1465 88192225.xml Written
# 1466 88194662.xml Written
# 1467 88178248.xml No results returned
# 1467 88192260.xml Written
# 1468 88205882.xml Written
# 1469 88184008.xml Written
# 1470 88194705.xml Written
# 1471 88202162.xml Written
# 1472 88180762.xml Written
# 1473 88220583.xml Written
# 1474 88215533.xml Written
# 1475 88204903.xml Written
# 1476 88228921.xml Written
# 1477 88190348.xml Written
# 1478 88202666.xml Written
# 1479 88184805.xml Written
# 1480 88191384.xml Written
# 1481 88194988.xml Written
# 1482 88204453.xml Written
# 1483 88204106.xml Written
# 1484 88186948.xml Written
# 1485 88227141.xml Written
# 1486 88195883.xml Written
# 1487 88195342.xml Written
# 1488 88188462.xml Written
# 1489 88211884.xml Written
# 1490 88212344.xml Written
# 1491 88192748.xml No results returned
# 1491 88188228.xml Written
# 1492 88198909.xml Written
# 1493 88202829.xml Written
# 1494 88196589.xml Written
# 1495 88216213.xml Written
# 1496 88193661.xml Written
# 1497 88229541.xml Written
# 1498 88206328.xml Written
# 1499 88188045.xml Written
# 1500 88198666.xml Written
# 1501 88211684.xml Written
# 1502 88200172.xml Written
# 1503 88191104.xml No results returned
# 1503 88184385.xml No results returned
# 1503 88203213.xml Written
# 1504 88196426.xml Written
# 1505 88186407.xml Written
# 1506 88196186.xml Written
# 1507 88225656.xml Written
# 1508 88195666.xml Written
# 1509 88195268.xml Written
# 1510 88215904.xml Written
# 1511 88194109.xml Written
# 1512 88193869.xml Written
# 1513 88229544.xml Written
# 1514 88219944.xml Written
# 1515 88186327.xml Written
# 1516 88208983.xml Written
# 1517 88184923.xml Written
# 1518 88197092.xml Written
# 1519 88218448.xml Written
# 1520 88201429.xml Written
# 1521 88219384.xml Written
# 1522 88180665.xml Written
# 1523 88205143.xml Written
# 1524 88179345.xml No results returned
# 1524 88191588.xml Written
# 1525 88193389.xml Written
# 1526 88179505.xml Written
# 1527 88193349.xml Written
# 1528 88222444.xml Written
# 1529 88191087.xml Written
# 1530 88197786.xml Written
# 1531 88226981.xml Written
# 1532 88214744.xml Written
# 1533 88214104.xml Written
# 1534 88198429.xml Written
# 1535 88193548.xml Written
# 1536 88202386.xml Written
# 1537 88211768.xml Written
# 1538 88196264.xml Written
# 1539 88189843.xml Written
# 1540 88229524.xml Written
# 1541 88222848.xml Written
# 1542 88208664.xml Written
# 1543 88190767.xml Written
# 1544 88200626.xml Written
# 1545 88196504.xml Written
# 1546 88196749.xml Written
# 1547 88212743.xml Written
# 1548 88194268.xml Written
# 1549 88190887.xml Written
# 1550 88223821.xml Written
# 1551 88192942.xml Written
# 1552 88187085.xml Written
# 1553 88199066.xml Written
# 1554 88178185.xml Written
# 1555 88183905.xml No results returned
# 1555 88197389.xml Written
# 1556 88194628.xml Written
# 1557 88198549.xml Written
# 1558 88190963.xml Written
# 1559 88197403.xml Written
# 1560 88204148.xml Written
# 1561 88198443.xml Written
# 1562 88207007.xml Written
# 1563 88203108.xml Written
# 1564 88219527.xml Written
# 1565 88204188.xml Written
# 1566 88201083.xml Written
# 1567 88201024.xml Written
# 1568 88221647.xml Written
# 1569 88207704.xml Written
# 1570 88200683.xml Written
# 1571 88205148.xml Written
# 1572 88204904.xml Written
# 1573 88197643.xml Written
# 1574 88201483.xml Written
# 1575 88200304.xml Written
# 1576 88207167.xml Written
# 1577 88203384.xml Written
# 1578 88205508.xml Written
# 1579 88202908.xml Written
# 1580 88203664.xml Written
# 1581 88201908.xml Written
# 1582 88198123.xml Written
# 1583 88200148.xml Written
# 1584 88194643.xml Written
# 1585 88198523.xml Written
# 1586 88204664.xml Written
# 1587 88193643.xml Written
# ...
# 1618 88188565.xml Written
# 1619 88225242.xml Written
# 1620 88185662.xml Written
# 1621 88229327.xml Written
# 1622 88196240.xml Written
# 1623 88189845.xml Written
# 1624 88230882.xml Written
# 1625 88207520.xml Written
# 1626 88187983.xml Written
# 1627 88225845.xml Written
# 1628 88191645.xml Written
# 1629 88183863.xml Written
# 1630 88192600.xml Written
# 1631 88229725.xml Written
# 1632 88228042.xml Written
# 1633 88207200.xml Written
# 1634 88185823.xml Written
# 1635 88195245.xml Written
# 1636 88180182.xml Written
# 1637 88189063.xml Written
# 1638 88224967.xml Written
# 1639 88221725.xml Written
# 1640 88188485.xml No results returned
# 1640 88218122.xml Written
# 1641 88190285.xml Written
# 1642 88189685.xml Written
# 1643 88184888.xml Written
# 1644 88195080.xml Written
# 1645 88212160.xml Written
# 1646 88196600.xml Written
# 1647 88189423.xml No results returned
# 1647 88222925.xml Written
# 1648 88183568.xml Written
# 1649 88184782.xml No results returned
# 1649 88176441.xml Written
# 1650 88190405.xml Written
# 1651 88176942.xml No results returned
# 1651 88198965.xml No results returned
# 1651 88223925.xml Written
# 1652 88221267.xml Written
# 1653 88188985.xml No results returned
# 1653 88207747.xml Written
# 1654 88197585.xml Written
# 1655 88189905.xml No results returned
# 1655 88195265.xml Written
# 1656 88191900.xml Written
# 1657 88214827.xml Written
# 1658 88191820.xml Written
# 1659 88208507.xml Written
# 1660 88199985.xml Written
# 1661 88201665.xml Written
# 1662 88196625.xml Written
# 1663 88202540.xml Written
# 1664 88196620.xml Written
# 1665 88196305.xml Written
# 1666 88202425.xml Written
# 1667 88197420.xml Written
# 1668 88225387.xml Written
# 1669 88188145.xml Written
# 1670 88201140.xml Written
# 1671 88200140.xml Written
# 1672 88194180.xml Written
# 1673 88198023.xml Written
# 1674 88207347.xml Written
# 1675 88198583.xml Written
# 1676 88201340.xml Written
# 1677 88202505.xml Written
# 1678 88196705.xml Written
# 1679 88201460.xml Written
# 1680 88198663.xml Written
# 1681 88196260.xml Written
# 1682 88201745.xml Written
# 1683 88207227.xml Written
# 1684 88194500.xml Written
# 1685 88214107.xml Written
# 1686 88221227.xml Written
# 1687 88197305.xml Written
# 1688 88198183.xml Written
# 1689 88194345.xml Written
# 1690 88202220.xml Written
# 1691 88222707.xml Written
# 1692 88191340.xml Written
# 1693 88189345.xml Written
# 1694 88202185.xml Written
# 1695 88200943.xml Written
# 1696 88198620.xml Written
# 1697 88198825.xml No results returned
# 1697 88194020.xml Written
# 1698 88222987.xml Written
# 1699 88199140.xml Written
# 1700 88224027.xml Written
# 1701 88191940.xml Written
# 1702 88200860.xml Written
# 1703 88188785.xml Written
# 1704 88229507.xml Written
# 1705 88207547.xml Written
# 1706 88230899.xml Written
# 1707 88232016.xml Written
# 1708 88231010.xml Written
# 1709 88230730.xml Written
# 1710 88231619.xml Written
# 1711 88231419.xml Written
# 1712 88229733.xml Written
# 1713 88231173.xml Written
# 1714 88230693.xml Written
# 1715 88224659.xml Written
# 1716 88232213.xml Written
# 1717 88232053.xml Written
# 1718 88229973.xml Written
# 1719 88231456.xml Written
# 1720 88230210.xml Written
# 1721 88230539.xml Written
# 1722 88226009.xml Written
# 1723 88231890.xml Written
# 1724 88229936.xml Written
# 1725 88229090.xml Written
# 1726 88228883.xml Written
# 1727 88229930.xml Written
# 1728 88226890.xml Written
# 1729 88232096.xml Written
# 1730 88230259.xml Written
# 1731 88231686.xml Written
# 1732 88228129.xml Written
# 1733 88229570.xml Written
# 1734 88225363.xml Written
# 1735 88230289.xml Written
# 1736 88230653.xml Written
# 1737 88184634.xml Written
# 1738 88203298.xml Written
# 1739 88180612.xml No results returned
# 1739 88214038.xml Written
# 1740 88178252.xml Written
# 1741 88217336.xml Written
# 1742 88181436.xml Written
# 1743 88180836.xml Written
# 1744 88206694.xml Written
# 1745 88199117.xml Written
# 1746 88203498.xml Written
# 1747 88180559.xml Written
# 1748 88184994.xml Written
# 1749 88179154.xml Written
# 1750 88180519.xml No results returned
# 1750 88206598.xml Written
# 1751 88229158.xml Written
# 1752 88181239.xml Written
# 1753 88185396.xml Written
# 1754 88204098.xml Written
# 1755 88178613.xml No results returned
# 1755 88205498.xml Written
# 1756 88207536.xml Written
# 1757 88220878.xml Written
# 1758 88196677.xml Written
# 1759 88178133.xml Written
# 1760 88180236.xml No results returned
# 1760 88178436.xml Written
# 1761 88225718.xml Written
# 1762 88184394.xml Written
# 1763 88173653.xml No results returned
# 1763 88227118.xml Written
# 1764 88183916.xml No results returned
# 1764 88203898.xml Written
# 1765 88184954.xml Written
# 1766 88200437.xml Written
# 1767 88206734.xml Written
# 1768 88213638.xml Written
# 1769 88183674.xml Written
# 1770 88183634.xml Written
# 1771 88181276.xml Written
# 1772 88179319.xml Written
# 1773 88183234.xml Written
# 1774 88175533.xml No results returned
# 1774 88180354.xml Written
# 1775 88226398.xml Written
# 1776 88195677.xml Written
# 1777 88197197.xml Written
# 1778 88196197.xml Written
# 1779 88180253.xml No results returned
# 1779 88186474.xml Written
# 1780 88182373.xml No results returned
# 1780 88205838.xml Written
# 1781 88199597.xml Written
# 1782 88207216.xml Written
# 1783 88180159.xml No results returned
# 1783 88179274.xml Written
# 1784 88186234.xml Written
# 1785 88183354.xml Written
# 1786 88184396.xml No results returned
# 1786 88174773.xml No results returned
# 1786 88177156.xml No results returned
# 1786 88224376.xml Written
# 1787 88203938.xml Written
# 1788 88178636.xml No results returned
# 1788 88212918.xml Written
# 1789 88177772.xml Written
# 1790 88226078.xml Written
# 1791 88184596.xml Written
# 1792 88207438.xml Written
# 1793 88179279.xml Written
# 1794 88204174.xml Written
# 1795 88181356.xml No results returned
# 1795 88196437.xml Written
# 1796 88178853.xml Written
# 1797 88180919.xml Written
# 1798 88220776.xml Written
# 1799 88181076.xml Written
# 1800 88183076.xml Written
# 1801 88173493.xml Written
# 1802 88221438.xml Written
# 1803 88226838.xml Written
# 1804 88186434.xml Written
# 1805 88182236.xml Written
# 1806 88202974.xml Written
# 1807 88176293.xml No results returned
# 1807 88203934.xml Written
# 1808 88207774.xml Written
# 1809 88211758.xml Written
# 1810 88204454.xml Written
# 1811 88179354.xml No results returned
# 1811 88205758.xml Written
# 1812 88182519.xml Written
# 1813 88179994.xml Written
# 1814 88214638.xml Written
# 1815 88197437.xml Written
# 1816 88174253.xml Written
# 1817 88184154.xml Written
# 1818 88193393.xml Written
# 1819 88179271.xml Written
# 1820 88200833.xml Written
# 1821 88194153.xml Written
# 1822 88174103.xml Written
# 1823 88193553.xml Written
# 1824 88190071.xml Written
# 1825 88177685.xml Written
# 1826 88191391.xml Written
# 1827 88186838.xml Written
# 1828 88173684.xml Written
# 1829 88229957.xml Written
# 1830 88205086.xml Written
# 1831 88188804.xml Written
# 1832 88190724.xml Written
# 1833 88192893.xml Written
# 1834 88208266.xml Written
# 1835 88217266.xml Written
# 1836 88178031.xml Written
# 1837 88176566.xml No results returned
# 1837 88200933.xml Written
# 1838 88187235.xml Written
# 1839 88192358.xml Written
# 1840 88199173.xml Written
# 1841 88207137.xml Written
# 1842 88189155.xml Written
# 1843 88202333.xml Written
# 1844 88176764.xml Written
# 1845 88206157.xml Written
# 1846 88225334.xml Written
# 1847 88175823.xml Written
# 1848 88202473.xml Written
# 1849 88190678.xml Written
# 1850 88212074.xml Written
# 1851 88183871.xml Written
# 1852 88174848.xml Written
# 1853 88188231.xml Written
# 1854 88180199.xml Written
# 1855 88184514.xml Written
# 1856 88192951.xml Written
# 1857 88215586.xml Written
# 1858 88182079.xml Written
# 1859 88180471.xml Written
# 1860 88192833.xml Written
# 1861 88230294.xml Written
# 1862 88184554.xml Written
# 1863 88186311.xml No results returned
# 1863 88175726.xml No results returned
# 1863 88182874.xml No results returned
# 1863 88202173.xml Written
# 1864 88182036.xml Written
# 1865 88185754.xml Written
# 1866 88220186.xml Written
# 1867 88229277.xml Written
# 1868 88208897.xml Written
# 1869 88181719.xml Written
# 1870 88176284.xml Written
# 1871 88174165.xml No results returned
# 1871 88210034.xml Written
# 1872 88175922.xml Written
# 1873 88176124.xml Written
# 1874 88183194.xml Written
# 1875 88189758.xml Written
# 1876 88228506.xml Written
# 1877 88177871.xml No results returned
# 1877 88206517.xml Written
# 1878 88201409.xml Written
# 1879 88193721.xml Written
# 1880 88185190.xml Written
# 1881 88195204.xml Written
# 1882 88188871.xml Written
# 1883 88174724.xml Written
# 1884 88191911.xml Written
# 1885 88188910.xml Written
# 1886 88201953.xml Written
# 1887 88184234.xml Written
# 1888 88188310.xml Written
# 1889 88200113.xml Written
# 1890 88231114.xml Written
# 1891 88231774.xml Written
# 1892 88200793.xml Written
# 1893 88191804.xml Written
# 1894 88189715.xml Written
# 1895 88203286.xml Written
# 1896 88185354.xml Written
# 1897 88195533.xml Written
# 1898 88185711.xml Written
# 1899 88174526.xml Written
# 1900 88181311.xml Written
# 1901 88197873.xml Written
# 1902 88174768.xml No results returned
# 1902 88189478.xml Written
# 1903 88179071.xml Written
# 1904 88217706.xml Written
# 1905 88211777.xml Written
# 1906 88198121.xml Written
# 1907 88175325.xml Written
# 1908 88186155.xml Written
# 1909 88201809.xml Written
# 1910 88176046.xml No results returned
# 1910 88188275.xml Written
# 1911 88177631.xml Written
# 1912 88173362.xml Written
# 1913 88177836.xml Written
# 1914 88178071.xml Written
# 1915 88179314.xml Written
# 1916 88204086.xml Written
# 1917 88185434.xml Written
# 1918 88177084.xml Written
# 1919 88172743.xml Written
# 1920 88229774.xml Written
# 1921 88221157.xml Written
# 1922 88173143.xml Written
# 1923 88183236.xml No results returned
# 1923 88181596.xml Written
# 1924 88212666.xml Written
# 1925 88227194.xml Written
# 1926 88183474.xml Written
# 1927 88177645.xml Written
# 1928 88196313.xml Written
# 1929 88179394.xml Written
# 1930 88224088.xml Written
# 1931 88200567.xml Written
# 1932 88206208.xml Written
# 1933 88202047.xml Written
# 1934 88183393.xml Written
# 1935 88212168.xml Written
# 1936 88202567.xml Written
# 1937 88204359.xml Written
# 1938 88186353.xml No results returned
# 1938 88211368.xml Written
# 1939 88202557.xml Written
# 1940 88207408.xml Written
# 1941 88197087.xml Written
# 1942 88190043.xml Written
# 1943 88196687.xml Written
# 1944 88206679.xml Written
# 1945 88190567.xml Written
# 1946 88185832.xml Written
# 1947 88190113.xml Written
# 1948 88195047.xml Written
# 1949 88205119.xml Written
# 1950 88205167.xml Written
# 1951 88192197.xml No results returned
# 1951 88201527.xml Written
# 1952 88191523.xml Written
# 1953 88206008.xml Written
# 1954 88207009.xml Written
# 1955 88189127.xml Written
# 1956 88206009.xml Written
# 1957 88189117.xml Written
# 1958 88188953.xml Written
# 1959 88205087.xml Written
# 1960 88214488.xml Written
# 1961 88229408.xml Written
# 1962 88222168.xml Written
# 1963 88199087.xml Written
# 1964 88186917.xml Written
# 1965 88228808.xml Written
# 1966 88186073.xml Written
# 1967 88191557.xml Written
# 1968 88191433.xml Written
# 1969 88192037.xml Written
# 1970 88202247.xml Written
# 1971 88196407.xml Written
# 1972 88192523.xml Written
# 1973 88199007.xml Written
# 1974 88191367.xml Written
# 1975 88206969.xml Written
# 1976 88204249.xml Written
# 1977 88189553.xml Written
# 1978 88205369.xml Written
# 1979 88201207.xml Written
# 1980 88191167.xml Written
# 1981 88202607.xml Written
# 1982 88194127.xml Written
# 1983 88206448.xml Written
# 1984 88212328.xml Written
# 1985 88197367.xml Written
# 1986 88207848.xml Written
# 1987 88186113.xml Written
# 1988 88202407.xml Written
# 1989 88186102.xml Written
# 1990 88195876.xml Written
# 1991 88194159.xml Written
# 1992 88189370.xml Written
# 1993 88202602.xml Written
# 1994 88201479.xml Written
# 1995 88197839.xml Written
# 1996 88188504.xml Written
# 1997 88230630.xml Written
# 1998 88203602.xml Written
# 1999 88190869.xml Written
# 2000 88195896.xml Written
# 2001 88189698.xml Written
# 2002 88179584.xml No results returned
# 2002 88184469.xml Written
# 2003 88189050.xml Written
# 2004 88182904.xml Written
# 2005 88216227.xml Written
# 2006 88186018.xml Written
# 2007 88181624.xml Written
# 2008 88176667.xml Written
# 2009 88193038.xml Written
# 2010 88196143.xml Written
# 2011 88190067.xml Written
# 2012 88230910.xml Written
# 2013 88185789.xml Written
# 2014 88194999.xml Written
# 2015 88187490.xml No results returned
# 2015 88196616.xml Written
# 2016 88195819.xml Written
# 2017 88188023.xml Written
# 2018 88186503.xml Written
# 2019 88187330.xml Written
# 2020 88188149.xml Written
# 2021 88229224.xml Written
# 2022 88200419.xml Written
# 2023 88229871.xml Written
# 2024 88185290.xml Written
# 2025 88192178.xml Written
# 2026 88204245.xml Written
# 2027 88208467.xml Written
# 2028 88188107.xml No results returned
# 2028 88186610.xml Written
# 2029 88180944.xml Written
# 2030 88215667.xml Written
# 2031 88182224.xml Written
# 2032 88228279.xml Written
# 2033 88192463.xml Written
# 2034 88208627.xml Written
# 2035 88228673.xml Written
# 2036 88182584.xml Written
# 2037 88206717.xml Written
# 2038 88185743.xml Written
# 2039 88223685.xml Written
# 2040 88198979.xml Written
# 2041 88190010.xml Written
# 2042 88186743.xml Written
# 2043 88193939.xml Written
# 2044 88201636.xml Written
# 2045 88195539.xml Written
# 2046 88190189.xml No results returned
# 2046 88184984.xml Written
# 2047 88180704.xml Written
# 2048 88192898.xml Written
# 2049 88206002.xml Written
# 2050 88187107.xml Written
# 2051 88193907.xml Written
# 2052 88224842.xml Written
# 2053 88187147.xml Written
# 2054 88183704.xml Written
# 2055 88212030.xml Written
# 2056 88188010.xml Written
# 2057 88179224.xml No results returned
# 2057 88195587.xml Written
# 2058 88189858.xml Written
# 2059 88208670.xml Written
# 2060 88187389.xml Written
# 2061 88188587.xml Written
# 2062 88208885.xml Written
# 2063 88216987.xml Written
# 2064 88201823.xml Written
# 2065 88183984.xml Written
# 2066 88191707.xml Written
# 2067 88181864.xml Written
# 2068 88187744.xml Written
# 2069 88188618.xml Written
# 2070 88196983.xml Written
# 2071 88192147.xml Written
# 2072 88189770.xml Written
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-4f8b4c620caa> in <module>
#      18             paragraphs3= paragraph_wordsearch(paragraphs2)
#      19             #select only quality paragraphs
# ---> 20             paragraphs4 = select_good_paragraphs(paragraphs3)
#      21             #remove bad phrases
#      22             paragraphs5 = paragraph_remove(paragraphs4)
#
# <ipython-input-11-c4796131455b> in select_good_paragraphs(paragraphs)
#      10         percent_digits = (nums*1.0)/len(paragraph)
#      11         #keep sections with spell correctness above .85
# ---> 12         spellcorrect= calculate_percent_correct(paragraph)
#      13         #remove sections with list of all capitalized words (most likely to be names)
#      14         percent_uppers = (1.0*sum(1 for c in paragraph if c.isupper()))/len(paragraph)
#
# <ipython-input-121-f0daa44ce5d4> in calculate_percent_correct(text)
#       3         true =0
#       4         total = 0.0
# ----> 5         for word in tknzr(text):
#       6                 word1 =word[0]
#       7                 total +=1
#
# ~/anaconda3/lib/python3.7/site-packages/enchant/tokenize/__init__.py in __next__(self)
#     391
#     392         def __next__(self):
# --> 393             return self.next()
#     394
#     395         def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/enchant/tokenize/__init__.py in next(self)
#     398             while True:
#     399                 try:
# --> 400                     (word,pos) = next(self._curtok)
#     401                     return (word,pos + self._curpos)
#     402                 except StopIteration:
#
# ~/anaconda3/lib/python3.7/site-packages/enchant/tokenize/__init__.py in __next__(self)
#     131
#     132     def __next__(self):
# --> 133         return self.next()
#     134
#     135     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/enchant/tokenize/en.py in next(self)
#     169             # Find end of word using, allowing valid_chars
#     170             while offset < len(text):
# --> 171                 incr = self._consume_alpha(text,offset)
#     172                 if not incr:
#     173                     if text[offset] in self._valid_chars:
#
# ~/anaconda3/lib/python3.7/site-packages/enchant/tokenize/en.py in _consume_alpha_u(self, text, offset)
#     151             incr = 1
#     152             while offset + incr < len(text):
# --> 153                 if unicodedata.category(text[offset+incr])[0] != "M":
#     154                     break
#     155                 incr += 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create text file with examples

# %%
#for i,item in enumerate(example_list):
#    with open(test_files +  item.replace(" ", "") + '2.txt', 'w') as f:
#        f.write('%s\n\n' % example_container_lists[i])

# %% [markdown]
# ## Create selection of 1000 random paragrahs

# %%
#how many were selected?
len(random_selection)
# Out:
# 38060

# %%
#select 1000 random paragraphs 
random_sample = random.choices(random_selection, k=1000)
len(random_sample)
# Out:
# 1000

# %%
#put these in a csv
with open(test_paragraphs + "random_sample_v1.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(random_sample)

# %%
paragraphs4
# Out:
# ['Shareowners are cordially invited to attend the Annual Meeting of the company at The Greenbner White Sulphur Springs W. Va. on March 24 1961. Details ***will be given in the Notice of the Annual MeetingBeginning Another Great Era of Growth']
