# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Set topic number

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic50.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/scipy/sparse/sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 50

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/corpus.pkl', 'rb') )

# %% [markdown]
# ### IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# ### extract term-topic matrix (note this will be over all the time slices)

# %% [markdown]
# # get_topics for DTM
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %% [markdown]
# ## Frex output

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['busi', 'custom', 'compani', 'servic', 'valu', 'growth', 'market', 'commit']
# FREX WORDS: ['custom', 'strategi', 'commit', 'valu', 'growth', 'opportun', 'qualiti', 'focus']
#
# TOPIC  1
# PROB WORDS: ['industri', 'busi', 'year', 'econom', 'economi', 'condit', 'nation', 'problem']
# FREX WORDS: ['econom', 'economi', 'industri', 'problem', 'war', 'condit', 'demand', 'uncertainti']
#
# TOPIC  2
# PROB WORDS: ['report', 'form', 'secur', 'inform', 'exchang', 'commiss', 'request', 'annual']
# FREX WORDS: ['commiss', 'secur', 'request', 'exchang', 'report', 'inform', 'copi', 'file']
#
# TOPIC  3
# PROB WORDS: ['american', 'america', 'world', 'industri', 'north', 'market', 'region', 'global']
# FREX WORDS: ['american', 'america', 'world', 'north', 'region', 'global', 'delta', 'market']
#
# TOPIC  4
# PROB WORDS: ['year', 'earn', 'sale', 'continu', 'increas', 'improv', 'growth', 'oper']
# FREX WORDS: ['earn', 'sale', 'growth', 'improv', 'increas', 'profit', 'record', 'strong']
#
# TOPIC  5
# PROB WORDS: ['plant', 'new', 'construct', 'facil', 'complet', 'oper', 'addit', 'year']
# FREX WORDS: ['plant', 'construct', 'facil', 'complet', 'new', 'capac', 'equip', 'modern']
#
# TOPIC  6
# PROB WORDS: ['reserv', 'loss', 'year', 'charg', 'valu', 'surplu', 'depreci', 'asset']
# FREX WORDS: ['reserv', 'depreci', 'surplu', 'loss', 'charg', 'valu', 'conting', 'asset']
#
# TOPIC  7
# PROB WORDS: ['steel', 'car', 'equip', 'aircraft', 'truck', 'contract', 'product', 'militari']
# FREX WORDS: ['steel', 'car', 'equip', 'aircraft', 'truck', 'contract', 'militari', 'roll']
#
# TOPIC  8
# PROB WORDS: ['men', 'war', 'women', 'role', 'aluminum', 'plai', 'nation', 'job']
# FREX WORDS: ['men', 'war', 'women', 'role', 'aluminum', 'plai', 'cement', 'shoe']
#
# TOPIC  9
# PROB WORDS: ['method', 'televis', 'lor', 'color', 'design', 'radio', 'cabl', 'seri']
# FREX WORDS: ['method', 'televis', 'lor', 'color', 'radio', 'cabl', 'station', 'film']
#
# TOPIC  10
# PROB WORDS: ['polici', 'continu', 'compani', 'manag', 'benefit', 'need', 'fair', 'possibl']
# FREX WORDS: ['polici', 'fair', 'cooper', 'need', 'desir', 'benefit', 'problem', 'sound']
#
# TOPIC  11
# PROB WORDS: ['product', 'chemic', 'ton', 'metal', 'produc', 'mine', 'industri', 'copper']
# FREX WORDS: ['chemic', 'metal', 'ton', 'mine', 'copper', 'product', 'coal', 'or']
#
# TOPIC  12
# PROB WORDS: ['compani', 'subsidiari', 'oper', 'corpor', 'consolid', 'account', 'statement', 'sheet']
# FREX WORDS: ['subsidiari', 'consolid', 'sheet', 'statement', 'own', 'incom', 'account', 'balanc']
#
# TOPIC  13
# PROB WORDS: ['cost', 'price', 'increas', 'rate', 'materi', 'higher', 'wage', 'labor']
# FREX WORDS: ['cost', 'price', 'increas', 'wage', 'labor', 'higher', 'rate', 'materi']
#
# TOPIC  14
# PROB WORDS: ['report', 'cover', 'page', 'annual', 'shown', 'segment', 'corpor', 'industri']
# FREX WORDS: ['cover', 'report', 'page', 'annual', 'illustr', 'shown', 'segment', 'pictur']
#
# TOPIC  15
# PROB WORDS: ['presid', 'vice', 'san', 'francisco', 'chairman', 'assist', 'secretari', 'treasur']
# FREX WORDS: ['presid', 'vice', 'san', 'francisco', 'chairman', 'treasur', 'secretari', 'assist']
#
# TOPIC  16
# PROB WORDS: ['michigan', 'detroit', 'motor', 'tire', 'rubber', 'gener', 'lake', 'middl']
# FREX WORDS: ['michigan', 'detroit', 'motor', 'tire', 'rubber', 'middl', 'lake', 'cna']
#
# TOPIC  17
# PROB WORDS: ['home', 'product', 'care', 'health', 'servic', 'provid', 'custom', 'system']
# FREX WORDS: ['home', 'care', 'health', 'system', 'technolog', 'medic', 'product', 'custom']
#
# TOPIC  18
# PROB WORDS: ['california', 'pacif', 'western', 'line', 'southern', 'union', 'san', 'florida']
# FREX WORDS: ['california', 'pacif', 'western', 'southern', 'san', 'union', 'line', 'florida']
#
# TOPIC  19
# PROB WORDS: ['insur', 'life', 'compani', 'premium', 'new', 'group', 'mutual', 'policyhold']
# FREX WORDS: ['insur', 'life', 'premium', 'mutual', 'policyhold', 'annuiti', 'underwrit', 'group']
#
# TOPIC  20
# PROB WORDS: ['bank', 'loan', 'financ', 'rate', 'capit', 'financi', 'asset', 'year']
# FREX WORDS: ['bank', 'loan', 'financ', 'credit', 'borrow', 'debt', 'fund', 'capit']
#
# TOPIC  21
# PROB WORDS: ['secur', 'sale', 'intend', 'sell', 'connect', 'offer', 'corpor', 'report']
# FREX WORDS: ['secur', 'intend', 'sale', 'sell', 'connect', 'offer', 'inform', 'prospectu']
#
# TOPIC  22
# PROB WORDS: ['new', 'york', 'bank', 'compani', 'nation', 'trust', 'street', 'citi']
# FREX WORDS: ['york', 'bank', 'new', 'trust', 'street', 'chicago', 'citi', 'stock']
#
# TOPIC  23
# PROB WORDS: ['power', 'electr', 'energi', 'system', 'electron', 'gener', 'util', 'servic']
# FREX WORDS: ['power', 'electr', 'energi', 'system', 'electron', 'nuclear', 'util', 'light']
#
# TOPIC  24
# PROB WORDS: ['compani', 'approv', 'corpor', 'merger', 'agreement', 'court', 'order', 'propos']
# FREX WORDS: ['approv', 'merger', 'court', 'agreement', 'propos', 'commiss', 'transact', 'file']
#
# TOPIC  25
# PROB WORDS: ['million', 'percent', 'share', 'increas', 'net', 'total', 'billion', 'equiti']
# FREX WORDS: ['million', 'percent', 'share', 'billion', 'equiti', 'net', 'incom', 'return']
#
# TOPIC  26
# PROB WORDS: ['statement', 'result', 'forwardlook', 'risk', 'includ', 'report', 'factor', 'discuss']
# FREX WORDS: ['statement', 'forwardlook', 'risk', 'factor', 'discuss', 'differ', 'uncertainti', 'result']
#
# TOPIC  27
# PROB WORDS: ['compani', 'year', 'futur', 'posit', 'taken', 'action', 'step', 'chang']
# FREX WORDS: ['taken', 'action', 'step', 'posit', 'strengthen', 'took', 'term', 'decis']
#
# TOPIC  28
# PROB WORDS: ['unit', 'state', 'govern', 'question', 'nation', 'feder', 'charter', 'land']
# FREX WORDS: ['unit', 'state', 'govern', 'question', 'offici', 'charter', 'feder', 'answer']
#
# TOPIC  29
# PROB WORDS: ['capit', 'program', 'expenditur', 'year', 'increas', 'expans', 'facil', 'addit']
# FREX WORDS: ['expenditur', 'capit', 'program', 'expans', 'facil', 'increas', 'project', 'order']
#
# TOPIC  30
# PROB WORDS: ['foreign', 'domest', 'market', 'countri', 'intern', 'unit', 'canada', 'state']
# FREX WORDS: ['foreign', 'domest', 'countri', 'canada', 'intern', 'state', 'unit', 'subsidiari']
#
# TOPIC  31
# PROB WORDS: ['peopl', 'live', 'work', 'todai', 'great', 'new', 'famili', 'world']
# FREX WORDS: ['peopl', 'live', 'famili', 'todai', 'thing', 'work', 'man', 'world']
#
# TOPIC  32
# PROB WORDS: ['oil', 'ga', 'product', 'compani', 'petroleum', 'crude', 'explor', 'develop']
# FREX WORDS: ['oil', 'ga', 'crude', 'petroleum', 'explor', 'barrel', 'drill', 'refin']
#
# TOPIC  33
# PROB WORDS: ['year', 'compani', 'sharehold', 'histori', 'record', 'futur', 'ahead', 'report']
# FREX WORDS: ['year', 'histori', 'sharehold', 'record', 'ahead', 'achiev', 'letter', 'challeng']
#
# TOPIC  34
# PROB WORDS: ['servic', 'transport', 'air', 'revenu', 'passeng', 'train', 'oper', 'railroad']
# FREX WORDS: ['servic', 'transport', 'air', 'passeng', 'train', 'traffic', 'railroad', 'rout']
#
# TOPIC  35
# PROB WORDS: ['meet', 'proxi', 'annual', 'stockhold', 'held', 'notic', 'statement', 'april']
# FREX WORDS: ['proxi', 'meet', 'annual', 'notic', 'held', 'stockhold', 'statement', 'mail']
#
# TOPIC  36
# PROB WORDS: ['board', 'director', 'execut', 'chairman', 'offic', 'presid', 'chief', 'member']
# FREX WORDS: ['board', 'director', 'execut', 'chairman', 'chief', 'presid', 'offic', 'elect']
#
# TOPIC  37
# PROB WORDS: ['product', 'develop', 'research', 'new', 'engin', 'paper', 'manufactur', 'advanc']
# FREX WORDS: ['research', 'develop', 'engin', 'product', 'paper', 'introduc', 'advanc', 'technolog']
#
# TOPIC  38
# PROB WORDS: ['oper', 'result', 'cost', 'reduc', 'loss', 'quarter', 'expens', 'improv']
# FREX WORDS: ['cost', 'loss', 'quarter', 'result', 'expens', 'reduc', 'oper', 'restructur']
#
# TOPIC  39
# PROB WORDS: ['new', 'store', 'food', 'market', 'brand', 'product', 'retail', 'sale']
# FREX WORDS: ['store', 'food', 'brand', 'retail', 'market', 'open', 'merchandis', 'new']
#
# TOPIC  40
# PROB WORDS: ['meet', 'annual', 'held', 'sharehold', 'april', 'corpor', 'stockhold', 'build']
# FREX WORDS: ['meet', 'held', 'annual', 'sharehold', 'april', 'hotel', 'street', 'minneapoli']
#
# TOPIC  41
# PROB WORDS: ['year', 'report', 'end', 'compani', 'stockhold', 'fiscal', 'annual', 'oper']
# FREX WORDS: ['year', 'report', 'end', 'fiscal', 'stockhold', 'annual', 'letter', 'submit']
#
# TOPIC  42
# PROB WORDS: ['tax', 'incom', 'year', 'net', 'earn', 'profit', 'feder', 'compar']
# FREX WORDS: ['tax', 'incom', 'net', 'earn', 'feder', 'profit', 'compar', 'share']
#
# TOPIC  43
# PROB WORDS: ['product', 'demand', 'meet', 'suppli', 'need', 'custom', 'increas', 'requir']
# FREX WORDS: ['product', 'demand', 'meet', 'suppli', 'need', 'custom', 'machin', 'milk']
#
# TOPIC  44
# PROB WORDS: ['financi', 'statement', 'consolid', 'inform', 'report', 'contain', 'review', 'oper']
# FREX WORDS: ['statement', 'financi', 'consolid', 'inform', 'contain', 'review', 'summari', 'highlight']
#
# TOPIC  45
# PROB WORDS: ['billion', 'mill', 'doubl', 'agricultur', 'crop', 'size', 'popul', 'nearli']
# FREX WORDS: ['billion', 'mill', 'doubl', 'agricultur', 'crop', 'corn', 'popul', 'feed']
#
# TOPIC  46
# PROB WORDS: ['compani', 'oper', 'divis', 'product', 'develop', 'growth', 'manag', 'corpor']
# FREX WORDS: ['divis', 'growth', 'develop', 'acquisit', 'diversif', 'field', 'product', 'manag']
#
# TOPIC  47
# PROB WORDS: ['share', 'stock', 'dividend', 'common', 'earn', 'prefer', 'increas', 'paid']
# FREX WORDS: ['stock', 'share', 'dividend', 'common', 'prefer', 'paid', 'quarterli', 'cash']
#
# TOPIC  48
# PROB WORDS: ['year', 'sale', 'increas', 'volum', 'price', 'inventori', 'product', 'declin']
# FREX WORDS: ['sale', 'volum', 'inventori', 'increas', 'price', 'declin', 'year', 'previou']
#
# TOPIC  49
# PROB WORDS: ['plan', 'fund', 'compani', 'retir', 'employe', 'bond', 'payment', 'purchas']
# FREX WORDS: ['fund', 'plan', 'retir', 'bond', 'payment', 'employe', 'pension', 'debentur']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %%
#https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/
#https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/

# %% [markdown]
# # Topics over time
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (33989, 50)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['Filename']]
topic_document_distribution['Filename'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["Filename", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "Filename", "topic"])
print(dtm.head())
# Out:
#             Filename  Year topic        weight
# 19798   88178299.xml  1930     0  0.0004878049
# 53787   88178299.xml  1930     1  0.0004878049
# 87776   88178299.xml  1930     2  0.0004878049
# 121765  88178299.xml  1930     3  0.0004878049
# 155754  88178299.xml  1930     4  0.0004878049

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#        Filename  Year topic        weight  \
# 0  88178299.xml  1930     0  0.0004878049
# 1  88178309.xml  1930     0  0.0001709402
# 2  88178340.xml  1930     0  0.0001481481
# 3  88178352.xml  1930     0  0.0005714286
# 4  88178376.xml  1930     0  0.4807618977
#
#                                  keywords
# 0  busi custom compani servic valu growth
# 1  busi custom compani servic valu growth
# 2  busi custom compani servic valu growth
# 3  busi custom compani servic valu growth
# 4  busi custom compani servic valu growth

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9943352601156067
# Min: 1.5396458814472702e-05
# Average: 0.020000000000073126
# Median: 0.00035087719298245617
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['Filename'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, size=5, aspect=1.5, title=""):
    p = sns.factorplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  size=size, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, size=5, aspect=1.5, title=""):
    p = sns.factorplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, size=size, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
# Out:
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/carlyknight/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
