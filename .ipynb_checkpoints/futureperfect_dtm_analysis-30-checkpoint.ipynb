# %% [markdown]
# # Analyzing DTM Results
# #https://github.com/RaRe-Technologies/gensim/blob/develop/docs/notebooks/dtm_example.ipynb

# %%
#import 
import pickle
import pyLDAvis
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.special import logsumexp
import scipy as sp
from collections import OrderedDict, defaultdict

#set precision for pandas
pd.set_option("display.precision", 10)

# %% [markdown]
# # Open Model

# %%
model = pickle.load(open("/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/topic30.pkl", "rb" ) )
#print model attirbutes
print(model.__dict__.keys())
# Out:
# dict_keys(['dtm_path', 'id2word', 'num_terms', 'num_topics', 'lencorpus', 'prefix', 'time_slices', 'lda_sequence_min_iter', 'lda_sequence_max_iter', 'lda_max_em_iter', 'alpha', 'top_chain_var', 'rng_seed', 'initialize_lda', 'lambda_', 'obs_', 'lhood_', 'gamma_', 'init_alpha', 'init_beta', 'init_ss', 'em_steps', 'influences_time'])

# %%
number_topic = model.num_topics
number_topic
# Out:
# 30

# %%
corpus = pickle.load(open('/Users/carlyknight/Documents/Data/FuturePerfect/dynamic_topic_models/corpus.pkl', 'rb') )

# %% [markdown]
# # IDENTIFY FREQUENT TERMS (FREX WORDS)

# %% [markdown]
# #get_topics()
# #Get the term-topic matrix learned during inference.
#
# #Returns
# #The probability for each word in each topic, shape (num_topics, vocabulary_size).
#
# #Return type
# #numpy.ndarray
#
# #https://stackoverflow.com/questions/42289858/extract-topic-word-probability-matrix-in-gensim-ldamodel

# %%
def ecdf(arr):
    """Calculate the ECDF values for all elements in a 1D array."""
    return sp.stats.rankdata(arr, method='max') / arr.size

# %%
def get_topics(model, time):
    topic_terms = model.lambda_

    #timeslice
    timeslice = [ "ts_" + str(i) for i in range(topic_terms.shape[2])]

    # find the right word based on column index
    words = [model.id2word[i] for i in range(topic_terms.shape[1])]

    #apply words over 40 topics, generate list of dataframes, columns are time-slices
    word_time_topic_matrix=[]

    for j in range(topic_terms.shape[0]):
        temp = topic_terms[j]
        temp=pd.DataFrame(temp,columns=timeslice)
        temp['word'] = words
        temp=temp.set_index('word')
        word_time_topic_matrix.append(temp)
    
    #reshape dataframe so that its one dataframe per topic, columns are topics
    topic_term_matrix=[ ]

    for i in timeslice:
        temp =pd.concat([df[[i]] for df in word_time_topic_matrix], axis=1)
        temp.columns = ["topic_" + str(i) for i in range(number_topic)]
        topic_term_matrix.append(temp)
    
    #now, invert so shape is (num_topics, vocabulary_size)
    term_topic_matrix = [df.transpose() for df in topic_term_matrix] 
        
    #convert estimates to probability (sum equals to 1 per topic)
    term_topic_proba = np.apply_along_axis(lambda x: x/x.sum(),1,term_topic_matrix[time])
    term_topic_proba1 = pd.DataFrame(term_topic_proba,columns=words)
    
    return term_topic_proba1

# %% [markdown]
# ### Calculate FREX for all words in a topic model
# #see R STM package for details
#
# #https://gist.github.com/jrnold/daa039f02486009a24cf3e83403dabf0

# %%
"""Calculate FREX scores for all words in a topic model.

See R STM package for details.

"""
def frex(topics_matrix, w):
    log_beta = np.log(topics_matrix)
    log_exclusivity = log_beta - logsumexp(log_beta, axis=0)
    #log_exclusivity = (log_beta.transpose() - logsumexp(log_beta, axis=0)).transpose()
    exclusivity_ecdf = np.apply_along_axis(ecdf, 1, log_exclusivity)
    freq_ecdf = np.apply_along_axis(ecdf, 1, log_beta)
    #out = 1. /(w / freq_ecdf + (1 - w) / exclusivity_ecdf )
    out = exclusivity_ecdf
    return out

# %%
def word_freq(corpus):
    """Calculate word frequencies in a ``corpus``."""
    counts = defaultdict(int)
    for doc in corpus:
        for word, count in doc:
            counts[word] += count
    total = sum(counts.values())
    nwords = max(counts.keys())
    out = np.zeros(nwords + 1)
    for k, v in counts.items():
        out[k] = v / total
    return out

# %%
def create_topic_word_data(model, corpus, frex_w, time):
    """Create data frame with topic-word information.
    Parameters
    ------------
    model: Fitted dTM model
    corpus: list
    frex_w: float
        Weight to use in FREX calculations.

    Returns
    ---------
    :class:`pandas.DataFrame`
        Data frame with the following columns.

        :word: ``str``. Word
        :word_id: ``float``. Word identifier
        :topic: ``int``. Topic number
        :prob: ``float``. Probability of the word conditional on a topic.
        :frex: ``float``. FREX score
    """
    #word ids
    id2word = model.id2word
    words = pd.DataFrame({
        'word_id': list(id2word.keys()),
        'word': list(id2word.values())
         }, columns=("word_id", "word"))
    #get probabilities
    topics_matrix = pd.DataFrame(get_topics(model, time))
    #organize
    term_topics = topics_matrix
    term_topics.index.name = "topic"
    term_topics=term_topics.stack().reset_index()
    term_topics.columns = ["topic", "word", "prob"]
    term_topics=term_topics.merge(words, left_on="word", right_on="word")
    term_topics.columns = ['topic', 'word', 'prob', 'word_id'] #Step 5: merge back in 
    # need to ensure that the array's are flattened in the right order
    term_topics['frex'] = np.ravel(frex(topics_matrix, w=frex_w), order="F")
    return term_topics

# %%
#return frex words
def get_frex_words(frex_output, number_topic, topn):
    frexlist = frex_output.loc[frex_output['topic'] == number_topic].sort_values(by = "frex", ascending = True)['word'].tolist()
    frexlist = frexlist[0:topn]
    return frexlist

# %% [markdown]
# # Get Topic Descriptions

# %% [markdown]
# ### Descriptions: Based on year 2005

# %%
#run frex models, time = 78
frex_output = create_topic_word_data(model, corpus, frex_w =.5, time = 78)

# %%
for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=75, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['court', 'action', 'claim', 'file', 'alleg', 'defend', 'damag', 'district']
# FREX WORDS: ['court', 'alleg', 'plaintiff', 'complaint', 'defend', 'lawsuit', 'violat', 'dismiss']
#
# TOPIC  1
# PROB WORDS: ['mine', 'copper', 'ton', 'or', 'coal', 'metal', 'dodg', 'phelp']
# FREX WORDS: ['copper', 'mine', 'or', 'ounc', 'phelp', 'dodg', 'newmont', 'ton']
#
# TOPIC  2
# PROB WORDS: ['shall', 'committe', 'execut', 'award', 'section', 'termin', 'particip', 'vote']
# FREX WORDS: ['shall', 'committe', 'gatx', 'aramark', 'hereund', 'award', 'hereof', 'deem']
#
# TOPIC  3
# PROB WORDS: ['bank', 'loan', 'percent', 'financ', 'inflat', 'trust', 'save', 'averag']
# FREX WORDS: ['bank', 'loan', 'morgan', 'branch', 'lend', 'monetari', 'banker', 'id']
#
# TOPIC  4
# PROB WORDS: ['claim', 'asbesto', 'corn', 'bankruptci', 'file', 'liabil', 'reorgan', 'court']
# FREX WORDS: ['corn', 'asbesto', 'owen', 'bankruptci', 'delphi', 'asbestosrel', 'chapter', 'claim']
#
# TOPIC  5
# PROB WORDS: ['borrow', 'loan', 'prefer', 'shall', 'debentur', 'lender', 'seri', 'agent']
# FREX WORDS: ['loan', 'shall', 'lender', 'borrow', 'corco', 'indentur', 'subordin', 'tranch']
#
# TOPIC  6
# PROB WORDS: ['engin', 'divis', 'aircraft', 'system', 'air', 'textron', 'research', 'commerci']
# FREX WORDS: ['textron', 'aircraft', 'missil', 'engin', 'navi', 'caterpillar', 'grumman', 'trw']
#
# TOPIC  7
# PROB WORDS: ['research', 'drug', 'pharmaceut', 'patient', 'care', 'merck', 'medic', 'health']
# FREX WORDS: ['patient', 'abbott', 'merck', 'pharmaceut', 'drug', 'clinic', 'pfizer', 'medicin']
#
# TOPIC  8
# PROB WORDS: ['stockhold', 'cent', 'war', 'organ', 'month', 'field', 'arc', 'public']
# FREX WORDS: ['war', 'postwar', 'arc', 'men', 'surplu', 'cent', 'civilian', 'shall']
#
# TOPIC  9
# PROB WORDS: ['technolog', 'system', 'percent', 'inform', 'sharehold', 'billion', 'perform', 'world']
# FREX WORDS: ['softwar', 'digit', 'technolog', 'global', 'ncr', 'pitnei', 'client', 'bow']
#
# TOPIC  10
# PROB WORDS: ['oil', 'ga', 'field', 'drill', 'crude', 'barrel', 'explor', 'occident']
# FREX WORDS: ['occident', 'oil', 'crude', 'ga', 'barrel', 'drill', 'refineri', 'lyondel']
#
# TOPIC  11
# PROB WORDS: ['environment', 'site', 'liabil', 'remedi', 'percent', 'oblig', 'debt', 'regul']
# FREX WORDS: ['environment', 'remedi', 'prp', 'closur', 'cleanup', 'landfil', 'epa', 'goodyear']
#
# TOPIC  12
# PROB WORDS: ['power', 'electr', 'nuclear', 'energi', 'fuel', 'util', 'commiss', 'station']
# FREX WORDS: ['electr', 'nuclear', 'kilowatt', 'aep', 'coal', 'atom', 'power', 'reactor']
#
# TOPIC  13
# PROB WORDS: ['presid', 'vice', 'divis', 'chairman', 'execut', 'york', 'research', 'chief']
# FREX WORDS: ['vice', 'presid', 'kodak', 'colleg', 'chairman', 'camera', 'cenco', 'mcgrawhil']
#
# TOPIC  14
# PROB WORDS: ['ga', 'niagara', 'mohawk', 'natur', 'columbia', 'pipelin', 'commiss', 'texa']
# FREX WORDS: ['mohawk', 'niagara', 'ga', 'pipelin', 'dresser', 'coastal', 'cubic', 'mcf']
#
# TOPIC  15
# PROB WORDS: ['food', 'divis', 'feed', 'agricultur', 'cooper', 'farm', 'sugar', 'fiscal']
# FREX WORDS: ['food', 'milk', 'sugar', 'beef', 'feed', 'farmland', 'grain', 'meat']
#
# TOPIC  16
# PROB WORDS: ['brand', 'retail', 'divis', 'consum', 'apparel', 'group', 'brunswick', 'footwear']
# FREX WORDS: ['brunswick', 'apparel', 'footwear', 'shoe', 'disnei', 'brand', 'mattel', 'alden']
#
# TOPIC  17
# PROB WORDS: ['util', 'electr', 'sce', 'power', 'edison', 'regulatori', 'energi', 'em']
# FREX WORDS: ['sce', 'edison', 'em', 'cpuc', 'decommiss', 'gpu', 'nuclear', 'pge']
#
# TOPIC  18
# PROB WORDS: ['televis', 'cabl', 'radio', 'station', 'broadcast', 'advertis', 'commun', 'rca']
# FREX WORDS: ['televis', 'broadcast', 'radio', 'cabl', 'rca', 'dealership', 'cb', 'sonic']
#
# TOPIC  19
# PROB WORDS: ['chemic', 'aluminum', 'plastic', 'research', 'dow', 'divis', 'fiber', 'metal']
# FREX WORDS: ['aluminum', 'chemic', 'eastman', 'dow', 'plastic', 'carbid', 'resin', 'polym']
#
# TOPIC  20
# PROB WORDS: ['fiscal', 'food', 'brand', 'consum', 'commod', 'sharehold', 'beverag', 'gain']
# FREX WORDS: ['fiscal', 'conagra', 'food', 'maytag', 'heinz', 'beverag', 'restaur', 'brand']
#
# TOPIC  21
# PROB WORDS: ['insur', 'claim', 'risk', 'reinsur', 'liabil', 'life', 'premium', 'underwrit']
# FREX WORDS: ['reinsur', 'safeco', 'policyhold', 'underwrit', 'annuiti', 'allstat', 'claim', 'risk']
#
# TOPIC  22
# PROB WORDS: ['insur', 'life', 'premium', 'policyhold', 'american', 'group', 'cna', 'health']
# FREX WORDS: ['insur', 'policyhold', 'cna', 'life', 'casualti', 'underwrit', 'premium', 'reinsur']
#
# TOPIC  23
# PROB WORDS: ['steel', 'paper', 'divis', 'ton', 'pulp', 'instal', 'machin', 'suppli']
# FREX WORDS: ['steel', 'pulp', 'timber', 'furnac', 'ton', 'paperboard', 'lumber', 'armco']
#
# TOPIC  24
# PROB WORDS: ['store', 'fiscal', 'retail', 'merchandis', 'open', 'leas', 'center', 'depart']
# FREX WORDS: ['store', 'merchandis', 'fiscal', 'vendor', 'retail', 'stapl', 'hotel', 'marriott']
#
# TOPIC  25
# PROB WORDS: ['aircraft', 'railroad', 'transport', 'car', 'airlin', 'revenu', 'freight', 'traffic']
# FREX WORDS: ['aircraft', 'railroad', 'airlin', 'passeng', 'freight', 'traffic', 'car', 'boe']
#
# TOPIC  26
# PROB WORDS: ['risk', 'loan', 'bank', 'deriv', 'fair', 'portfolio', 'instrument', 'hedg']
# FREX WORDS: ['risk', 'loan', 'bancorp', 'hedg', 'portfolio', 'securit', 'lynch', 'swap']
#
# TOPIC  27
# PROB WORDS: ['care', 'health', 'network', 'telephon', 'medicar', 'medic', 'hospit', 'patient']
# FREX WORDS: ['pharmaci', 'medicar', 'patient', 'caremark', 'telecom', 'medicaid', 'telecommun', 'clinic']
#
# TOPIC  28
# PROB WORDS: ['fair', 'risk', 'flow', 'liabil', 'hedg', 'impact', 'impair', 'oblig']
# FREX WORDS: ['hedg', 'sfa', 'impair', 'risk', 'currenc', 'goodwil', 'swap', 'forwardlook']
#
# TOPIC  29
# PROB WORDS: ['energi', 'ga', 'electr', 'risk', 'consum', 'dominion', 'fuel', 'power']
# FREX WORDS: ['cm', 'dominion', 'ga', 'electr', 'pef', 'keyspan', 'energi', 'decommiss']

# %%
#create top six words
keywords = []

for i in range(0,number_topic):
    topics=model.show_topic(topicid=i, time=75, topn=6)
    words=" ".join([word for number, word in topics])
    keywords.append(words)

# %% [markdown]
# ### Descriptions: Based on year 1950

# %%
#run frex models, time = 20
frex_output_1950 = create_topic_word_data(model, corpus, frex_w =.5, time = 20)

for i in range(0,number_topic):
    print("TOPIC ", i)
    topics=model.show_topic(topicid=i, time=20, topn=8)
    topic_words =[word for number, word in topics]
    print("PROB WORDS:", topic_words)
    frex_words = get_frex_words(frex_output_1950, number_topic = i, topn=8)
    print("FREX WORDS:", frex_words)
    print(" ")
# Out:
# TOPIC  0
# PROB WORDS: ['court', 'action', 'alleg', 'claim', 'file', 'damag', 'district', 'defend']
# FREX WORDS: ['court', 'alleg', 'plaintiff', 'tobacco', 'complaint', 'defend', 'violat', 'district']
#
# TOPIC  1
# PROB WORDS: ['mine', 'ton', 'sugar', 'copper', 'or', 'coal', 'metal', 'explor']
# FREX WORDS: ['sugar', 'copper', 'mine', 'or', 'ton', 'zinc', 'coal', 'smelter']
#
# TOPIC  2
# PROB WORDS: ['shall', 'particip', 'section', 'committe', 'employ', 'termin', 'compens', 'execut']
# FREX WORDS: ['shall', 'lender', 'gatx', 'hereund', 'bonu', 'committe', 'dell', 'articl']
#
# TOPIC  3
# PROB WORDS: ['bank', 'loan', 'financ', 'inflat', 'percent', 'save', 'home', 'real']
# FREX WORDS: ['bank', 'loan', 'branch', 'lend', 'chase', 'monetari', 'mortgag', 'midland']
#
# TOPIC  4
# PROB WORDS: ['claim', 'court', 'bankruptci', 'liabil', 'file', 'reorgan', 'settlement', 'asbesto']
# FREX WORDS: ['bankruptci', 'asbesto', 'chapter', 'debtor', 'claim', 'court', 'creditor', 'asbestosrel']
#
# TOPIC  5
# PROB WORDS: ['prefer', 'grant', 'stockhold', 'convert', 'debentur', 'seri', 'properti', 'aggreg']
# FREX WORDS: ['corco', 'shall', 'prefer', 'loan', 'debentur', 'sink', 'redempt', 'redeem']
#
# TOPIC  6
# PROB WORDS: ['engin', 'divis', 'system', 'aircraft', 'air', 'research', 'electron', 'commerci']
# FREX WORDS: ['aircraft', 'missil', 'engin', 'navi', 'militari', 'mdc', 'flight', 'aerospac']
#
# TOPIC  7
# PROB WORDS: ['research', 'drug', 'pharmaceut', 'medic', 'health', 'diseas', 'clinic', 'abbott']
# FREX WORDS: ['abbott', 'clinic', 'drug', 'pharmaceut', 'patient', 'pfizer', 'diseas', 'antibiot']
#
# TOPIC  8
# PROB WORDS: ['war', 'stockhold', 'cent', 'depart', 'field', 'countri', 'public', 'organ']
# FREX WORDS: ['war', 'postwar', 'surplu', 'shall', 'men', 'arc', 'civilian', 'peacetim']
#
# TOPIC  9
# PROB WORDS: ['technolog', 'system', 'inform', 'percent', 'peopl', 'sharehold', 'help', 'perform']
# FREX WORDS: ['technolog', 'softwar', 'digit', 'global', 'ibm', 'xerox', 'ncr', 'semiconductor']
#
# TOPIC  10
# PROB WORDS: ['oil', 'ga', 'crude', 'drill', 'field', 'barrel', 'refineri', 'natur']
# FREX WORDS: ['crude', 'oil', 'ga', 'barrel', 'drill', 'refineri', 'occident', 'well']
#
# TOPIC  11
# PROB WORDS: ['environment', 'liabil', 'site', 'percent', 'remedi', 'oblig', 'standard', 'debt']
# FREX WORDS: ['environment', 'remedi', 'chrysler', 'cleanup', 'epa', 'prp', 'site', 'superfund']
#
# TOPIC  12
# PROB WORDS: ['electr', 'power', 'nuclear', 'util', 'fuel', 'energi', 'commiss', 'station']
# FREX WORDS: ['electr', 'nuclear', 'kilowatt', 'edison', 'westinghous', 'power', 'coal', 'reactor']
#
# TOPIC  13
# PROB WORDS: ['presid', 'vice', 'execut', 'york', 'chairman', 'divis', 'school', 'colleg']
# FREX WORDS: ['vice', 'presid', 'colleg', 'kodak', 'mcgrawhil', 'school', 'polaroid', 'film']
#
# TOPIC  14
# PROB WORDS: ['ga', 'columbia', 'natur', 'transmiss', 'pipelin', 'suppli', 'texa', 'commiss']
# FREX WORDS: ['ga', 'agwai', 'columbia', 'transmiss', 'pipelin', 'cubic', 'mohawk', 'niagara']
#
# TOPIC  15
# PROB WORDS: ['food', 'divis', 'farm', 'agricultur', 'tire', 'feed', 'suppli', 'milk']
# FREX WORDS: ['food', 'milk', 'tire', 'meat', 'deer', 'farm', 'dairi', 'feed']
#
# TOPIC  16
# PROB WORDS: ['divis', 'fabric', 'fiscal', 'consum', 'retail', 'brand', 'apparel', 'shoe']
# FREX WORDS: ['apparel', 'shoe', 'mattel', 'fabric', 'textil', 'disnei', 'knit', 'carpet']
#
# TOPIC  17
# PROB WORDS: ['sanminasci', 'nuclear', 'energi', 'regulatori', 'power', 'util', 'electr', 'decommiss']
# FREX WORDS: ['sanminasci', 'nuclear', 'decommiss', 'clp', 'firstenergi', 'wmeco', 'millston', 'psnh']
#
# TOPIC  18
# PROB WORDS: ['televis', 'advertis', 'viacom', 'station', 'radio', 'newspap', 'cabl', 'broadcast']
# FREX WORDS: ['televis', 'viacom', 'broadcast', 'radio', 'newspap', 'cabl', 'cb', 'advertis']
#
# TOPIC  19
# PROB WORDS: ['chemic', 'research', 'armco', 'aluminum', 'plastic', 'monsanto', 'divis', 'fiber']
# FREX WORDS: ['armco', 'monsanto', 'chemic', 'aluminum', 'plastic', 'fmc', 'resin', 'fiber']
#
# TOPIC  20
# PROB WORDS: ['food', 'fiscal', 'consum', 'brand', 'percent', 'packag', 'sharehold', 'acquisit']
# FREX WORDS: ['food', 'fiscal', 'conagra', 'brand', 'restaur', 'whirlpool', 'foodservic', 'drink']
#
# TOPIC  21
# PROB WORDS: ['insur', 'claim', 'risk', 'life', 'reinsur', 'premium', 'liabil', 'annuiti']
# FREX WORDS: ['reinsur', 'lnc', 'policyhold', 'berkshir', 'annuiti', 'insur', 'underwrit', 'aon']
#
# TOPIC  22
# PROB WORDS: ['insur', 'life', 'premium', 'continent', 'policyhold', 'cna', 'casualti', 'group']
# FREX WORDS: ['insur', 'cna', 'policyhold', 'casualti', 'continent', 'annuiti', 'underwrit', 'uslif']
#
# TOPIC  23
# PROB WORDS: ['steel', 'paper', 'divis', 'pulp', 'ton', 'machin', 'timber', 'instal']
# FREX WORDS: ['steel', 'pulp', 'timber', 'lumber', 'furnac', 'kaiser', 'cement', 'plywood']
#
# TOPIC  24
# PROB WORDS: ['store', 'fiscal', 'retail', 'leas', 'merchandis', 'open', 'center', 'group']
# FREX WORDS: ['store', 'merchandis', 'fiscal', 'stapl', 'retail', 'sear', 'carmax', 'safewai']
#
# TOPIC  25
# PROB WORDS: ['railroad', 'car', 'transport', 'aircraft', 'passeng', 'revenu', 'freight', 'traffic']
# FREX WORDS: ['railroad', 'passeng', 'aircraft', 'car', 'freight', 'airlin', 'traffic', 'railwai']
#
# TOPIC  26
# PROB WORDS: ['risk', 'loan', 'portfolio', 'billion', 'instrument', 'bank', 'deriv', 'transact']
# FREX WORDS: ['loan', 'risk', 'portfolio', 'swap', 'merril', 'lynch', 'securit', 'hedg']
#
# TOPIC  27
# PROB WORDS: ['telephon', 'care', 'health', 'network', 'commun', 'revenu', 'drug', 'regul']
# FREX WORDS: ['sprint', 'wireless', 'pharmaci', 'att', 'medicar', 'bell', 'telephon', 'drug']
#
# TOPIC  28
# PROB WORDS: ['fair', 'liabil', 'risk', 'flow', 'hedg', 'impair', 'impact', 'sfa']
# FREX WORDS: ['hedg', 'sfa', 'impair', 'visteon', 'swap', 'risk', 'goodwil', 'forwardlook']
#
# TOPIC  29
# PROB WORDS: ['energi', 'ga', 'electr', 'cm', 'consum', 'risk', 'natur', 'power']
# FREX WORDS: ['cm', 'mcv', 'ga', 'energi', 'electr', 'ferc', 'mpsc', 'duke']

# %% [markdown]
# # Topics over time

# %% [markdown]
# #https://jeriwieringa.com/2017/06/21/Calculating-and-Visualizing-Topic-Significance-over-Time-Part-1/
# #https://radimrehurek.com/gensim/models/ldamodel.html
# ##https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %% [markdown]
# ### open metadata

# %%
file_loc = "/Users/carlyknight/Documents/Data/Annual Report/report_paragraphs/future_texts/"

#limit to over 1930
metadata = pd.read_csv(file_loc + "metadata_futureperfect.csv") 
metadata = metadata[(metadata['Year'] >= 1930)]
metadata['text_filename'] = metadata['Filename'].str.replace(".xml", ".txt")

# %% [markdown]
# # Get document-topic weights

# %%
#create document-topic matrix
num_docs = model.lencorpus
data = []

for j in range(0, num_docs):
    doc_topics = [model.gamma_[j, i] for i in range(0, number_topic)]
    data.append(doc_topics)
    
topic_document_distribution = pd.DataFrame(data)
topic_document_distribution.shape
# Out:
# (36479, 30)

# %%
#check to make sure weights load to 1:
sumweights= topic_document_distribution.sum(axis=1)
for i, doc in enumerate(sumweights):
    if doc !=1:
        continue
        #print("Doc ", i, " does not equal 1: ", doc )

# %%
#basically loads to 1

#pull in metadata
names = [i for i in metadata['Filename']]
topic_document_distribution['Filename'] = names
years = [i for i in metadata['Year']]
topic_document_distribution['Year'] = years

topic_document_distribution.to_csv("/Users/carlyknight/Dropbox/PROJECTS/ConceptionsofRisk/data/dtm/topic_document_distribution.csv")

#convert dataset to long
dtm = pd.melt(topic_document_distribution, id_vars=["Filename", "Year"], var_name= "topic", value_name='weight')
dtm=dtm.sort_values(by = ["Year", "Filename", "topic"])
print(dtm.head())
# Out:
#             Filename  Year topic        weight
# 21217   88178299.xml  1930     0  0.0003095975
# 57696   88178299.xml  1930     1  0.0003095975
# 94175   88178299.xml  1930     2  0.1454691687
# 130654  88178299.xml  1930     3  0.0003095975
# 167133  88178299.xml  1930     4  0.0003095975

# %%
#put in topic keywords
dfkeys = pd.DataFrame(keywords)
dfkeys.columns = ['keywords']
dfkeys['topic'] = range(0,number_topic)

#merge
dtm=dtm.merge(dfkeys, left_on='topic', right_on='topic')
print(dtm.head())
# Out:
#        Filename  Year topic        weight  \
# 0  88178299.xml  1930     0  0.0003095975
# 1  88178309.xml  1930     0  0.0003003003
# 2  88178340.xml  1930     0  0.0001049318
# 3  88178352.xml  1930     0  0.0010752688
# 4  88178376.xml  1930     0  0.0012048193
#
#                                keywords
# 0  court action claim file alleg defend
# 1  court action claim file alleg defend
# 2  court action claim file alleg defend
# 3  court action claim file alleg defend
# 4  court action claim file alleg defend

# %% [markdown]
# # Summary Statistics

# %%
dtm_sum = dtm[dtm['weight'] != 0]

print("Max: {}".format(dtm_sum['weight'].max()))
print("Min: {}".format(dtm_sum['weight'].min()))
print("Average: {}".format(dtm_sum['weight'].mean()))
print("Median: {}".format(dtm_sum['weight'].median()))
print("Most frequent value: {}".format(dtm_sum['weight'].round(3).value_counts().idxmax()))
# Out:
# Max: 0.9993181283799673
# Min: 3.9878291454480874e-07
# Average: 0.03333333333335221
# Median: 3.8565368299267265e-05
# Most frequent value: 0.0

# %% [markdown]
# # Graph over time

# %%
# Get number of docs per year
total_docs = dtm.groupby('Year')['Filename'].apply(lambda x: len(x.unique())).reset_index()
total_docs.columns = ['Year', 'total_docs']

# Group by year and topic id
dtm_avg = dtm.groupby(['Year', 'topic'])['weight'].sum().reset_index()

# Merge dataframes
dtm_avg_1 = dtm_avg.merge(total_docs, on="Year", how="left")

# Compute the mean per topic
dtm_avg_1['average_weight'] = dtm_avg_1['weight'] / dtm_avg_1['total_docs']

#merge in labels
labels= dtm[['topic', 'keywords']].drop_duplicates()
dtm_avg_2 = dtm_avg_1.merge(labels, on='topic')

dtm_time = dtm_avg_2

# %%
#Create plot
def create_pointplot(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='point', hue=hue, 
                       col=col, col_wrap=wrap,  height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    p.set_xticklabels(rotation=45)
    n = 5  # Keeps every 5th label
    [l.set_visible(False) for (i,l) in enumerate(p.ax.xaxis.get_ticklabels()) if i % n != 0]
    return p


def create_bar(df, y_value, hue=None, col=None, wrap=None, height=5, aspect=1.5, title=""):
    p = sns.catplot(x="Year", y=y_value, kind='bar', hue=hue, 
                       col=col, col_wrap=wrap, height=height, aspect=aspect, data=df)
    p.fig.subplots_adjust(top=0.9)
    p.fig.suptitle(title, fontsize=16)
    return p

# %% [markdown]
# # Plots

# %%
for i in range(0, number_topic, 5):
    dfs = dtm_time[(dtm_time['topic'] >= i) & (dtm_time['topic'] < i +5 )]
    create_pointplot(dfs, 'average_weight', hue="topic",
                title="Yearly Average of Normalized Weight per Topic")
